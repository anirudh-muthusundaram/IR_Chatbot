# %% [markdown]
# ## Web Scrpaing

# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
import wikipedia
import time
import requests
from bs4 import BeautifulSoup, FeatureNotFound

# UB IT name based user agent
user = "amuthusu/IR (https://www.linkedin.com/in/anirudhmuthusundaram/; anirudhms247@gmail.com)"

# User agent Assignment
wikipedia.set_user_agent(user)

# API endpoint
url = "https://www.mediawiki.org/w/api.php"
headers = {
    "User-Agent": user
}

# %% [markdown]
# ### Health

# %%
# Define the topics and subtopics
title = {
    'Health': [
        'Common diseases',
        'Global health statistics',
        'Mental health trends',
        'Cardiovascular health',
        'Diabetes management',
        'Cancer types and treatments',
        'Childhood vaccinations',
        'Epidemiology of infectious diseases',
        'Nutrition and dietetics',
        'Mental disorders and therapies',
        'Public health policies',
        'Healthcare systems worldwide',
        'Women’s health issues',
        'Men’s health issues',
        'Pediatric health and diseases',
        'Geriatric care and aging',
        'Dental health and hygiene',
        'Eye health and vision care',
        'Orthopedics and musculoskeletal disorders',
        'Dermatological conditions and skincare',
        'Neurological disorders',
        'Gastrointestinal diseases',
        'Respiratory diseases and treatment',
        'Endocrinology and hormonal disorders',
        'Physical fitness and exercise',
        'Mental wellness and mindfulness',
        'Alternative and complementary medicine',
        'Pharmacology and medication',
        'Environmental health and pollution',
        'Occupational health and safety',
        'Global pandemics and outbreaks',
        'Vaccination and immunization',
        'First aid and emergency medicine',
        'Radiology and imaging',
        'Surgical advancements and techniques',
        'Telemedicine and digital health',
        'Addiction and rehabilitation',
        'Reproductive health and fertility',
        'Healthcare technology and innovations',
        'Public health education and awareness',
        'Health insurance and economics',
        'Epidemics and their control',
        'Sleep health and disorders',
        'Allergies and autoimmune diseases',
        'Health effects of climate change',
        'Genetics in medicine',
        'Global health initiatives'
    ]
}

# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5600 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: Common cold
# PageError for title: Pogona
# PageError for title: Nonsense mutation
# PageError for title: Infection
# PageError for title: Tetter
# PageError for title: Lupus
# PageError for title: Nobel disease
# PageError for title: ALS
# PageError for title: Chagas disease
# PageError for title: Bronchus
# PageError for title: Human body
# PageError for title: Canavan disease
# PageError for title: Batten disease
# PageError for title: List of rye diseases
# PageError for title: Diseases of the foot
# PageError for title: Kuru (disease)
# PageError for title: Enteritis
# PageError for title: Tomato
# PageError for title: Atypical pneumonia
# PageError for title: Gallstone
# PageError for title: Longan
# PageError for title: Common nighthawk
# PageError for title: Herd immunity
# PageError for title: Canada
# PageError for title: Sustainable Development Goal 3
# PageError for title: Average human height by country
# PageError for title: Statistics of the COVID-19 pandemic in Brazil
# PageError for title: Allied health professions
# PageError for title: Population growth
# PageError for title: Mortality rate
# PageError for title: Environmental health
# PageError for title: China
# PageError for title: Rape statistics
# PageError for title: Metro Manila
# PageError for title: Demographics of Africa
# PageError for title: World Economic Forum
# PageError for title: Healthcare in the United Kingdom
# PageError for title: Norway
# PageError for title: Benin
# PageError for title: Philippines
# PageError for title: Abortion
# PageError for title: Obesity
# PageError for title: Urban area
# PageError for title: Sustainable Development Goal 7
# PageError for title: Prison
# PageError for title: Midday Meal Scheme
# PageError for title: Kayah State
# PageError for title: COVID-19 vaccine
# PageError for title: Black swan theory
# PageError for title: Teenage pregnancy
# PageError for title: Kenya
# PageError for title: City
# PageError for title: New York City
# PageError for title: Cataract
# PageError for title: Gender inequality in India
# PageError for title: Casino
# PageError for title: Worldometer
# PageError for title: Cervical cancer
# PageError for title: Sergey Brin
# PageError for title: Prostitution
# PageError for title: Economy of Canada
# PageError for title: Ren Gill
# PageError for title: Allied health professions
# PageError for title: Sadfishing
# PageError for title: Spectrum disorder
# PageError for title: CoryxKenshin
# PageError for title: Average human height by country
# Unhandled exception for title: Social support: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Loneliness: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Sociology of food: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Abortion: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Effects of pornography: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Treatment of mental disorders: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: List of awareness ribbons: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Alberta Health Services: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Healthcare in the State of Palestine: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Anthony Jorm: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Public health surveillance: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Bullet journal: An unknown error occured: "Search is currently too busy. Please try again later.". Please report it on GitHub!
# PageError for title: Etika
# PageError for title: Alastair Campbell
# PageError for title: Catherine, Princess of Wales
# PageError for title: Corecore
# PageError for title: IQ classification
# PageError for title: Lzzy Hale
# PageError for title: Avicii
# PageError for title: Old age
# PageError for title: Kaiser Permanente
# PageError for title: School shooting
# PageError for title: Generation Z in the United States
# PageError for title: Obesity
# PageError for title: Healthcare in Ethiopia
# PageError for title: Environmental health
# PageError for title: Canada
# PageError for title: Smash or pass?
# PageError for title: Risky sexual behavior
# PageError for title: Madison Bailey
# PageError for title: Video game addiction
# PageError for title: Zuri Hall
# PageError for title: Asexuality
# PageError for title: FMR1
# PageError for title: Healthcare in the United Kingdom
# PageError for title: Birth weight
# PageError for title: Convenience sampling
# PageError for title: Vaas Montenegro
# PageError for title: Jesy Nelson
# PageError for title: Selena Gomez
# PageError for title: Teenage pregnancy
# PageError for title: Maternal health
# PageError for title: Gender inequality in India
# PageError for title: Rollo May
# PageError for title: Oily fish
# PageError for title: Om Murti Anil
# PageError for title: DASH diet
# PageError for title: Orgasm
# PageError for title: Healthy diet
# PageError for title: ALS
# PageError for title: Circulatory system
# PageError for title: Dukan Diet
# PageError for title: Vitamin B12
# PageError for title: Henry Kravis
# PageError for title: Western gorilla
# PageError for title: Food desert
# PageError for title: Alpha Phi
# PageError for title: Sunscreen
# PageError for title: Centenarian
# PageError for title: Robert Lustig
# PageError for title: Ministry of Health and Family Welfare
# PageError for title: Stephen Nicholls
# PageError for title: Therapy dog
# PageError for title: Ancel Keys
# PageError for title: Subjective well-being
# PageError for title: Allied health professions
# PageError for title: Red meat
# PageError for title: Immunosenescence
# PageError for title: Obesity
# PageError for title: Nuvance Health
# PageError for title: Cardiac surgery
# PageError for title: Walking
# PageError for title: Marfan syndrome
# PageError for title: Veganism
# PageError for title: Aspirin
# PageError for title: Amy Herr
# PageError for title: Jacki Sorensen
# PageError for title: Sustainable Development Goal 3
# PageError for title: Environmental health
# PageError for title: Maternal health
# PageError for title: Multivitamin
# PageError for title: Pollution
# PageError for title: Carnivore diet
# PageError for title: Luana Reyes
# PageError for title: SingHealth
# PageError for title: Dexcom
# PageError for title: Medtronic
# PageError for title: OpenAPS
# PageError for title: Verily
# PageError for title: Underweight
# PageError for title: Angina
# PageError for title: Metformin
# PageError for title: Obesity
# PageError for title: Taylor Wang
# PageError for title: Occupational therapy
# PageError for title: Red meat
# PageError for title: Tim Noakes
# PageError for title: Oren Liebermann
# PageError for title: Lewis Marnell
# PageError for title: Liberty Medical
# PageError for title: Canada
# PageError for title: Sanofi
# PageError for title: John Rollo
# PageError for title: Frederick Banting
# PageError for title: Birth weight
# PageError for title: Summit Health
# PageError for title: Rocky Aoki
# PageError for title: Bell's palsy
# PageError for title: CDA
# PageError for title: 2018 in American television
# PageError for title: DASH diet
# PageError for title: Neurodevelopmental disorder
# PageError for title: Autoimmunity
# PageError for title: Glutathione
# PageError for title: Bladder cancer
# PageError for title: Cervical cancer
# PageError for title: Recurrent cancer
# PageError for title: Salivary gland tumour
# PageError for title: Genital wart
# PageError for title: Photodynamic therapy
# PageError for title: Mohs surgery
# PageError for title: Breathwork
# PageError for title: Richard J Stephenson
# PageError for title: Cachexia
# PageError for title: Cancer cell
# PageError for title: Moderna
# PageError for title: Blood in stool
# PageError for title: Belle Gibson
# PageError for title: T-cell lymphoma
# PageError for title: Sean Parker
# PageError for title: Immunotherapy
# PageError for title: Prostate
# PageError for title: Metformin
# PageError for title: Benign tumor
# PageError for title: Squamous-cell carcinoma of the vagina
# PageError for title: Cervix
# PageError for title: Johnny Ruffo
# PageError for title: BRCA1
# PageError for title: Rob Schneider
# PageError for title: Amanda Peet
# PageError for title: Anti-vaccine activism
# PageError for title: Smallpox
# PageError for title: Christiane Northrup
# PageError for title: Measles
# PageError for title: Jenny McCarthy
# PageError for title: Leana Wen
# PageError for title: Hepatitis B vaccine
# PageError for title: Tigray War
# PageError for title: Caste system in India
# PageError for title: Jim Breuer
# PageError for title: Edward Jenner
# PageError for title: 20th Century Boys
# PageError for title: Jessica Biel
# PageError for title: Marianne Williamson
# PageError for title: Joe Biden
# PageError for title: Jo Frost
# PageError for title: Yellow fever
# PageError for title: Bill Gates
# PageError for title: List of medical abbreviations: T
# PageError for title: Roald Dahl
# PageError for title: Rishi Sunak
# PageError for title: National File
# PageError for title: Won Bin
# PageError for title: List of The Conners episodes
# PageError for title: Gavin Newsom
# PageError for title: Joe Rogan
# PageError for title: Immunization
# PageError for title: Pox party
# PageError for title: Dolly Parton
# PageError for title: Breathwork
# PageError for title: Javier Milei
# PageError for title: Otitis media
# PageError for title: Harvard Classics
# PageError for title: Robert De Niro
# PageError for title: Jill Biden
# PageError for title: Selena Gomez
# PageError for title: Satanic panic
# PageError for title: Belle Gibson
# PageError for title: Polio in Pakistan
# PageError for title: Sensitization
# PageError for title: 2022 in British television
# PageError for title: List of acts of the 117th United States Congress
# PageError for title: Matt Le Tissier
# PageError for title: Ron Johnson
# PageError for title: Bongbong Marcos
# PageError for title: Lenny Henry
# PageError for title: 2023 in British television
# PageError for title: Brave New World
# PageError for title: Graham Linehan
# PageError for title: Scott Morrison
# PageError for title: Fidel Castro
# PageError for title: Chris Hipkins
# PageError for title: Sajid Javid
# PageError for title: Immunosenescence
# PageError for title: MacGruber
# PageError for title: Jimmy Dore
# PageError for title: 2023 Birthday Honours
# PageError for title: Paul Offit
# PageError for title: Nick Catone
# PageError for title: Lindsey Graham
# PageError for title: Ian Dury
# PageError for title: Conversion therapy
# PageError for title: Normani
# PageError for title: Infection
# PageError for title: Population growth
# PageError for title: Cervix
# PageError for title: Infection
# PageError for title: Latent period (epidemiology)
# PageError for title: Infectious period
# PageError for title: George Seage
# PageError for title: Thomas E. Dobbs
# PageError for title: Kuru (disease)
# PageError for title: Chagas disease
# PageError for title: Herd immunity
# PageError for title: Enteritis
# PageError for title: Pathogenic bacteria
# PageError for title: Mary-Louise McLaws
# PageError for title: Anthony Fauci
# PageError for title: Biosafety level
# PageError for title: Yellow fever
# PageError for title: Rabies
# PageError for title: Spanish flu
# PageError for title: SaTScan
# PageError for title: Smallpox
# PageError for title: Sarah Cleaveland
# PageError for title: Pox party
# PageError for title: David Fisman
# PageError for title: Measles
# PageError for title: Common cold
# PageError for title: Mpox
# PageError for title: Environmental health
# PageError for title: Barbara O'Neill
# PageError for title: Veganism
# PageError for title: Red meat
# PageError for title: Lenna F. Cooper
# PageError for title: Healthy diet
# PageError for title: Joy Bauer
# PageError for title: Brenda Davis
# PageError for title: Food security
# PageError for title: RVS College of Arts and Science
# PageError for title: Vitamin B12
# PageError for title: Tambra Raye Stevenson
# PageError for title: Phytanic acid
# PageError for title: Obesity
# PageError for title: Conformity
# PageError for title: Food craving
# PageError for title: Clare Collins
# PageError for title: Nutrition transition
# PageError for title: Zvi HaCohen
# PageError for title: Maye Musk
# PageError for title: 2021 New Year Honours
# PageError for title: Meg Lemon
# PageError for title: Adelle Davis
# PageError for title: DSM-5
# PageError for title: Conversion disorder
# PageError for title: Conversion therapy
# PageError for title: Schema therapy
# PageError for title: Abnormal psychology
# PageError for title: Occupational therapy
# PageError for title: Anxiety
# PageError for title: ICD-11
# PageError for title: Intrusive thought
# PageError for title: Therapist
# PageError for title: Depression (mood)
# PageError for title: Video game addiction
# PageError for title: Aaron Beck
# PageError for title: David H. Barlow
# PageError for title: MindMed
# PageError for title: Panic attack
# PageError for title: Lauretta Bender
# PageError for title: Jonathan Comer
# PageError for title: Hyperfocus
# PageError for title: Hyperphantasia
# PageError for title: Codependency
# PageError for title: Adderall
# PageError for title: Avolition
# PageError for title: Philippe Pinel
# PageError for title: Keith Dobson
# PageError for title: Ashish Jha
# PageError for title: Elevance Health
# PageError for title: Smoking ban
# PageError for title: Overton window
# PageError for title: Environmental health
# PageError for title: Rachel Levine
# PageError for title: Obesity
# PageError for title: Alice Chen
# PageError for title: Beveridge model
# PageError for title: Tara Kirk
# PageError for title: Governance
# PageError for title: Public participation
# PageError for title: Barbara Ferrer
# PageError for title: Milken Institute School of Public Health
# PageError for title: TATA AIG
# PageError for title: Lisa Berkman
# PageError for title: RAND Corporation
# PageError for title: Healthcare in the United Kingdom
# PageError for title: Public housing
# PageError for title: Veeva Systems
# PageError for title: CAE Inc.
# PageError for title: OpenVMS
# PageError for title: BSI Group
# PageError for title: Green party
# PageError for title: Circulatory system
# PageError for title: Travelport
# PageError for title: Infor
# PageError for title: Demographics of Africa
# PageError for title: ZS Associates
# PageError for title: Canada
# PageError for title: Honeywell
# PageError for title: DXC Technology
# PageError for title: Nasdaq-100
# PageError for title: Mayo Clinic
# PageError for title: Accenture
# PageError for title: Sakthi Group
# PageError for title: Jawan (film)
# PageError for title: List of S&P 400 companies
# PageError for title: Norovirus
# PageError for title: Elevance Health
# PageError for title: ChatGPT
# PageError for title: Larry Fink
# PageError for title: Pegasystems
# PageError for title: Ady Barkan
# PageError for title: Maternal health
# PageError for title: Allied health professions
# PageError for title: Tyman
# PageError for title: Empiric Student Property
# PageError for title: Wipro
# PageError for title: Sustainable Development Goal 3
# PageError for title: Samsung SDS
# PageError for title: Jabil
# PageError for title: Chuck Norris
# PageError for title: TTK Group
# PageError for title: Big Hero 6 (film)
# PageError for title: HID Global
# PageError for title: Freepik
# PageError for title: Blackstone Inc.
# PageError for title: Merck Group
# PageError for title: Nick Varney
# PageError for title: AppDynamics
# PageError for title: InDrive
# PageError for title: G4S
# PageError for title: Accidental Love
# PageError for title: Tonga
# PageError for title: CS gas
# PageError for title: List of S&P 600 companies
# PageError for title: Signify N.V.
# PageError for title: Greggs
# PageError for title: Withings
# PageError for title: Linde plc
# PageError for title: ADP (company)
# PageError for title: Way Maker
# PageError for title: Air Liquide
# PageError for title: Fran Drescher
# PageError for title: Environmental issues
# PageError for title: Teenage pregnancy
# PageError for title: Women in Algeria
# PageError for title: Dobbs v. Jackson Women's Health Organization
# PageError for title: Abortion
# PageError for title: Animal hoarding
# PageError for title: Maternal health
# PageError for title: Gender inequality in India
# PageError for title: Donna Redel
# PageError for title: International Men's Day
# PageError for title: Medical abortion
# PageError for title: Maye Musk
# PageError for title: Rachel Levine
# PageError for title: Catherine M. Russell
# PageError for title: Female education
# PageError for title: Lila Wallis
# PageError for title: Staci Gruber
# PageError for title: Demographics of Africa
# PageError for title: Pollution
# PageError for title: Rosa DeLauro
# PageError for title: Tonya Lewis Lee
# PageError for title: Sex work
# PageError for title: Women in Ghana
# PageError for title: Doggy style
# PageError for title: Shih Tzu
# PageError for title: Milken Institute School of Public Health
# PageError for title: Sustainable Development Goal 3
# PageError for title: Phyllis Stern
# PageError for title: Roe v. Wade
# PageError for title: Elevance Health
# PageError for title: Rosalynn Carter
# PageError for title: Alexis Ren
# PageError for title: Strong black woman
# PageError for title: Arewa 24
# PageError for title: Sara Josephine Baker
# PageError for title: Women on Waves
# PageError for title: Marie Forleo
# PageError for title: Michael Grodin
# PageError for title: Ampallang
# PageError for title: Nimco Ali
# PageError for title: Women in Oman
# PageError for title: Adolescent sexuality
# PageError for title: Rania Awaad
# PageError for title: No Nut November
# PageError for title: International Men's Day
# PageError for title: Philip Davies
# PageError for title: Gender inequality in India
# PageError for title: XHamster
# PageError for title: Dobbs v. Jackson Women's Health Organization
# PageError for title: Rachel Levine
# PageError for title: Sex work
# PageError for title: Doggy style
# PageError for title: Average human height by country
# PageError for title: Glory hole
# PageError for title: State of Palestine
# PageError for title: Two and a Half Men
# PageError for title: Carl Lentz
# PageError for title: Thad Matta
# PageError for title: Sustainable Development Goal 3
# PageError for title: Ampallang
# PageError for title: Dua Lipa
# PageError for title: Moscow mule
# PageError for title: Oral sex
# Error for title: Rhodesian Ridgeback, retrying (1/3)
# PageError for title: Non-penetrative sex
# PageError for title: Interpretative phenomenological analysis
# PageError for title: Teenage pregnancy
# PageError for title: Adolescent sexuality
# PageError for title: Afghan Hound
# PageError for title: Italy
# PageError for title: Richard Isay
# PageError for title: Roe v. Wade
# PageError for title: Intersex
# PageError for title: Lyle Foster
# PageError for title: Mad Men
# PageError for title: 2024 NCAA Division I men's basketball tournament
# PageError for title: Obesity
# PageError for title: Tim Scott
# PageError for title: Joseph Baena
# PageError for title: Gavin Newsom
# PageError for title: John F. Kennedy
# PageError for title: Olivia Munn
# PageError for title: Christie Brinkley
# PageError for title: Ted Kennedy
# PageError for title: Abortion
# PageError for title: Karamo Brown
# PageError for title: Brooklyn Decker
# PageError for title: Bhutan
# PageError for title: Sophia Bush
# PageError for title: Catherine, Princess of Wales
# PageError for title: List of social movements
# PageError for title: Women in Algeria
# PageError for title: Sedation
# PageError for title: Average human height by country
# PageError for title: SingHealth
# PageError for title: Peter Hotez
# PageError for title: NewYork-Presbyterian Hospital
# PageError for title: George Seage
# PageError for title: Rohit Varma
# PageError for title: Areola
# PageError for title: Robert Lustig
# PageError for title: Rachel Levine
# PageError for title: The 2nd Affiliated Hospital & Yuying Children's Hospital
# PageError for title: Measles
# PageError for title: Mustafa Abdalla Mohamed Salih
# PageError for title: Tanner scale
# PageError for title: James E. Crowe
# PageError for title: Obesity
# PageError for title: Herd immunity
# PageError for title: Lupus
# PageError for title: UNC Medical Center
# PageError for title: Maternal health
# Error for title: Scurvy, retrying (1/3)
# PageError for title: Circulatory system
# PageError for title: Norovirus
# PageError for title: Appendicitis
# PageError for title: Cyanosis
# PageError for title: List of medical abbreviations: P
# PageError for title: Old age
# PageError for title: Mark Lachs
# PageError for title: Sidney Katz
# PageError for title: Parenteral nutrition
# PageError for title: Elaine Brody
# PageError for title: Sumner Redstone
# PageError for title: Vaginal discharge
# PageError for title: Vitamin B12 deficiency
# PageError for title: UNC Medical Center
# PageError for title: Debra Fox
# PageError for title: Ryman Healthcare
# PageError for title: List of medical abbreviations: G
# PageError for title: The Golden Girls
# PageError for title: Animal hoarding
# PageError for title: DSM-5
# PageError for title: Gallstone
# PageError for title: Guinea pig
# PageError for title: Rosa Parks
# PageError for title: Jonathan Comer
# PageError for title: Palpitations
# PageError for title: Tommy Prince
# PageError for title: Toothpaste
# PageError for title: Dental implant
# PageError for title: Ministry of Health and Family Welfare

# %%
# Create the CSV from the DataFrame
h_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Health.csv"
h_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Health = pd.read_csv("./Data/Health.csv")
Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ### Environment

# %%
# Define the topics and subtopics
title = {
    'Environment': [
        'Global warming', 'Endangered species', 'Deforestation rates',
        'Climate change effects', 'Sea level rise', 'Ocean acidification',
        'Carbon footprint reduction', 'Renewable energy sources', 'Greenhouse gas emissions',
        'Wildlife conservation', 'Habitat loss', 'Invasive species',
        'Biodiversity hotspots', 'Pollinator decline', 'Marine life protection',
        'Plastic pollution', 'Air quality and smog', 'Water pollution',
        'Hazardous waste disposal', 'Recycling and upcycling', 'E-waste management',
        'Sustainable agriculture', 'Water scarcity and management', 'Fossil fuels vs. renewable energy',
        'Deforestation and reforestation', 'Soil degradation', 'Solar and wind energy advancements',
        'Environmental laws and regulations', 'Corporate sustainability practices', 'Environmental activism',
        'Impact of urbanization', 'Eco-friendly products and innovations', 'Environmental education and awareness',
        'Amazon rainforest conservation', 'Great Barrier Reef deterioration', 'Arctic ice melt',
        'Air quality in major cities', 'Effects of specific environmental disasters', 'Conservation efforts in specific countries',
        'Climate change predictions', 'Future of renewable energy', 'Long-term conservation strategies',
        'Environmental impact of technology', 'Sustainable urban planning', 'Population growth and environmental impact'
    ],
}
# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: Drought
# PageError for title: Indus River
# PageError for title: Climate of Mars
# PageError for title: Arctic
# PageError for title: John Hagee
# PageError for title: Polar bear
# PageError for title: James Spann
# PageError for title: Frank Luntz
# PageError for title: Environmental issues
# PageError for title: Maximum Ride
# PageError for title: Deforestation
# PageError for title: Hurricane Sandy
# PageError for title: El Niño
# PageError for title: Rat snake
# PageError for title: Richard Branson
# PageError for title: An Inconvenient Truth
# PageError for title: Greta Thunberg
# PageError for title: Steven Tyler
# PageError for title: Environmental science
# PageError for title: R-410A
# PageError for title: Shale gas
# PageError for title: Titanic II (film)
# PageError for title: Pollution
# PageError for title: Water scarcity
# PageError for title: R-454B
# PageError for title: Al Gore
# PageError for title: Swami Sundaranand
# PageError for title: City
# PageError for title: The Washington Times
# PageError for title: World Economic Forum
# PageError for title: Earth Day
# PageError for title: Ice age
# PageError for title: Polar desert
# PageError for title: TotalEnergies
# PageError for title: Paul Hawken
# PageError for title: The Daily Sceptic
# PageError for title: Atmosphere of Earth
# PageError for title: Pacific Northwest tree octopus
# PageError for title: Formosan black bear
# PageError for title: Virgin River
# PageError for title: Doc Antle
# PageError for title: Blue whale
# PageError for title: Ex situ conservation
# PageError for title: Taxus
# PageError for title: Elizabeth Ann
# PageError for title: Eastern cougar
# PageError for title: Bull trout
# PageError for title: Great hammerhead
# PageError for title: Fraser fir
# PageError for title: Sei whale
# PageError for title: Philippine eagle
# PageError for title: Laysan duck
# PageError for title: Golden lancehead
# PageError for title: San Diego Zoo
# PageError for title: Devil fish
# PageError for title: Spotted owl
# PageError for title: California condor
# PageError for title: Silvery gibbon
# PageError for title: Javan hawk-eagle
# Error for title: United States Fish and Wildlife Service Office of Law Enforcement, retrying (1/3)
# PageError for title: Little brown bat
# PageError for title: Deforestation
# PageError for title: Deforestation in Brazil
# PageError for title: Pantanal
# PageError for title: Forestry in Pakistan
# PageError for title: Gustavo Petro
# PageError for title: Belize
# PageError for title: Environmental degradation
# PageError for title: Gombi
# PageError for title: Central African Republic
# PageError for title: Marina Silva
# PageError for title: Girei
# PageError for title: Erosion
# PageError for title: Blackstone Inc.
# PageError for title: Logging
# PageError for title: Cargill
# PageError for title: Larry Fink
# PageError for title: Forestry in Argentina
# PageError for title: Environmental issues
# PageError for title: JBS S.A.
# PageError for title: Gabon
# PageError for title: Philippine eagle
# PageError for title: Rishi Sunak
# PageError for title: Industrial Revolution
# PageError for title: Electric ant
# PageError for title: Western gorilla
# PageError for title: Jeff Bezos
# PageError for title: Environmental science
# PageError for title: Trader Joe's
# PageError for title: White bellbird
# PageError for title: Gillian Anderson
# PageError for title: Italy
# PageError for title: Red panda
# PageError for title: Sumatran tiger
# PageError for title: Deepfake
# PageError for title: Flood control
# PageError for title: Southeast Asia
# PageError for title: Panama Canal
# PageError for title: Greta Thunberg
# PageError for title: American marten
# PageError for title: Norway
# PageError for title: East Timor
# PageError for title: Haiti
# PageError for title: Coyote
# PageError for title: King cobra
# PageError for title: Edo period
# PageError for title: Philippines
# PageError for title: Christmas tree
# PageError for title: Spirited Away
# PageError for title: Organic farming
# PageError for title: Saint Helena
# PageError for title: Mau Forest
# PageError for title: Climate change in Iraq
# PageError for title: Deforestation
# PageError for title: Drought
# PageError for title: Water resources
# PageError for title: Temperate climate
# PageError for title: Springtail
# PageError for title: Climate of South Africa
# PageError for title: Deep Adaptation
# PageError for title: 2040 (film)
# PageError for title: Flood control
# PageError for title: Asia
# PageError for title: El Niño
# PageError for title: Greta Thunberg
# PageError for title: Climate of Mars
# PageError for title: Anthony Zinni
# PageError for title: Pollution
# PageError for title: Freeman Dyson
# PageError for title: Livestock
# PageError for title: Sea level
# PageError for title: Sea level
# PageError for title: Maldives
# PageError for title: Coastal flooding
# PageError for title: Flood control
# Error for title: Marshall Islands, retrying (1/3)
# PageError for title: 6th millennium BC
# PageError for title: Environmental degradation
# PageError for title: Coastal management
# PageError for title: Robben Island
# PageError for title: Aral Sea
# PageError for title: Outer Banks
# PageError for title: Cape Town
# PageError for title: Delta Works
# PageError for title: Salton Sea
# PageError for title: Lyonesse
# PageError for title: Robin Bartleman
# PageError for title: Doggerland
# PageError for title: Cortes Bank
# PageError for title: The Fens
# PageError for title: Cosquer Cave
# PageError for title: Tombolo
# PageError for title: Subboreal
# PageError for title: Drought
# PageError for title: Red knot
# PageError for title: Acid rain
# PageError for title: Deep sea
# PageError for title: Calcite
# PageError for title: Sea urchin
# PageError for title: Pollution
# PageError for title: Bay of Bengal
# PageError for title: Socioeconomics
# PageError for title: Haze
# PageError for title: Environmental issues
# PageError for title: Biocapacity
# PageError for title: Biomedical waste
# PageError for title: Timeline of the far future
# PageError for title: Incineration
# PageError for title: List of bills in the 117th United States Congress
# PageError for title: Ozone
# PageError for title: Environmental engineering
# PageError for title: Sweetgreen
# PageError for title: Open defecation
# PageError for title: Kii Peninsula
# PageError for title: World Surf League
# PageError for title: Volcanic ash
# PageError for title: Microplastics
# PageError for title: Unisys
# PageError for title: Food miles
# PageError for title: Nike, Inc.
# PageError for title: Screw piles
# PageError for title: Environmental issues
# PageError for title: Drought
# PageError for title: Water resources
# PageError for title: Biochar
# PageError for title: Simple living
# PageError for title: Deforestation
# Error for title: ITS Dental Hospital, retrying (1/3)
# PageError for title: Environmental degradation
# PageError for title: Demarketing
# PageError for title: Gary Gensler
# PageError for title: Environmental technology
# PageError for title: Green growth
# PageError for title: District heating
# Error for title: Kia EV6, retrying (1/3)
# PageError for title: Flood control
# PageError for title: Bioplastic
# PageError for title: Food security
# PageError for title: Digital Cleanup Day
# PageError for title: City
# PageError for title: Biofilter
# PageError for title: IPhone 12
# PageError for title: Data center
# PageError for title: Honeywell
# PageError for title: Tata Steel
# PageError for title: Vertical farming
# PageError for title: Incineration
# PageError for title: Deforestation in Brazil
# PageError for title: Greta Thunberg
# PageError for title: Non-renewable resource
# PageError for title: Desertec
# PageError for title: Bioenergy
# PageError for title: LUMA Energy
# PageError for title: Terna Energy
# PageError for title: Microgrid
# PageError for title: Ministry of Energy (Saudi Arabia)
# PageError for title: Dominion Energy
# PageError for title: Off-the-grid
# PageError for title: Energy in Zambia
# PageError for title: Eco hotel
# PageError for title: Energy in Austria
# PageError for title: Energy in Chile
# PageError for title: Green computing
# PageError for title: Renewable Energy Programme
# PageError for title: Electricity sector in Iceland
# PageError for title: Nike, Inc.
# PageError for title: Shale gas
# PageError for title: Data center
# PageError for title: Shell plc
# PageError for title: Pollution
# PageError for title: Livestock
# PageError for title: Food miles
# PageError for title: Cement kiln
# PageError for title: Greta Thunberg
# PageError for title: ISO 14064
# PageError for title: Environmental science
# PageError for title: Blast furnace
# PageError for title: Oat milk
# PageError for title: Plug-in electric vehicle
# PageError for title: Bioenergy
# PageError for title: Wipro
# PageError for title: Environmentally friendly
# PageError for title: Plastic
# PageError for title: Gary Gensler
# PageError for title: Joe Biden
# PageError for title: Amtrak
# PageError for title: Carnivore diet
# PageError for title: Wildlife
# PageError for title: Gerald Durrell
# PageError for title: Pangolin
# PageError for title: Wild Life (Protection) Act, 1972
# PageError for title: Formosan black bear
# PageError for title: Maya Higa
# PageError for title: Mohammed Saleem
# PageError for title: Jeff Corwin
# PageError for title: Forestry in Pakistan
# PageError for title: Ex situ conservation
# PageError for title: Pallas's cat
# PageError for title: Forrest Galante
# Error for title: Project Elephant, retrying (1/3)
# PageError for title: Yorkshire Wildlife Park
# PageError for title: Gharial
# PageError for title: Laurance Rockefeller
# PageError for title: Whooping crane
# PageError for title: Marco Polo sheep
# PageError for title: Malayan tiger
# PageError for title: Tusk Trust
# PageError for title: Delia Owens
# PageError for title: Sandhill crane
# PageError for title: Department of Parks and Wildlife (Western Australia)
# PageError for title: Deforestation
# PageError for title: Red goral
# PageError for title: Socioeconomics
# PageError for title: White-bellied heron
# PageError for title: Hawaii mamo
# PageError for title: Little bustard
# PageError for title: Carolinian forest
# PageError for title: Logging
# Error for title: Invasive species in Mexico, retrying (1/3)
# PageError for title: Asian carp
# PageError for title: Nile perch
# PageError for title: Marionberry
# PageError for title: Lake Victoria
# PageError for title: List of invasive species in South Africa
# PageError for title: Calluna
# PageError for title: Red lionfish
# PageError for title: Electric ant
# PageError for title: Common myna
# PageError for title: Snakehead (fish)
# PageError for title: Prosopis
# PageError for title: Fire ant
# PageError for title: Rosa multiflora
# PageError for title: Conifer
# PageError for title: Ruddy duck
# PageError for title: Thrips
# PageError for title: Aloe vera
# PageError for title: Cane toad
# PageError for title: Bed bug
# PageError for title: Argentine ant
# PageError for title: Shola
# PageError for title: Sida acuta
# PageError for title: Brown rat
# PageError for title: Western Ghats
# PageError for title: High-Biodiversity Wilderness Area
# PageError for title: Eastern Arc Mountains
# PageError for title: Shola
# PageError for title: Indo-Pacific
# PageError for title: Benthic zone
# PageError for title: Southwest Australia
# PageError for title: Megadiverse countries
# PageError for title: Physalis
# PageError for title: Noongar
# PageError for title: Northeast India
# PageError for title: Honeyeater
# PageError for title: List of GIS data sources
# PageError for title: Department of Parks and Wildlife (Western Australia)
# PageError for title: Norman Myers
# PageError for title: Deforestation
# PageError for title: Bhutan
# PageError for title: Robert Engelman
# PageError for title: Nama (island)
# PageError for title: Pande Game Reserve
# PageError for title: Cape Town
# PageError for title: East Timor
# PageError for title: Pollination
# PageError for title: Almond
# PageError for title: Honey bee
# PageError for title: Conifer
# PageError for title: Community (ecology)
# PageError for title: Pumpkin
# PageError for title: Date palm
# PageError for title: St. Louis
# PageError for title: Argentine ant
# PageError for title: Common myna
# PageError for title: Ethereal wave
# PageError for title: Flea circus
# PageError for title: Directional selection
# PageError for title: Cereal
# PageError for title: Longan
# PageError for title: Red wattlebird
# PageError for title: Google Doodle
# PageError for title: Deforestation
# PageError for title: Organic farming
# PageError for title: Ozone
# PageError for title: List of domesticated animals
# PageError for title: Megabat
# PageError for title: New wave of British heavy metal
# PageError for title: Beta vulgaris
# PageError for title: Environmental degradation
# PageError for title: Southwest Australia
# PageError for title: Deforestation in Brazil
# PageError for title: Marine Life Protection Act
# PageError for title: Wu Chun
# PageError for title: BRTF
# PageError for title: Marine Protection, Research, and Sanctuaries Act of 1972
# PageError for title: Royal Marines
# PageError for title: Sunscreen
# PageError for title: TATA AIG
# PageError for title: Marinemap
# PageError for title: MRAP
# PageError for title: 42 Commando
# PageError for title: LAV-25
# PageError for title: Singlife
# PageError for title: Benthic zone
# PageError for title: Blue economy
# PageError for title: MARCOS
# PageError for title: Seabed
# PageError for title: Caribbean Sea
# PageError for title: Guam
# PageError for title: Septic tank
# PageError for title: Flak jacket
# PageError for title: Alexandra Cunha
# PageError for title: Right whale
# PageError for title: ISO 7010
# PageError for title: Mussel
# PageError for title: Giant sunfish
# PageError for title: Life on Mars
# PageError for title: Whale shark
# PageError for title: North Sea
# PageError for title: Blue whale
# PageError for title: Allstate
# PageError for title: Lili Taylor
# PageError for title: Charles Graner
# PageError for title: Sikorsky S-70
# PageError for title: Bull shark
# PageError for title: NFPA 70E
# PageError for title: Maldives
# PageError for title: Plastic bag
# PageError for title: Harbor seal
# PageError for title: Lucas Kunce
# PageError for title: Flatback sea turtle
# PageError for title: Sperm whale
# PageError for title: Megalodon
# PageError for title: Plastic
# PageError for title: Pollution
# PageError for title: Microplastics
# PageError for title: Plastic bag
# PageError for title: Pollution prevention
# PageError for title: Dianna Cohen
# PageError for title: LADbible Group
# PageError for title: Seabed
# PageError for title: Ecobricks
# PageError for title: Daily Mail
# PageError for title: River Thames
# PageError for title: Bioplastic
# PageError for title: Blue Planet II
# Error for title: The Ocean Cleanup, retrying (1/3)
# PageError for title: Earth Day
# PageError for title: James Quincey
# PageError for title: Charles J. Moore
# PageError for title: Liz Bonnin
# PageError for title: Jackson Browne
# PageError for title: French Frigate Shoals
# PageError for title: Jackson Hinkle
# PageError for title: Disposable cup
# PageError for title: Bonnie Wright
# PageError for title: World Economic Forum
# PageError for title: Miss Earth 2023
# PageError for title: Greenpeace USA
# PageError for title: Fionn Ferreira
# PageError for title: Cotton swab
# PageError for title: Our Planet
# PageError for title: 5 Gyres
# PageError for title: Plasticulture
# PageError for title: Roz Savage
# PageError for title: 7-Eleven
# PageError for title: Fashion
# PageError for title: Mandy Barker
# PageError for title: Abigail Barrows
# PageError for title: 49th G7 summit
# PageError for title: Belu (company)
# PageError for title: Tiza Mafira
# PageError for title: Lilly Platt
# PageError for title: Gary Gensler
# PageError for title: Island Saver
# PageError for title: Environment Act 2021
# PageError for title: Steve Daines
# PageError for title: Michael Kremer
# PageError for title: Dominic Thiem
# PageError for title: Plastic pipework
# PageError for title: Tearfund
# PageError for title: Environmental law
# PageError for title: Environmental health
# PageError for title: Biomedical waste
# PageError for title: Clean Air Act 1956
# PageError for title: 1939 St. Louis smog
# PageError for title: Environmental law
# PageError for title: Pollution
# PageError for title: Haze
# PageError for title: Toyota Prius (XW20)
# PageError for title: Wallow Fire
# PageError for title: Biomedical waste
# PageError for title: Cloud seeding
# PageError for title: Environmental health
# PageError for title: Ozone
# PageError for title: Inland Empire
# PageError for title: Grand Canyon
# PageError for title: Acid rain
# PageError for title: Chevrolet Corvair
# PageError for title: Incineration
# PageError for title: Domed city
# PageError for title: CityTrees
# PageError for title: Athens Metro
# PageError for title: Arvin, California

# %%
# Create the CSV from the DataFrame
env_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Environment.csv"
env_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
environment = pd.read_csv("./Data/Environment.csv")
environment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ### Technology

# %%
# Define the topics and subtopics
title = {
    'Technology': [
        'Emerging technologies', 'AI advancements', 'Bitcoin',
        'Blockchain applications', 'Quantum computing', '5G technology',
        'Virtual reality (VR) developments', 'Augmented reality (AR) trends', 'Internet of Things (IoT)',
        'Big data analytics', 'Cloud computing', 'Cybersecurity trends',
        'Biotechnology breakthroughs', 'Nanotechnology', 'Renewable energy technology',
        'Electric vehicles', 'Autonomous driving', 'Space exploration technology',
        'Robotics and automation', 'Wearable technology', 'Smart home devices',
        '3D printing applications', 'Artificial neural networks', 'Machine learning algorithms',
        'Digital currency trends', 'Fintech innovations', 'Smart cities',
        'Telemedicine and e-health', 'Sustainable tech solutions', 'Tech industry ethics',
        'Data privacy and protection', 'Social media technology', 'Tech startups and entrepreneurship',
        'E-commerce technology trends', 'Gaming technology advancements', 'Streaming media technology'
    ],
}


# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: Transhumanism
# PageError for title: Special Competitive Studies Project
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: 3D printing
# PageError for title: Wendell Wallach
# PageError for title: Daphne Koller
# PageError for title: SD-WAN
# PageError for title: Loitering munition
# PageError for title: Timeline of historic inventions
# PageError for title: Bioconvergence
# PageError for title: Vertical farming
# PageError for title: Society 5.0
# PageError for title: Superhuman
# PageError for title: Accenture
# PageError for title: Gavin Andresen
# PageError for title: 3CX
# PageError for title: Designer baby
# PageError for title: Anthony Dunne
# PageError for title: Upgrade
# PageError for title: Flying car
# PageError for title: Schmidt Futures
# Error for title: Bone ash, retrying (1/3)
# PageError for title: Nanoengineering
# PageError for title: Transrapid
# PageError for title: DevOps
# PageError for title: Metaliteracy
# PageError for title: Nick Bostrom
# PageError for title: Beggars in Spain
# PageError for title: AI boom
# PageError for title: ServiceNow
# PageError for title: Generative artificial intelligence
# PageError for title: Ai Weiwei
# PageError for title: Meta AI
# PageError for title: Roko's basilisk
# PageError for title: Deepfake
# PageError for title: Terah Lyons
# PageError for title: Dong Xian
# PageError for title: Eric Horvitz
# PageError for title: A.I. Insight forums
# PageError for title: Nvidia GTC
# PageError for title: Neuralink
# PageError for title: Song-Chun Zhu
# PageError for title: IP camera
# PageError for title: Amy Karle
# PageError for title: XPeng
# PageError for title: Amazon Alexa
# PageError for title: Digital literacy
# PageError for title: Project Jupyter
# PageError for title: Arms race
# PageError for title: Civilization VI
# PageError for title: Moore's law
# PageError for title: Façade (video game)
# PageError for title: Predictive analytics
# PageError for title: Camera
# PageError for title: Meta Quest 3
# PageError for title: Civilization IV
# Error for title: Hyperreality, retrying (1/3)
# PageError for title: Daphne Koller
# PageError for title: Bill Gates
# PageError for title: The Beatles
# PageError for title: 49th G7 summit
# PageError for title: Todd Boehly
# PageError for title: IPhone 11 Pro
# PageError for title: Al Gore
# PageError for title: Andy Warhol
# PageError for title: Judea Pearl
# PageError for title: Gears of War
# PageError for title: Apple Inc.
# PageError for title: Genie Engine
# PageError for title: Cyberpunk 2077
# PageError for title: Boneworks
# PageError for title: Ethics
# PageError for title: Industrial Revolution
# PageError for title: 2023 deaths in the United States
# PageError for title: Fairy Tail (season 9)
# PageError for title: Turing Award
# PageError for title: Saeed Amidi
# PageError for title: IRacing
# PageError for title: Computer vision
# PageError for title: Civilization (video game)
# PageError for title: Agriculture in India
# PageError for title: Hanson Robotics
# PageError for title: The Accidental Billionaires
# PageError for title: Mikoyan MiG-35
# PageError for title: Pangolin
# PageError for title: Eve Online
# PageError for title: Lynne Parker
# PageError for title: Superhuman
# PageError for title: Paul Allen
# PageError for title: Janet Foutty
# PageError for title: Unreal Engine
# PageError for title: Hulk
# PageError for title: Satoshi Nakamoto
# PageError for title: Dark web
# PageError for title: Bitcoin ATM
# PageError for title: Coinbase
# PageError for title: James Zhong
# PageError for title: Tim Draper
# PageError for title: Brock Pierce
# PageError for title: Dogecoin
# PageError for title: Binance
# PageError for title: Cash App
# PageError for title: Gavin Andresen
# PageError for title: CamSoda
# PageError for title: Bitcoin Unlimited
# PageError for title: Darknet market
# PageError for title: Bitconnect
# PageError for title: Non-fungible token
# PageError for title: BTCC (company)
# PageError for title: Coinme
# PageError for title: Colored Coins
# PageError for title: Bitcoin Core
# PageError for title: Testnet
# PageError for title: USD Coin
# PageError for title: Ark Invest
# PageError for title: Xapo
# PageError for title: FTX
# PageError for title: Celsius Network
# PageError for title: BitPay
# PageError for title: EToro
# PageError for title: Bitpanda
# PageError for title: Cryptoeconomics
# PageError for title: OKX
# PageError for title: Namecheap
# PageError for title: Uniswap
# PageError for title: Regression theorem
# PageError for title: Charlie Munger
# PageError for title: Auroracoin
# PageError for title: Pantera Capital
# PageError for title: Mining pool
# PageError for title: Elon Musk
# PageError for title: Wikimedia Foundation
# PageError for title: Central African Republic
# PageError for title: The Big Bang Theory (season 11)
# PageError for title: 2014 St. Petersburg Bowl
# PageError for title: Chia (cryptocurrency)
# PageError for title: PlusToken
# PageError for title: Worldcoin
# PageError for title: Li Xiaolai
# PageError for title: Axie Infinity
# PageError for title: LBRY
# PageError for title: Gabe Amo
# PageError for title: Vertcoin
# PageError for title: WhatsApp
# PageError for title: Xi Jinping
# PageError for title: The DAO
# PageError for title: Wise (company)
# PageError for title: PayPal
# PageError for title: Starbucks
# PageError for title: Doxing
# PageError for title: Jordan Belfort
# PageError for title: Anna Sorokin
# PageError for title: Ben McKenzie
# PageError for title: CryptoPunks
# PageError for title: Joe Manchin
# PageError for title: Bill Gates
# PageError for title: Sam Bankman-Fried
# PageError for title: Tor (network)
# PageError for title: John McAfee
# PageError for title: Lockbit
# PageError for title: Filecoin
# PageError for title: Chia Network
# PageError for title: Zachery Ty Bryan
# PageError for title: NEO (cryptocurrency)
# PageError for title: Black market
# PageError for title: Bybit
# PageError for title: Coinmarketcap
# PageError for title: Matt Damon
# PageError for title: Mark Consuelos
# PageError for title: Tony Hawk
# PageError for title: Eric Adams
# PageError for title: IOTA (technology)
# PageError for title: Currency symbol
# PageError for title: Peter Thiel
# PageError for title: Payoneer
# PageError for title: Nubank
# PageError for title: Brandon Moreno
# PageError for title: OpenBSD
# PageError for title: Boracay
# PageError for title: The Simpsons (season 34)
# PageError for title: United States v. Gratkowski
# PageError for title: Reid Hoffman
# PageError for title: Ron Paul
# PageError for title: Liberland
# PageError for title: Ryan Salame
# PageError for title: OneRepublic
# PageError for title: Jared Polis
# PageError for title: Polygon (blockchain)
# PageError for title: Testnet
# PageError for title: Non-fungible token
# PageError for title: IOTA (technology)
# PageError for title: Filecoin
# PageError for title: NEO (cryptocurrency)
# PageError for title: Colored Coins
# PageError for title: The DAO
# PageError for title: Gate.io
# PageError for title: LBRY
# PageError for title: Decentralized web
# PageError for title: Uniswap
# PageError for title: Samsung SDS
# PageError for title: Microcontroller
# PageError for title: Binance
# PageError for title: Satoshi Nakamoto
# PageError for title: Coinbase
# PageError for title: CryptoPunks
# PageError for title: Crypto.com
# PageError for title: EToro
# PageError for title: Dogecoin
# PageError for title: USD Coin
# PageError for title: Axie Infinity
# PageError for title: Worldcoin
# PageError for title: Justin Kan
# PageError for title: David Chaum
# PageError for title: SafeMoon
# PageError for title: Mark Ginzburg
# PageError for title: Infosys
# PageError for title: Sergey Brin
# PageError for title: Michael Mainelli
# PageError for title: Astar Network
# PageError for title: Cryptoeconomics
# PageError for title: Mining pool
# PageError for title: OKX
# PageError for title: Wolfram Mathematica
# PageError for title: Pegasystems
# PageError for title: Xapo
# PageError for title: BTCC (company)
# PageError for title: Iris recognition
# PageError for title: Unisys
# PageError for title: EPAM Systems
# PageError for title: Topcoder
# PageError for title: FTX
# PageError for title: Metaverse
# PageError for title: MobileCoin
# PageError for title: Peter Chen
# PageError for title: Deepfake
# PageError for title: Glenn Parry
# PageError for title: Darknet market
# PageError for title: Auroracoin
# PageError for title: Bitpanda
# PageError for title: ETH Zurich
# PageError for title: Starbucks
# PageError for title: Cash App
# PageError for title: Daniel Harple
# PageError for title: Ark Invest
# PageError for title: MeWe
# PageError for title: Vertcoin
# PageError for title: VRChat
# PageError for title: Chia (cryptocurrency)
# PageError for title: Bithumb
# PageError for title: ING Group
# PageError for title: Bitconnect
# PageError for title: Bloom filter
# PageError for title: Walmart
# PageError for title: Governance
# PageError for title: 256-bit computing
# PageError for title: Larry Sanger
# PageError for title: Proton Mail
# PageError for title: Qubit
# PageError for title: Scott Aaronson
# Error for title: Grover's algorithm, retrying (1/3)
# PageError for title: Threshold theorem
# PageError for title: Transmon
# PageError for title: Isaac Chuang
# PageError for title: Google
# PageError for title: Andrea Morello
# PageError for title: QC
# PageError for title: Ion trap
# PageError for title: Pauli exclusion principle
# PageError for title: Computer
# PageError for title: John M. Martinis
# PageError for title: Stabilizer code
# PageError for title: Merritt Moore
# PageError for title: One-time pad
# PageError for title: Double-slit experiment
# PageError for title: Hyperfine structure
# PageError for title: Chris Ferrie
# PageError for title: Emanuele Dalla Torre
# PageError for title: Quantum foundations
# PageError for title: 5G NR
# PageError for title: 5G NR frequency bands
# PageError for title: Samsung Galaxy A14
# PageError for title: LTE Advanced
# PageError for title: Cristiano Amon
# PageError for title: Samsung Galaxy A73 5G
# PageError for title: Sacha Stone
# PageError for title: Ken Howery
# PageError for title: Rogers Wireless
# PageError for title: IMT-2000
# PageError for title: OnePlus 8
# PageError for title: 5GBioShield
# PageError for title: Voice over NR
# PageError for title: Marvell Technology
# PageError for title: Samsung Galaxy S10
# PageError for title: BMW iX
# PageError for title: Samsung Galaxy S22
# PageError for title: Sony Ericsson T610
# PageError for title: John Cornyn
# PageError for title: SiTime
# PageError for title: Pixel 4a
# PageError for title: Next Generation 112
# PageError for title: IQOO
# PageError for title: IPhone 12
# PageError for title: Cellnex
# PageError for title: Apple Inc.
# PageError for title: IPhone SE (3rd generation)
# PageError for title: Xiaomi
# PageError for title: Lava International
# PageError for title: Telcel
# PageError for title: Samsung Galaxy Note 10
# PageError for title: Cradlepoint
# PageError for title: Samsung Galaxy S21
# PageError for title: Motorola Razr
# PageError for title: Infinix Mobile
# PageError for title: Samsung Galaxy Note 20
# PageError for title: OnePlus
# PageError for title: Samsung Galaxy S series
# PageError for title: Xiaomi Mi 11
# PageError for title: Xilinx
# PageError for title: 7 nm process
# PageError for title: Adreno
# PageError for title: OnePlus 7
# PageError for title: 2020 NASCAR Cup Series
# PageError for title: Redington Group
# PageError for title: IIT Hyderabad
# PageError for title: Moto G (2022)
# PageError for title: IPhone 12 Pro
# PageError for title: FRMCS
# PageError for title: Hutch (Sri Lanka)
# PageError for title: Alibaba Group
# PageError for title: ESIM
# PageError for title: Redmi K30
# PageError for title: Free Mobile
# PageError for title: BBK Electronics
# PageError for title: Foxconn
# PageError for title: ARM Cortex-A76
# PageError for title: Nvidia GTC
# PageError for title: Poco X3
# PageError for title: HMD Global
# PageError for title: Entity List
# PageError for title: OnePlus 7T
# PageError for title: Redmi
# PageError for title: Wireless WAN
# PageError for title: Virtual reality
# PageError for title: Ariane 5
# PageError for title: SK Telecom
# PageError for title: Mercedes-Benz W140
# PageError for title: OnePlus 6T
# PageError for title: OnePlus 5T
# PageError for title: Moto G (2021)
# PageError for title: Rohde & Schwarz
# PageError for title: Mike Sievert
# PageError for title: Airplane mode
# PageError for title: Amitava Ghosh
# PageError for title: Virtual reality
# PageError for title: Metaverse
# PageError for title: Sniper Elite VR
# PageError for title: VRChat
# PageError for title: PlayStation VR2
# PageError for title: Immersive learning
# PageError for title: Iron Man VR
# PageError for title: L.A. Noire
# PageError for title: I Expect You to Die
# PageError for title: Reality
# PageError for title: Moss: Book II
# PageError for title: Superhot
# PageError for title: The Persistence
# PageError for title: The Lab (video game)
# PageError for title: Schell Games
# PageError for title: WebXR
# PageError for title: Jaron Lanier
# PageError for title: Unreal Engine
# PageError for title: Nintendo Labo
# PageError for title: Bravo Team
# PageError for title: Virtual sex
# PageError for title: Boneworks
# PageError for title: Battlezone (2016 video game)
# PageError for title: Chronos (2016 video game)
# PageError for title: Squanch Games
# PageError for title: Beat Saber
# PageError for title: Trover Saves the Universe
# PageError for title: Driveclub
# PageError for title: Stormland (video game)
# PageError for title: Wired glove
# PageError for title: DiSTI
# PageError for title: Moss (video game)
# PageError for title: Tentacular (video game)
# PageError for title: Fallout 4
# PageError for title: Archangel (2017 video game)
# PageError for title: Among Us
# PageError for title: The Climb (video game)
# PageError for title: Hitman 3
# PageError for title: The Light Brigade (video game)
# PageError for title: Unity Technologies
# PageError for title: Obduction (video game)
# PageError for title: Phasmophobia (video game)
# PageError for title: John Wick
# PageError for title: Polybius (2017 video game)
# PageError for title: Mario Kart
# PageError for title: Jurassic Park video games
# PageError for title: STX Entertainment
# PageError for title: WebAR
# PageError for title: Smash Drums (video game)
# PageError for title: Ian McDowall
# PageError for title: John Carmack
# PageError for title: SN Systems
# PageError for title: 2016 in video games
# PageError for title: XHamster
# PageError for title: Canon Inc.
# PageError for title: Rez (video game)
# PageError for title: Five Nights at Freddy's
# PageError for title: Himax
# PageError for title: The Forest (video game)
# PageError for title: The Shore (video game)
# PageError for title: Canadian Film Centre
# PageError for title: Virtual reality
# PageError for title: Metaverse
# PageError for title: Giga Pet
# PageError for title: Computer-generated imagery
# PageError for title: Beatie Wolfe
# PageError for title: Moss (video game)
# PageError for title: IOS 15
# PageError for title: Unity Technologies
# PageError for title: Immersive learning
# PageError for title: Canon Inc.
# PageError for title: Canada
# PageError for title: Five Nights at Freddy's
# PageError for title: Full Sail University
# PageError for title: MicroLED
# PageError for title: Computer vision
# PageError for title: Avatar (2009 film)
# PageError for title: Apple Inc.
# PageError for title: Baidu
# PageError for title: Adderall
# PageError for title: White people
# PageError for title: List of YouTubers
# PageError for title: Creativity
# PageError for title: Blinding Lights
# PageError for title: Hololive Production
# PageError for title: Rodney Mullen
# PageError for title: Deism
# PageError for title: Janet Jackson
# PageError for title: Contact lens
# PageError for title: Spanish flu
# PageError for title: BanG Dream!
# PageError for title: JSON-LD
# PageError for title: Alder Lake
# PageError for title: AliOS
# PageError for title: Peter Chen
# PageError for title: VxWorks
# PageError for title: Windows IoT
# PageError for title: Voice over NR
# PageError for title: Fog computing
# PageError for title: Moxa Technologies
# PageError for title: IoT Forensics
# PageError for title: Nvidia GTC
# PageError for title: IEEE 802.11ah
# PageError for title: ARC (processor)
# PageError for title: Samsung SDS
# PageError for title: IOTA (technology)
# PageError for title: ESIM
# PageError for title: Philippe Kahn
# PageError for title: Operational technology
# PageError for title: Semtech
# PageError for title: Software AG
# PageError for title: Cellnex
# PageError for title: Itron
# PageError for title: Jeremy Rifkin
# PageError for title: OpenPicus
# PageError for title: Arm Holdings
# PageError for title: ESP8266
# PageError for title: B+ tree
# PageError for title: RISC-V
# PageError for title: Jeff Merritt
# PageError for title: BT Group
# PageError for title: LittleBits
# PageError for title: Sanjay Sarma
# PageError for title: Cary, North Carolina
# PageError for title: AlphaLab
# PageError for title: Telkom Indonesia
# Error for title: Hajime (malware), retrying (1/3)
# PageError for title: Xilinx
# PageError for title: Banana Pi
# PageError for title: Internet universality
# PageError for title: Next Generation 112
# PageError for title: BT Research
# PageError for title: Prescriptive analytics
# PageError for title: Software AG
# PageError for title: Predictive analytics
# PageError for title: Sisense
# PageError for title: Augmented Analytics
# PageError for title: Lex Fridman
# PageError for title: Data center
# PageError for title: DevOps
# PageError for title: SAP HANA
# PageError for title: Walmart
# PageError for title: Sqrrl
# PageError for title: Accenture
# PageError for title: Samsung SDS
# PageError for title: Sapphire Rapids
# PageError for title: StatSoft
# PageError for title: Reiwa era
# PageError for title: FICO
# PageError for title: Marico
# PageError for title: Moveworks
# PageError for title: Thales Group
# PageError for title: Wipro
# PageError for title: MariaDB
# PageError for title: Logi Analytics
# PageError for title: Unnormalized form
# PageError for title: Visual analytics
# PageError for title: Databricks
# PageError for title: Data mining
# PageError for title: Mitochondrial DNA
# PageError for title: Civic technology
# PageError for title: Greenplum
# PageError for title: IKANOW
# PageError for title: Lauren Sallan
# PageError for title: TMA Solutions
# PageError for title: Narus
# PageError for title: Civis Analytics
# PageError for title: Zero-COVID
# PageError for title: Amazon Kinesis
# PageError for title: IMC Technologies
# PageError for title: Cloudant
# PageError for title: IQ Analytics
# PageError for title: Internet universality
# PageError for title: Amit Sheth
# PageError for title: Cambridge Analytica
# PageError for title: Chen Chi-mai
# PageError for title: NTT Data
# PageError for title: Kdb+
# PageError for title: Big Bang
# PageError for title: Cloud-native computing
# PageError for title: Fog computing
# PageError for title: Amazon Web Services
# PageError for title: Green computing
# PageError for title: Centralized computing
# PageError for title: Jeff Bezos
# PageError for title: Alibaba Group
# PageError for title: OwnCloud
# PageError for title: Multicloud
# PageError for title: Stackdriver
# PageError for title: ShareFile
# PageError for title: Wipro
# PageError for title: Disk image
# PageError for title: Google
# PageError for title: Dew computing
# PageError for title: Gcore
# PageError for title: Le.com
# PageError for title: OpenAPS
# PageError for title: ServiceNow
# PageError for title: Andy Jassy
# PageError for title: AWS Lambda
# PageError for title: Mirantis
# PageError for title: FedRAMP
# PageError for title: Cloudlet
# PageError for title: Veeva Systems
# PageError for title: Arista Networks
# PageError for title: CloudZero
# PageError for title: CloudBees
# PageError for title: .xxx
# PageError for title: PRISM
# PageError for title: CNF
# PageError for title: Mindtree
# PageError for title: AppDynamics
# PageError for title: Amazon Kinesis
# PageError for title: Microservices
# PageError for title: Taobao
# PageError for title: OpenDNS
# PageError for title: Windows Server 2016
# PageError for title: Wei Yen
# PageError for title: Cloudant
# PageError for title: Onshape
# PageError for title: Freshworks
# PageError for title: Xbox Cloud Gaming
# PageError for title: GitHub
# PageError for title: McAfee
# PageError for title: Naftali Bennett
# PageError for title: Bill Conner
# PageError for title: Clario Tech
# PageError for title: AnyDesk
# PageError for title: ESET
# PageError for title: ChatGPT
# PageError for title: Moxa Technologies
# PageError for title: John McAfee
# PageError for title: Dark web
# PageError for title: Unisys
# PageError for title: Shein
# PageError for title: WhatsApp
# PageError for title: Sci-Hub
# PageError for title: Generation Z in the United States
# PageError for title: Deepfake
# PageError for title: Xi Jinping
# PageError for title: Zerologon
# PageError for title: McAfee
# PageError for title: Accounting
# PageError for title: Tinder (app)
# PageError for title: Sourcegraph
# PageError for title: The New York Times
# PageError for title: Anti-vaccine activism
# PageError for title: Stuxnet
# PageError for title: Mike Lindell
# PageError for title: Xiaomi
# PageError for title: Sidney Powell
# PageError for title: Abdul Mutalib
# PageError for title: Antivirus software
# PageError for title: United Airlines
# PageError for title: 2023 in American television
# PageError for title: Voice over IP
# PageError for title: SIM card
# PageError for title: Machine learning
# PageError for title: Mike Pence
# PageError for title: Costa del Sol
# PageError for title: Fake news
# PageError for title: Electronic discovery
# PageError for title: Darknet market
# PageError for title: ByteDance
# PageError for title: Presidency of Barack Obama
# PageError for title: Weibo
# PageError for title: Conficker
# PageError for title: Newsmax
# PageError for title: HMD Global
# PageError for title: Apax Partners
# PageError for title: Bioterrorism
# PageError for title: Techfest
# PageError for title: Impact of the COVID-19 pandemic on international relations
# PageError for title: Robert S. Langer
# PageError for title: Bill Maris
# PageError for title: Tom Hiddleston
# PageError for title: James Richman
# PageError for title: Dean Kamen
# PageError for title: Anna Faris
# PageError for title: Jeff Bezos
# PageError for title: Suntory
# PageError for title: Bluebird bio
# PageError for title: Moderna
# PageError for title: Kite Pharma
# PageError for title: Neil Young
# PageError for title: Joshua Boger
# PageError for title: Harvey Prize
# PageError for title: Kary Mullis
# PageError for title: Lee Je-hoon
# PageError for title: Organic farming
# PageError for title: Frederick Sanger
# PageError for title: Edward Boyden
# PageError for title: Transhumanism
# PageError for title: Fermentation
# PageError for title: Yuri Milner
# PageError for title: Louis Pasteur
# PageError for title: Pig
# PageError for title: Timeline of historic inventions
# PageError for title: Theranos
# PageError for title: Addgene
# PageError for title: Density functional theory
# PageError for title: Fine chemical
# PageError for title: Edward Jenner
# PageError for title: Bioplastic
# PageError for title: Tau protein
# PageError for title: Discovery science
# PageError for title: SRI International
# PageError for title: DuPont
# PageError for title: Northern California
# PageError for title: Stony Brook University
# PageError for title: Alexander Fleming
# PageError for title: Moore's law
# PageError for title: Robert Fraley
# PageError for title: Supramolecular chemistry
# PageError for title: COVID-19 vaccine
# PageError for title: 2300 AD
# PageError for title: Jay Inslee
# PageError for title: Metalloid
# PageError for title: Sila Nanotechnologies
# PageError for title: Vitamin B12
# Error for title: Nanobiotechnology, retrying (1/3)
# PageError for title: Nanobiotechnology
# PageError for title: Holliday junction
# PageError for title: Nanoengineering
# PageError for title: Water
# PageError for title: Ethics
# PageError for title: University of Alberta
# PageError for title: Cyberpunk 2077
# PageError for title: Moore's law
# PageError for title: Energy density
# PageError for title: Transhumanism
# PageError for title: Central Asia
# PageError for title: Iron Man
# PageError for title: ASML Holding
# PageError for title: Northwestern University
# PageError for title: Outlast
# PageError for title: Hedonism
# PageError for title: Michael Faraday
# PageError for title: EasyJet
# PageError for title: IIT Bombay
# PageError for title: Crysis 3
# PageError for title: Alfred Pennyworth
# PageError for title: Transistor
# PageError for title: Environmental issues
# PageError for title: Moon Knight
# PageError for title: LCN
# PageError for title: Fullerene
# PageError for title: Discovery of the neutron
# PageError for title: Infinity Stones
# PageError for title: Nano
# PageError for title: Young's modulus
# PageError for title: Beast (Marvel Comics)
# PageError for title: Megastructure
# PageError for title: Life on Mars
# PageError for title: Stanisław Lem
# PageError for title: Non-renewable resource
# PageError for title: Environmental technology
# PageError for title: Greencells Group
# PageError for title: Hanergy
# PageError for title: Renewable Energy Programme
# PageError for title: Breakthrough Energy
# PageError for title: Forum Energy Technologies
# PageError for title: Sergey Brin
# PageError for title: ESB Group
# PageError for title: Sustainable Development Goal 7
# PageError for title: Power-to-X
# PageError for title: Energy in Chile
# PageError for title: Desertec
# PageError for title: Off-the-grid
# PageError for title: Robert Swan
# PageError for title: Bill Gates
# PageError for title: Bioenergy
# PageError for title: Tom Steyer
# PageError for title: TotalEnergies
# PageError for title: Energy density
# PageError for title: Navarre
# PageError for title: Plug-in electric vehicle
# PageError for title: Charging station
# PageError for title: Ola Electric
# PageError for title: Micromobility
# PageError for title: Ford Motor Company
# PageError for title: Rivian
# PageError for title: Jidu Auto
# PageError for title: B-segment
# PageError for title: BorgWarner
# PageError for title: Ford Focus Electric
# PageError for title: Battery charger
# PageError for title: Electricity
# PageError for title: JAC Motors
# PageError for title: Porsche
# PageError for title: Mia electric
# PageError for title: Iveco
# PageError for title: Stellantis
# PageError for title: Electric tractor
# PageError for title: BYD e6
# PageError for title: Gridserve
# PageError for title: Tesla Model 3
# PageError for title: Electrify America
# PageError for title: Common Modular Platform
# PageError for title: Magna International
# PageError for title: Navistar
# PageError for title: Nio Inc.
# PageError for title: Li Auto
# PageError for title: AMC Pacer
# PageError for title: Tesla Model Y
# PageError for title: Chevrolet Volt
# PageError for title: Volvo XC40
# PageError for title: Nissan Leaf
# PageError for title: BP Pulse
# PageError for title: Shanghai Maple
# PageError for title: BMW i
# PageError for title: Hyundai Ioniq
# PageError for title: XPeng
# PageError for title: Nio ET7
# PageError for title: XPeng
# PageError for title: Nio Inc.
# PageError for title: WeRide
# PageError for title: Robotaxi
# PageError for title: Baidu
# PageError for title: Pony.ai
# PageError for title: Aptiv
# PageError for title: Argo AI
# PageError for title: Xiaomi
# PageError for title: Operational design domain
# PageError for title: BMW iX
# PageError for title: Continental AG
# PageError for title: Cadillac Lyriq
# PageError for title: TuSimple
# PageError for title: BMW i4
# PageError for title: Mercedes-Benz E-Class
# PageError for title: Foxconn
# PageError for title: Dreame Technology
# PageError for title: Mercedes-Benz S-Class (W223)
# PageError for title: Intel
# PageError for title: Bolt (company)
# PageError for title: Drive.ai
# PageError for title: Mercedes-Benz S-Class (W222)
# PageError for title: AWF8F35
# PageError for title: ETH Zurich
# PageError for title: William Li
# PageError for title: Naver Corporation
# PageError for title: Rivian R1T
# PageError for title: Leapmotor
# PageError for title: Computer vision
# PageError for title: Volkswagen Golf Mk8

# %%
# Create the CSV from the DataFrame
tech_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Technology.csv"
tech_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Technology = pd.read_csv("./Data/Technology.csv")
Technology.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Economy

# %%
# Define the topics and subtopics
title = {
    'Economy': [
        'Stock market performance', 'Job markets', 'Cryptocurrency trends',
        'Global economic growth', 'Inflation rates', 'Unemployment trends',
        'Foreign exchange markets', 'Commodity prices', 'Real estate market trends',
        'Central bank policies', 'Fiscal policy', 'Monetary policy',
        'Economic impacts of COVID-19', 'E-commerce growth', 'Gig economy',
        'Trade wars and tariffs', 'Emerging market economies', 'Economic inequality',
        'Sustainable economic development', 'Consumer spending trends', 'Retail industry analysis',
        'Technology impact on economy', 'Green economy', 'Economic forecasting',
        'Business cycle analysis', 'Supply chain disruptions', 'Labor market dynamics',
        'Global investment trends', 'Financial regulation', 'Public debt and deficits',
        'Entrepreneurship trends', 'Venture capital markets', 'Corporate mergers and acquisitions',
        'Economic indicators', 'Energy market dynamics', 'Healthcare economics'
    ],
}

# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: S&P 500
# PageError for title: Russell 3000 Index
# PageError for title: Russell 1000 Index
# PageError for title: Nasdaq-100
# PageError for title: Danone
# PageError for title: Abnormal return
# PageError for title: ISO 9000
# PageError for title: KOSPI
# PageError for title: Nifty Fifty
# PageError for title: Wilshire 5000
# PageError for title: CAC 40
# PageError for title: Money market
# PageError for title: P/B ratio
# PageError for title: Dow Jones
# PageError for title: Russell 2500 Index
# PageError for title: Rights issue
# PageError for title: EURO STOXX 50
# PageError for title: S&P 600
# PageError for title: PTC India
# PageError for title: AEX index
# PageError for title: Jerome Powell
# PageError for title: Jordan Belfort
# PageError for title: Hero MotoCorp
# PageError for title: Hedge fund
# PageError for title: Smith & Wesson M&P15
# PageError for title: PSI-20
# PageError for title: Ray Dalio
# PageError for title: Bill Ackman
# PageError for title: Amer Sports
# PageError for title: Maxar Technologies
# PageError for title: Capitalism
# PageError for title: Inventory turnover
# PageError for title: Walmart
# PageError for title: Enron
# PageError for title: LiveChat Software
# PageError for title: Robert J. Shiller
# PageError for title: List of S&P 400 companies
# PageError for title: Business valuation
# PageError for title: Shutterstock
# PageError for title: Marc Chaikin
# PageError for title: Enron scandal
# PageError for title: Black market
# PageError for title: Financial planner
# PageError for title: McAfee
# PageError for title: ASRock
# PageError for title: Mopar
# PageError for title: EDreams
# PageError for title: Resideo
# PageError for title: GameStop
# PageError for title: Economy of China
# PageError for title: Dodge Charger
# PageError for title: Mitsubishi Starion
# PageError for title: Honda CR-X
# PageError for title: Sharpe ratio
# PageError for title: Economics Job Market Rumors
# PageError for title: Steve Jobs
# PageError for title: Nonfarm payrolls
# PageError for title: Flea market
# PageError for title: Quiet cutting
# PageError for title: Early 2000s recession
# PageError for title: Michael Spence
# PageError for title: Deseret Industries
# Error for title: Two-sided market, retrying (1/3)
# PageError for title: Financial Times
# PageError for title: Wegmans
# PageError for title: Upwork
# PageError for title: Economy of Canada
# PageError for title: Black market
# PageError for title: Inland Empire
# PageError for title: Economic migrant
# PageError for title: Capitalism
# PageError for title: Underemployment
# PageError for title: Apple Inc.
# PageError for title: Walmart
# PageError for title: Phyllis (TV series)
# PageError for title: David Dorn
# PageError for title: Youth unemployment
# PageError for title: Ant tribe
# PageError for title: Joachim Merz
# PageError for title: Mixed economy
# PageError for title: Unemployment in the United Kingdom
# PageError for title: Terah Lyons
# PageError for title: Safeway
# PageError for title: Deskilling
# PageError for title: Tom Joyner
# PageError for title: CHE University Ranking
# PageError for title: DPG Media
# PageError for title: Offshoring
# PageError for title: Bryan Caplan
# PageError for title: Mission Istaanbul
# PageError for title: Dirty Jobs
# PageError for title: Google
# PageError for title: English studies
# PageError for title: 2020 stock market crash
# PageError for title: Harshad Mehta
# PageError for title: Neijuan
# PageError for title: HSBC
# PageError for title: The Book Job
# PageError for title: Jason Statham
# PageError for title: Deliveroo
# PageError for title: Ray Dalio
# PageError for title: Dogecoin
# PageError for title: Jordan Belfort
# PageError for title: Cash App
# PageError for title: SoFi
# PageError for title: Save the Kids token
# PageError for title: SafeMoon
# PageError for title: Squid Game
# PageError for title: John McAfee
# PageError for title: Trainwreckstv
# PageError for title: Graphics card
# PageError for title: Shiba Inu
# PageError for title: ChatGPT
# PageError for title: Darknet market
# PageError for title: IShowSpeed
# PageError for title: Dark web
# PageError for title: WhatsApp
# PageError for title: Data center
# PageError for title: ASRock
# PageError for title: Veem
# PageError for title: Matt Damon
# PageError for title: Elon Musk
# PageError for title: Signal (software)
# PageError for title: New York City
# PageError for title: Logan Paul
# PageError for title: ESET
# PageError for title: Xi Jinping
# PageError for title: Industrial Revolution
# PageError for title: Metaverse
# PageError for title: Nyan Cat
# PageError for title: Dedollarisation
# PageError for title: Soulja Boy
# PageError for title: Reserve currency
# PageError for title: Riot Games
# PageError for title: Jim Breyer
# PageError for title: Peter Thiel
# PageError for title: Central African Republic
# PageError for title: VisualPolitik
# PageError for title: Robert J. Shiller
# PageError for title: One-time pad
# PageError for title: Jeremy Liew
# PageError for title: 2022 in the United States
# PageError for title: SARS-CoV-2 Omicron variant
# PageError for title: Techfest
# PageError for title: George Selgin
# PageError for title: 2020 stock market crash
# PageError for title: 2021 in China
# PageError for title: Impact of the COVID-19 pandemic on social media
# PageError for title: Green growth
# PageError for title: Sustainable Development Goal 8
# PageError for title: World Economic Forum
# PageError for title: Blue economy
# PageError for title: Great Reset
# PageError for title: Population growth
# PageError for title: Economy of China
# PageError for title: Keyu Jin
# PageError for title: Industrial Revolution
# PageError for title: Prosperity
# PageError for title: Development economics
# PageError for title: Economy of Singapore
# PageError for title: Business cycle
# PageError for title: Capitalism
# PageError for title: Club of Rome
# PageError for title: Economy of Canada
# PageError for title: City
# PageError for title: Socioeconomics
# PageError for title: Dependency theory
# PageError for title: Great Divergence
# PageError for title: Jason Hickel
# PageError for title: Economic impact of the COVID-19 pandemic
# PageError for title: Environmental degradation
# PageError for title: MEDays
# PageError for title: Danny Quah
# PageError for title: International economics
# PageError for title: Economic impact of the COVID-19 pandemic in India
# PageError for title: Water scarcity
# PageError for title: Ray Dalio
# PageError for title: Raghuram Rajan
# PageError for title: Horasis
# PageError for title: David Criswell
# PageError for title: China
# PageError for title: Agriculture in India
# PageError for title: Inflation
# PageError for title: Turkish lira
# PageError for title: Purchasing power parity
# PageError for title: Hungary and the euro
# Error for title: Euro convergence criteria, retrying (1/3)
# Error for title: Euro convergence criteria, retrying (2/3)
# PageError for title: Economy of China
# PageError for title: Economy of Uzbekistan
# PageError for title: Dogecoin
# PageError for title: Caracas
# PageError for title: No Name (brand)
# Error for title: Macroeconomic policy instruments, retrying (1/3)
# PageError for title: Steve Hanke
# PageError for title: Economy of Canada
# PageError for title: Anthony Eden
# PageError for title: Birth rate
# PageError for title: Jerome Powell
# PageError for title: 1986 State of the Union Address
# PageError for title: Zhu Rongji
# PageError for title: Japanese yen
# PageError for title: Progressive tax
# PageError for title: Janet Yellen
# PageError for title: Indira Gandhi
# PageError for title: Youth unemployment
# PageError for title: Inflation
# PageError for title: Unemployment in the United Kingdom
# PageError for title: Centre for Monitoring Indian Economy
# PageError for title: Edward Heath
# PageError for title: Google Search
# PageError for title: New Deal
# PageError for title: Business cycle
# PageError for title: State of Palestine
# PageError for title: White South Africans
# PageError for title: Rishi Sunak
# PageError for title: Economy of Singapore
# PageError for title: Mechanised agriculture
# PageError for title: Hamas
# PageError for title: Belize
# PageError for title: Civilian noninstitutional population
# PageError for title: Janet Yellen
# PageError for title: Elon Musk
# PageError for title: Generation X
# PageError for title: Baby boomers
# PageError for title: Norway
# PageError for title: Italy
# PageError for title: Leeds
# PageError for title: Birth rate
# PageError for title: Progressive Era
# PageError for title: Inland Empire
# PageError for title: Kenya
# PageError for title: Economy of Colombia
# PageError for title: 2022 Uttar Pradesh Legislative Assembly election
# PageError for title: John F. Kennedy
# PageError for title: Romania
# PageError for title: Jimmy Carter
# PageError for title: Greenland
# PageError for title: Gilded Age
# PageError for title: Valimai
# PageError for title: Washington, D.C.
# PageError for title: Atlantis, South Africa
# PageError for title: Panic of 1893
# PageError for title: Cape Town
# PageError for title: The End of Work
# PageError for title: Iraq War
# PageError for title: Gender inequality
# PageError for title: Skinhead
# PageError for title: Cary Grant
# PageError for title: Latvia
# PageError for title: Breaking Bad
# PageError for title: Political views of Generation Z
# PageError for title: Market maker
# PageError for title: CMC Markets
# PageError for title: Japanese yen
# PageError for title: NEX Group
# PageError for title: CLS Group
# PageError for title: Money market
# PageError for title: Spahn tax
# PageError for title: Nonfarm payrolls
# PageError for title: FXDD
# PageError for title: Purchasing power parity
# PageError for title: World currency
# PageError for title: Hedge fund
# PageError for title: Indira Gandhi
# PageError for title: Hana Bank
# PageError for title: Economy of Uzbekistan
# PageError for title: Russian ruble
# PageError for title: 2020 stock market crash
# PageError for title: Swiss franc
# PageError for title: KOSPI
# PageError for title: List of countries by received FDI
# PageError for title: Black market
# PageError for title: Nasdaq-100
# PageError for title: IShares
# PageError for title: HSBC
# PageError for title: Northern Trust
# PageError for title: Inflation
# PageError for title: Contango
# PageError for title: Business cycle
# PageError for title: S&P GSCI
# PageError for title: El Niño
# PageError for title: Brad Wall
# PageError for title: Enron
# PageError for title: Wa State
# PageError for title: Sesame
# PageError for title: Iron ore
# PageError for title: Resource curse
# PageError for title: Panic of 1893
# PageError for title: Economy of Dominica
# PageError for title: Coin
# PageError for title: Russian ruble
# PageError for title: Freelancer (video game)
# PageError for title: ICICI Bank
# PageError for title: Highland Clearances
# PageError for title: Naftali Bennett
# PageError for title: DBL Group
# PageError for title: Chaos theory
# PageError for title: Mining the Sky
# PageError for title: Teck Resources
# PageError for title: Juan Perón
# PageError for title: Megaproject
# PageError for title: Tulip mania
# PageError for title: Reserve currency
# PageError for title: Alan Greenspan
# PageError for title: Canal
# PageError for title: Precious metal
# PageError for title: Phil Gramm
# PageError for title: Purchasing power parity
# PageError for title: Panic of 1837
# PageError for title: ATB Financial
# PageError for title: Terms of trade
# PageError for title: Air Greenland
# PageError for title: International economics
# PageError for title: Commodity computing
# PageError for title: Maringá
# PageError for title: Mohammadi Group
# PageError for title: The Economist
# PageError for title: Mainstream economics
# PageError for title: Economy of Colombia
# PageError for title: Real estate
# PageError for title: Real estate investment trust
# PageError for title: Real estate transaction
# PageError for title: Compass, Inc.
# PageError for title: Flipping
# PageError for title: Ryan Serhant
# PageError for title: Redfin
# PageError for title: Christina Hall
# PageError for title: House
# PageError for title: Rockpoint Group
# PageError for title: Viral marketing
# PageError for title: Fannie Mae
# PageError for title: Freddie Mac
# PageError for title: Negative equity
# PageError for title: Economy of Canada
# PageError for title: Inflation
# PageError for title: Property insurance
# PageError for title: Occupancy
# PageError for title: Robert J. Shiller
# PageError for title: Carlos Slim
# PageError for title: Star Market
# PageError for title: Welltower
# PageError for title: Capitalism
# PageError for title: Neal Mohan
# PageError for title: Business valuation
# PageError for title: Slave market
# PageError for title: Zoning
# PageError for title: Toyota Corolla (E210)
# PageError for title: Conforming loan
# PageError for title: Mercedes-Benz E-Class
# PageError for title: Volkswagen Golf Mk7
# PageError for title: Section 8 (housing)
# PageError for title: Citroën CX
# PageError for title: Dasmariñas
# PageError for title: Jean-Michel Basquiat
# PageError for title: Bank of England
# PageError for title: Money market
# PageError for title: Gosbank
# PageError for title: Inflation
# PageError for title: Bank of Italy
# PageError for title: Argenta (bank)
# PageError for title: Bahamian dollar
# PageError for title: Luis Caputo
# PageError for title: Central Asia
# PageError for title: State of Palestine
# PageError for title: Bank run
# PageError for title: CFA franc
# PageError for title: ICICI Bank
# PageError for title: Turkish lira
# PageError for title: IDBI Bank
# PageError for title: SEB Group
# PageError for title: Exim Bank of India
# PageError for title: Ramesh Chander
# PageError for title: Demographics of Israel
# PageError for title: Numbers game
# PageError for title: Bank of America
# PageError for title: CLS Group
# PageError for title: Marsha Blackburn
# PageError for title: Inflation
# PageError for title: Jeb Bush
# PageError for title: New Deal
# PageError for title: John Maynard Keynes
# PageError for title: Lincoln Chafee
# PageError for title: Janet Yellen
# PageError for title: Bill Weld
# PageError for title: Fischer Black
# PageError for title: Jerome Powell
# PageError for title: Mary Fallin
# PageError for title: Javier Milei
# PageError for title: Factions in the Democratic Party (United States)
# PageError for title: Jack Kemp
# PageError for title: National Defense Authorization Act for Fiscal Year 2023
# PageError for title: Neil Howe
# PageError for title: Alan Greenspan
# PageError for title: Bard College
# PageError for title: Progressive tax
# PageError for title: Thomas Wolsey
# PageError for title: Presidency of Ronald Reagan
# PageError for title: Monetary economics
# PageError for title: Business cycle
# PageError for title: Krishnamurthy Subramanian
# PageError for title: Hugh Denys
# PageError for title: Economy of Singapore
# PageError for title: Inflation
# PageError for title: Monetary economics
# PageError for title: Economy of Uzbekistan
# PageError for title: Bank of England
# PageError for title: Economy of Canada
# PageError for title: Armenian dram
# PageError for title: Megan Greene
# PageError for title: John Maynard Keynes
# PageError for title: CFA franc
# PageError for title: Alan Greenspan
# PageError for title: Fischer Black
# PageError for title: Managerial economics
# PageError for title: Jerome Powell
# PageError for title: Janet Yellen
# PageError for title: Shilling
# PageError for title: Judy Shelton
# PageError for title: New Deal
# PageError for title: Chicago plan
# PageError for title: Money printing
# PageError for title: Richard Clarida
# PageError for title: Wale Edun
# PageError for title: Mixed economy
# PageError for title: Somali shilling
# PageError for title: Panic of 1837
# PageError for title: James G. Blaine
# PageError for title: Business cycle
# PageError for title: Paul Sheard
# PageError for title: Bahamian dollar
# PageError for title: Bank of Italy
# PageError for title: José Luis Cordeiro
# PageError for title: Economic impact of the COVID-19 pandemic in India
# PageError for title: Economic impact of the COVID-19 pandemic in Russia
# PageError for title: Social impact of the COVID-19 pandemic
# PageError for title: Economic impact of the COVID-19 pandemic in Malaysia
# PageError for title: Zero-COVID
# PageError for title: COVID-19 vaccine
# PageError for title: Social impact of the COVID-19 pandemic in Russia
# PageError for title: Impact of the COVID-19 pandemic on cricket
# PageError for title: Impact of the COVID-19 pandemic on prisons
# PageError for title: Impact of the COVID-19 pandemic on motorsport
# PageError for title: Great Reset
# PageError for title: Impact of the COVID-19 pandemic on association football
# PageError for title: COVID-19 pandemic in North Korea
# PageError for title: Impact of the COVID-19 pandemic on social media
# PageError for title: COVID-19 pandemic in Colombia
# PageError for title: Greensill scandal
# PageError for title: Timeline of the COVID-19 pandemic in January 2020
# PageError for title: Statistics of the COVID-19 pandemic in Brazil
# PageError for title: Impact of the COVID-19 pandemic on healthcare workers
# PageError for title: COVID-19 pandemic in Chile
# PageError for title: Super Bowl LV
# PageError for title: Impact of the COVID-19 pandemic on suicide rates
# PageError for title: COVID-19 pandemic in Africa
# PageError for title: Economy of Singapore
# PageError for title: Impact of the COVID-19 pandemic on the military
# PageError for title: Lockdown Files
# PageError for title: CARES Act
# PageError for title: COVID-19 vaccine hesitancy in the United States
# PageError for title: Sustainable Development Goal 1
# PageError for title: COVID-19 pandemic in Alberta
# PageError for title: Statistics of the COVID-19 pandemic in India
# PageError for title: COVID-19 pandemic in Wales
# PageError for title: COVID-19 pandemic in Oman
# PageError for title: Statistics of the COVID-19 pandemic in Germany
# PageError for title: Impact of the COVID-19 pandemic on international relations
# PageError for title: COVID-19 pandemic in South Carolina
# PageError for title: Timeline of the COVID-19 pandemic in December 2022
# PageError for title: Sustainable Development Goal 11
# PageError for title: COVID-19 pandemic in Malawi
# PageError for title: Pete Snyder
# PageError for title: Timeline of the COVID-19 pandemic in Australia (2020)
# PageError for title: Timeline of the COVID-19 pandemic in April 2021
# PageError for title: 2020 stock market crash
# PageError for title: COVID-19 protests in the United States
# PageError for title: Responses to the COVID-19 pandemic in October 2022
# PageError for title: Expo 2023
# PageError for title: Statistics of the COVID-19 pandemic in Italy
# PageError for title: Xi Jinping
# PageError for title: Statistics of the COVID-19 pandemic in Portugal
# PageError for title: Payoneer
# PageError for title: Lazada
# PageError for title: Commercetools
# PageError for title: IndiaMART
# PageError for title: Mytheresa
# PageError for title: Cyber Monday
# PageError for title: Singles' Day
# PageError for title: BigBasket
# PageError for title: Marc Lore
# PageError for title: Tim Scott
# PageError for title: MakeMyTrip
# PageError for title: Zalando
# PageError for title: Ninja Van
# PageError for title: Green growth
# PageError for title: Klarna
# PageError for title: Billings, Montana
# PageError for title: Shein
# PageError for title: Alibaba Group
# PageError for title: Jimmy Carter
# PageError for title: E-governance
# PageError for title: Vipshop
# PageError for title: Teespring
# PageError for title: Pimcore
# PageError for title: Walmart
# PageError for title: PhonePe
# PageError for title: Affirm Holdings
# PageError for title: LiveChat Software
# PageError for title: Seabrook, Washington
# PageError for title: Javier Olivan
# PageError for title: Costco
# PageError for title: Online banking
# PageError for title: DuPont
# PageError for title: Taobao
# PageError for title: Fingerhut
# PageError for title: Indian Chamber of Commerce
# PageError for title: Chuck Schumer
# PageError for title: Economy of Canada
# PageError for title: LVMH
# PageError for title: Wayfair
# PageError for title: Mount Greylock
# PageError for title: Indira Gandhi
# PageError for title: Ted Cruz
# PageError for title: LY Corporation
# PageError for title: Etsy
# PageError for title: Tencent
# PageError for title: Pine nut
# PageError for title: Adam Kinzinger
# PageError for title: Bryan Johnson
# PageError for title: Paytm
# PageError for title: VK (company)
# PageError for title: Whitefish (fisheries term)
# PageError for title: Das Kapital
# PageError for title: Flutterwave
# PageError for title: U.S. state
# PageError for title: TJ Maxx
# PageError for title: Jerry Yang
# PageError for title: Adlai Stevenson II
# PageError for title: John F. Kennedy
# PageError for title: Neiman Marcus
# Unhandled exception for title: Benin: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Indian commerce with early English colonists and the early United States: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Eric Schmidt: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# PageError for title: LPP (company)
# PageError for title: Société Générale
# Unhandled exception for title: Dubai: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Ashkenazi Jews: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# Unhandled exception for title: Papier (company): An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# PageError for title: Brasília
# PageError for title: TPG Inc.
# PageError for title: Teleperformance
# PageError for title: Jack Ma
# PageError for title: REWE Group
# PageError for title: Amway
# PageError for title: Harman International
# PageError for title: Arthur Andersen
# PageError for title: Pottery Barn
# PageError for title: Qoo10
# PageError for title: Philippines
# PageError for title: The Times Group
# PageError for title: China
# PageError for title: Inflation
# PageError for title: Trustpilot
# PageError for title: Doug McMillon
# PageError for title: E-470
# PageError for title: Kenya
# PageError for title: Deliveroo
# PageError for title: Payoneer
# PageError for title: 2023 Writers Guild of America strike
# PageError for title: Lapsis
# PageError for title: Sleepyboy
# PageError for title: Linda Evangelista
# PageError for title: Ritchie Torres
# PageError for title: Liveops
# PageError for title: Abbott Elementary
# PageError for title: Stacey Abrams
# PageError for title: Justin Welby
# PageError for title: 2023 in American television
# PageError for title: Axie Infinity
# PageError for title: Vox Media
# PageError for title: Matt Haney
# PageError for title: SweepSouth
# PageError for title: Useme
# PageError for title: Virtual management
# PageError for title: Upwork
# PageError for title: Sophie Wade
# PageError for title: Crowd Cow
# PageError for title: Online marketplace
# PageError for title: Form 1099
# PageError for title: 2018 in American television
# PageError for title: XHamster
# PageError for title: Leeds
# PageError for title: Rachel Sennott
# PageError for title: Jim Croce
# PageError for title: Wake Island
# PageError for title: Matty Healy
# PageError for title: Sacha Lord
# PageError for title: BTS
# PageError for title: Neil Young
# PageError for title: Janet Yellen
# PageError for title: Jeep Cherokee
# PageError for title: Wales
# PageError for title: Prince (musician)
# PageError for title: Abbie Hoffman
# PageError for title: Pink Floyd
# PageError for title: Michael Jackson
# PageError for title: Berlin Wall
# PageError for title: Lou Reed
# Unhandled exception for title: List of video games notable for negative reception: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# PageError for title: Tucker Carlson
# PageError for title: David Letterman
# Unhandled exception for title: List of Last Man Standing characters: An unknown error occured: "We could not complete your search due to a temporary problem. Please try again later.". Please report it on GitHub!
# PageError for title: Carole King
# PageError for title: Billy Connolly
# PageError for title: Miles Davis
# PageError for title: Woody Allen
# PageError for title: Dan Rather
# PageError for title: Jeep Liberty
# PageError for title: Mark Knopfler
# PageError for title: Scott Morrison
# PageError for title: Pope Francis
# PageError for title: Peter Cetera
# PageError for title: The Fame
# PageError for title: Lee Hyori
# PageError for title: Puget Sound
# PageError for title: Tang ping
# PageError for title: Al Sharpton
# PageError for title: Poison Ivy (character)
# PageError for title: Pete Best
# PageError for title: MC Hammer
# PageError for title: CARES Act
# PageError for title: The Drifters
# PageError for title: David Graeber
# PageError for title: Bruce Hornsby
# PageError for title: Trade barrier
# PageError for title: International Trade Centre
# PageError for title: Bonar Law
# PageError for title: Safeguard
# PageError for title: Balanced trade
# PageError for title: International economics
# PageError for title: Dedollarisation
# PageError for title: Indo-Pacific Economic Framework
# PageError for title: Economy of Canada
# PageError for title: John Maynard Keynes
# PageError for title: Canada
# PageError for title: 1888 United States presidential election
# PageError for title: Purchasing power parity
# PageError for title: Silk Road
# PageError for title: Benjamin Harrison
# PageError for title: Sherrod Brown
# PageError for title: John Tyler
# PageError for title: John C. Calhoun
# PageError for title: Cordell Hull
# PageError for title: China
# PageError for title: List of countries by wheat exports
# PageError for title: Peter Mandelson
# PageError for title: Andrew Jackson
# PageError for title: States' rights
# PageError for title: American entry into World War I
# PageError for title: Liam Fox
# PageError for title: James G. Blaine
# PageError for title: Mixed economy
# PageError for title: Black market
# PageError for title: Planned economy
# PageError for title: Ramesh Chander
# PageError for title: Capitalism
# PageError for title: Blue economy
# PageError for title: Southeast Asia
# PageError for title: Economy of China
# PageError for title: Agustín Carstens
# PageError for title: Tim Besley
# PageError for title: Mark Mobius
# PageError for title: Eurasia Group
# PageError for title: Actis Capital
# PageError for title: Darknet market
# PageError for title: GAZ Volga
# PageError for title: Barter
# PageError for title: Market segmentation
# PageError for title: 2023 Union budget of India
# PageError for title: Nordic model
# PageError for title: Jeffrey Garten
# PageError for title: New economy
# PageError for title: Inflation
# PageError for title: Classical economics
# PageError for title: Purchasing power parity
# PageError for title: Ian Bremmer
# PageError for title: Ray Dalio
# PageError for title: Gulf Cooperation Council
# PageError for title: Early 2000s recession
# PageError for title: Kia Seltos
# PageError for title: Raghuram Rajan
# PageError for title: Online marketplace
# PageError for title: Inequality
# PageError for title: Ray Dalio
# PageError for title: Gender inequality in India
# PageError for title: Economy of Singapore
# PageError for title: Gender inequality

# %%
# Create the CSV from the DataFrame
eco_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Economy.csv"
eco_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Economy = pd.read_csv("./Data/Economy.csv")
Economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Entertainment

# %%
# Define the topics and subtopics
title = {
    'Entertainment': [
        'Music industry', 'Popular cultural events', 'Streaming platforms',
        'Film industry trends', 'Television series popularity', 'Celebrity influence',
        'Video gaming industry', 'Virtual concerts and events', 'Social media influencers',
        'Theater and Broadway shows', 'Reality TV impact', 'Podcasting trends',
        'Book publishing industry', 'Comic books and graphic novels', 'Animation and CGI advancements',
        'Fashion trends and events', 'Art exhibitions and galleries', 'Stand-up comedy and live shows',
        'Sports entertainment', 'Award shows and ceremonies', 'Fan culture and fandoms',
        'Dance and performance arts', 'Photography in the digital age', 'Mobile gaming',
        'VR/AR in entertainment', 'Esports growth', 'Influencer marketing',
        'Cultural festivals', 'Film festivals and screenings', 'Music streaming trends',
        'Digital art and NFTs', 'Youth culture and entertainment', 'Classic vs. modern entertainment',
        'Interactive entertainment', 'Cable TV vs. streaming wars', 'Celebrity fashion and style trends'
    ],
}

# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: Music
# PageError for title: Record producer
# PageError for title: Pop music
# PageError for title: Tim Farriss
# PageError for title: 2023 in Latin music
# PageError for title: Andrew Farriss
# PageError for title: G Flip
# PageError for title: Music of Turkey
# PageError for title: C-pop
# PageError for title: MTV
# PageError for title: Angèle (singer)
# PageError for title: NF (rapper)
# PageError for title: Tina Arena
# PageError for title: Sony Music
# PageError for title: Blackout Tuesday
# PageError for title: Simon Cowell
# PageError for title: Goa trance
# PageError for title: Tommy Emmanuel
# PageError for title: Midnight Oil
# PageError for title: Kris Kross
# PageError for title: 1989 (album)
# PageError for title: MAMA Awards
# PageError for title: Music publisher
# PageError for title: Thom Yorke
# PageError for title: Tones and I
# PageError for title: Russell Simmons
# PageError for title: Taylor Swift
# PageError for title: Alicia Keys
# PageError for title: UK Singles Chart
# PageError for title: Martin Atkins
# PageError for title: Beyoncé
# PageError for title: Sid Sriram
# PageError for title: Whitney Houston
# PageError for title: Lil' Flip
# PageError for title: List of programs broadcast by MTV
# PageError for title: Clive Davis
# PageError for title: Onefour
# PageError for title: Ester Dean
# PageError for title: Ocean Alley
# PageError for title: Lucian Grainge
# PageError for title: Gangnam Style
# PageError for title: SoundCloud
# PageError for title: Peach PRC
# PageError for title: B Praak
# PageError for title: Golden Disc Awards
# PageError for title: Tommy Mottola
# PageError for title: Dream Theater discography
# PageError for title: Mark Volman
# PageError for title: Clarence Avant
# PageError for title: 2001 MTV Video Music Awards
# PageError for title: Haddaway
# PageError for title: A440 (pitch standard)
# PageError for title: Barry Weiss
# PageError for title: Kim Jong-kook
# PageError for title: 1993 in music
# PageError for title: Music of Rwanda
# PageError for title: Lyor Cohen
# PageError for title: Cultural tourism
# PageError for title: Cultural Revolution
# PageError for title: Cultural relativism
# PageError for title: Cultural competence
# PageError for title: Culture during the Cold War
# PageError for title: Zoot suit
# PageError for title: World Heritage Site
# PageError for title: Pop music
# PageError for title: Generation
# PageError for title: Culture of India
# PageError for title: Sinosphere
# PageError for title: ShowBT Entertainment
# PageError for title: Tug of war
# PageError for title: List of subcultures
# PageError for title: Pokémon
# PageError for title: Religion in Argentina
# PageError for title: Public participation
# PageError for title: Swinging Sixties
# PageError for title: Qilin
# PageError for title: Soul food
# PageError for title: Highwayman
# PageError for title: Fernando Amorsolo
# PageError for title: Mancala
# PageError for title: World War III in popular culture
# PageError for title: Easter parade
# PageError for title: Tony Scherman
# PageError for title: Sawney Bean
# PageError for title: The Simpsons
# PageError for title: Singles' Day
# PageError for title: Novel
# PageError for title: Philippines
# PageError for title: Tagetes
# PageError for title: El Niño
# PageError for title: Ha Ji-won
# PageError for title: Definitions of fascism
# PageError for title: The Hague
# PageError for title: New Year's Eve
# PageError for title: Music of Turkey
# PageError for title: Hygge
# PageError for title: Santa Claus
# PageError for title: ITVX
# PageError for title: JioCinema
# PageError for title: The Unhealer
# PageError for title: SonyLIV
# PageError for title: LiveOne
# PageError for title: Christmas in the Smokies
# PageError for title: Jaden Smith
# PageError for title: The Lost Girls (film)
# PageError for title: Aarya (TV series)
# PageError for title: SoundCloud
# PageError for title: SmartLess
# PageError for title: PBS Kids
# PageError for title: Hybe Corporation
# PageError for title: OnlyFans
# PageError for title: BritBox
# PageError for title: Xumo
# PageError for title: Domo Genesis
# PageError for title: Bellakath
# PageError for title: Zach Bryan
# PageError for title: FETV
# PageError for title: Katie Price
# PageError for title: CollegeHumor
# PageError for title: Måneskin
# PageError for title: Bigo Live
# PageError for title: CamSoda
# PageError for title: Justin Kan
# PageError for title: Sidemen
# PageError for title: TVING
# PageError for title: Cocomelon
# PageError for title: ScreenX
# PageError for title: Pluto TV
# PageError for title: Stream (disambiguation)
# PageError for title: Poor Man's Poison
# PageError for title: Bilibili
# PageError for title: Ed Craven
# PageError for title: Eddy Grant
# PageError for title: Curse of Aurore
# PageError for title: U-Next
# PageError for title: I Love You 3000
# PageError for title: Shannon Hoon
# PageError for title: Clickbait
# PageError for title: BabyTron
# PageError for title: Overwatch League
# PageError for title: The CW
# PageError for title: Chicago Med
# PageError for title: Wellmania
# PageError for title: Olivia Rodrigo
# PageError for title: Augustana (band)
# PageError for title: Fat Trel
# PageError for title: Calum Scott
# PageError for title: Dignity (TV series)
# PageError for title: 2023 NFL season
# PageError for title: JZyNO
# PageError for title: 1989 (album)
# PageError for title: The Tomorrow War
# PageError for title: XO Tour Llif3
# PageError for title: Quibi
# PageError for title: FuboTV
# PageError for title: Where Your Eyes Linger
# PageError for title: Stuart Zender
# PageError for title: Ryo Fukui
# PageError for title: Stranger Things (season 4)
# PageError for title: Lover (album)
# PageError for title: Curiosity Stream
# PageError for title: Passionflix
# PageError for title: Amanda Cerny
# PageError for title: FMovies
# PageError for title: Reno 911!
# PageError for title: Sadak 2
# PageError for title: Jimin
# PageError for title: Imagine Dragons
# PageError for title: Joeboy
# PageError for title: Dancing with the Stars (American season 31)
# PageError for title: 4:44
# PageError for title: Times Internet
# PageError for title: Tosca Musk
# PageError for title: Hickok45
# PageError for title: Duncan Laurence
# PageError for title: XHamster
# PageError for title: Fashion
# PageError for title: Mohamed Kordofani
# PageError for title: Tips
# PageError for title: MyFreeCams
# PageError for title: Barbie (film)
# PageError for title: Morbius (film)
# PageError for title: Pearl (2022 film)
# PageError for title: The Great Wall (film)
# PageError for title: Haunted Mansion (2023 film)
# PageError for title: Dune (2021 film)
# PageError for title: Jaya Prada
# PageError for title: Mia Khalifa
# PageError for title: Candyman (2021 film)
# PageError for title: Sunny Leone
# PageError for title: The Game Awards 2021
# PageError for title: Mining
# PageError for title: G.B.F. (film)
# PageError for title: Emelia Hartford
# PageError for title: XBIZ
# PageError for title: 777 Charlie
# PageError for title: KGF: Chapter 1
# PageError for title: Entertainment industry during World War II
# PageError for title: Lionsgate Films
# PageError for title: Cobra (2022 film)
# PageError for title: Nithya Das
# PageError for title: Fast food
# PageError for title: Promised Land (2012 film)
# PageError for title: Black Widow (2021 film)
# PageError for title: Booksmart
# PageError for title: 83 (film)
# PageError for title: King of Thieves (2022 film)
# PageError for title: Snuff film
# PageError for title: Premam
# PageError for title: Economy of Tamil Nadu
# PageError for title: Choi Jong-hoon
# PageError for title: Gone with the Wind (film)
# PageError for title: Aamir Khan
# PageError for title: Heroin chic
# PageError for title: Casting couch
# PageError for title: Kobe Tai
# PageError for title: Agriculture in India
# PageError for title: Unda (film)
# PageError for title: Shiva Rajkumar
# PageError for title: Pet industry
# PageError for title: Clueless
# PageError for title: Deliverance
# PageError for title: Classmates (2006 film)
# PageError for title: The Little Mermaid (2023 film)
# PageError for title: Battle Royale (film)
# PageError for title: Gay pornography
# PageError for title: Mahesh Babu
# PageError for title: Die Hard
# PageError for title: Guz Khan
# PageError for title: Avatar (2009 film)
# PageError for title: Zoolander
# PageError for title: VTuber
# PageError for title: 37th AVN Awards
# PageError for title: Cary Grant
# PageError for title: Nepo baby
# PageError for title: Gemini (2002 film)
# PageError for title: 3D film
# PageError for title: Batman Begins
# PageError for title: Glen Schofield
# PageError for title: Bhoot Police
# PageError for title: Photographic film
# PageError for title: Pop music
# PageError for title: Billa (1980 film)
# PageError for title: The Imitation Game
# PageError for title: Jeremy Rifkin
# PageError for title: B Praak
# PageError for title: Mozhi (film)
# PageError for title: Sholay
# PageError for title: Gender inequality
# PageError for title: Gangaajal
# PageError for title: Kony 2012
# PageError for title: Sharmin Segal
# PageError for title: Majid Michel
# PageError for title: Sunny Hinduja
# PageError for title: David McCallum
# PageError for title: Doctor Who (series 4)
# PageError for title: Monkey (TV series)
# PageError for title: Koala Man
# PageError for title: The Fairly OddParents
# PageError for title: CSI: Miami
# PageError for title: 2018 in American television
# PageError for title: Doctor Who (series 5)
# PageError for title: Batman (TV series)
# PageError for title: James Brolin
# PageError for title: Meteor Garden (2001 TV series)
# PageError for title: Susan Dey
# PageError for title: Game of Thrones
# PageError for title: Nichols (TV series)
# PageError for title: Spooks (TV series)
# PageError for title: Schitt's Creek
# PageError for title: Dom DeLuise
# PageError for title: GLOW (TV series)
# PageError for title: Queer Eye (2003 TV series)
# PageError for title: Joe Chen
# PageError for title: Sitcom
# PageError for title: Gran (TV series)
# PageError for title: E.U. (TV series)
# PageError for title: Ally McBeal
# PageError for title: Luna Wedler
# PageError for title: Lee Jae-wook
# PageError for title: Kavitha Gowda
# PageError for title: Loni Anderson
# PageError for title: Charlie's Angels
# PageError for title: Lee Jong-hyuk
# PageError for title: Won Bin
# PageError for title: Zhao Lusi
# PageError for title: Tom Bergeron
# PageError for title: Jaleel White
# PageError for title: Peter Andre
# PageError for title: Servant of the People (2015 TV series)
# PageError for title: Cold Case Files
# PageError for title: Hu Yitian
# PageError for title: Wallace Chung
# PageError for title: Song Ji-hyo
# PageError for title: Jeannie (TV series)
# PageError for title: Eerie, Indiana
# PageError for title: Song Kang
# PageError for title: Bai Lu (actress)
# PageError for title: The Betty White Show (1952 TV series)
# PageError for title: The Tick (2001 TV series)
# PageError for title: Lee Min-ho
# PageError for title: Go Princess Go
# PageError for title: Jonathan Brandis
# PageError for title: MacGruber
# PageError for title: Rowoon
# PageError for title: Jim Parsons
# PageError for title: Harry Potter
# PageError for title: Lee Se-hee
# PageError for title: Barbara Eden
# PageError for title: The Only Way Is Essex
# PageError for title: The WB
# PageError for title: Seo Yea-ji
# PageError for title: Shark Tank
# PageError for title: Maude (TV series)
# PageError for title: Ram Kapoor
# PageError for title: Texas hold 'em
# PageError for title: Smallville
# PageError for title: Shaun Cassidy
# PageError for title: The Flintstones
# PageError for title: Skai Jackson
# PageError for title: Valley of the Wolves
# PageError for title: Neena Gupta
# PageError for title: Ninjago (TV series)
# PageError for title: Even Stevens
# PageError for title: Jason Priestley
# PageError for title: Mr. Beef
# PageError for title: Jumong (TV series)
# PageError for title: Park Hyung-sik
# PageError for title: Glee (TV series)
# PageError for title: Squid Game
# PageError for title: Three's Company
# PageError for title: Saffron Barker
# PageError for title: Forbes China Celebrity 100
# PageError for title: Mr. Satan
# PageError for title: Tilly Ramsay
# PageError for title: Kendall Jenner
# PageError for title: Olivia Wilde
# PageError for title: Howard Bragman
# PageError for title: Nella Rose
# PageError for title: Peer pressure
# PageError for title: Conformity
# PageError for title: Danniella Westbrook
# PageError for title: Luke Macfarlane
# PageError for title: Supercouple
# PageError for title: Hole (band)
# PageError for title: Worst Cooks in America
# PageError for title: Courtney Love
# PageError for title: Mackenzie Davis
# PageError for title: Jennie Garth
# PageError for title: Emma Grede
# PageError for title: Cat Deeley
# PageError for title: Farrah Abraham
# PageError for title: RL (singer)
# PageError for title: 27 Club
# PageError for title: Gordon Ramsay
# PageError for title: Viral marketing
# PageError for title: Delia Smith
# PageError for title: Michael Lohan
# PageError for title: Doja Cat
# PageError for title: Deepfake
# PageError for title: Wentworth Miller
# PageError for title: Rachael Ray
# PageError for title: Beyoncé
# PageError for title: Justin Bieber
# PageError for title: Celebrity Treasure Island 2022
# PageError for title: Gemma Collins
# PageError for title: Joan Rivers
# PageError for title: Katrina Kaif
# PageError for title: Jodie Marsh
# PageError for title: List of YouTubers
# PageError for title: Vicky Pattison
# PageError for title: Jason Oppenheim
# PageError for title: Lady Gaga
# PageError for title: Melissa Villaseñor
# PageError for title: Dennis Rodman
# PageError for title: Gangnam Style
# PageError for title: Luke Hemmings
# PageError for title: Johnny Ruffo
# PageError for title: Andrew Tate
# PageError for title: Pamela Anderson
# PageError for title: Steven Wright
# PageError for title: Ranveer Singh
# PageError for title: Jason Mraz
# PageError for title: Justin de Dios
# PageError for title: Alli Simpson
# PageError for title: André 3000
# PageError for title: Megan Ganz
# PageError for title: Fashion
# PageError for title: Kray twins
# PageError for title: Na Yeong-seok
# PageError for title: Robin Williams
# PageError for title: NSYNC
# PageError for title: Chris Brown
# PageError for title: Mandy Moore
# PageError for title: James Spader
# PageError for title: Zeus Network
# PageError for title: Debbie Gibson
# PageError for title: Samantha Ronson
# PageError for title: Michael Jackson
# PageError for title: Rick Harrison
# PageError for title: Nadia Lim
# PageError for title: Jack Black
# PageError for title: Simon Cowell
# PageError for title: Tiffany Darwish
# PageError for title: Kevin Jonas
# PageError for title: Kellie Pickler
# PageError for title: Marion Grasby
# PageError for title: EQAL
# PageError for title: Boy George
# PageError for title: Anthony Bourdain
# PageError for title: Kylie Jenner
# PageError for title: Queens of the Stone Age
# PageError for title: Yang Zi (actress)
# PageError for title: John DeLorean
# PageError for title: Nick Cannon
# PageError for title: David Beckham
# PageError for title: Vanessa Lachey
# PageError for title: Mo Gilligan
# PageError for title: Lee Min-ho
# PageError for title: Tony Hawk
# PageError for title: Gemma Atkinson
# PageError for title: Gary Oldman
# PageError for title: Givenchy
# PageError for title: Sommore
# PageError for title: Melanie C
# PageError for title: Kris Wu
# PageError for title: Will Ferrell
# PageError for title: Janet Street-Porter
# PageError for title: Kevin Federline
# PageError for title: Ironmouse
# PageError for title: Bruno Mars
# PageError for title: Elijah Blue Allman
# PageError for title: Alexandra Burke
# PageError for title: Françoise Hardy
# PageError for title: Questlove
# PageError for title: Anoushka Shankar
# PageError for title: Shahid Kapoor
# PageError for title: Bob Monkhouse
# PageError for title: Amber Heard
# PageError for title: Tim Allen
# PageError for title: Hydro Flask
# PageError for title: Tom Cruise
# PageError for title: Little Mix
# PageError for title: Ike Turner
# PageError for title: Alicia Silverstone
# PageError for title: Sharon Osbourne
# PageError for title: Skai Jackson
# PageError for title: Janet Jackson
# PageError for title: Jon Lovitz
# PageError for title: Fan Bingbing
# PageError for title: Arthur (TV series)
# PageError for title: Belle Delphine
# PageError for title: Judy Garland
# PageError for title: Jenny McCarthy
# PageError for title: Tzi Ma
# PageError for title: Bobby Brown
# PageError for title: Joo Won
# PageError for title: Tom Waits
# PageError for title: Indie game
# PageError for title: Video game addiction
# PageError for title: The Invincible (video game)
# PageError for title: 2005 in video games
# PageError for title: Game studies
# PageError for title: Jason Schreier
# PageError for title: Alanah Pearce
# PageError for title: PC game
# PageError for title: E.T. the Extra-Terrestrial (video game)
# PageError for title: Wing Commander (video game)
# PageError for title: The Game Awards 2020
# PageError for title: Hong Kong 97 (video game)
# PageError for title: Video games in Belgium
# PageError for title: Squad (video game)
# PageError for title: Marienbad (video game)
# PageError for title: 1970s in video games
# PageError for title: Hades (video game)
# PageError for title: Joust (video game)
# PageError for title: Battlezone (1980 video game)
# PageError for title: 2016 in video games
# PageError for title: Gabe Newell
# PageError for title: Lemmings (video game)
# PageError for title: Post Scriptum (video game)
# PageError for title: Adventure (1980 video game)
# PageError for title: The Game Awards 2021
# PageError for title: Overwatch (video game)
# PageError for title: Rings of Power (video game)
# PageError for title: Console war
# PageError for title: Sid Meier
# PageError for title: The Oregon Trail (1971 video game)
# PageError for title: Licensed game
# PageError for title: Roberta Williams
# PageError for title: Amy Hennig
# PageError for title: R.O.B.
# PageError for title: Saori (video game)
# PageError for title: Gotcha (video game)
# PageError for title: ZUN (video game developer)
# PageError for title: Nolan Bushnell
# PageError for title: Fallout (video game)
# PageError for title: Berzerk (video game)
# PageError for title: State of Emergency (video game)
# PageError for title: Lords of the Fallen (2023 video game)
# PageError for title: Spider-Man 2 (2023 video game)
# PageError for title: Chris Roberts (video game developer)
# PageError for title: Bully (video game)
# PageError for title: Braid (video game)
# PageError for title: Atom's Last Shot
# PageError for title: Shenmue (video game)
# PageError for title: Limbo (video game)
# PageError for title: Civilization (video game)
# PageError for title: Among Us
# PageError for title: Id Software
# PageError for title: StarCraft (video game)
# PageError for title: The Last of Us
# PageError for title: Alone in the Dark (1992 video game)
# PageError for title: Catechumen (video game)
# PageError for title: Viewfinder (video game)
# PageError for title: Olympic Games Tokyo 2020 - The Official Video Game
# PageError for title: Populous (video game)
# PageError for title: Borderlands (video game)
# PageError for title: Rami Ismail
# PageError for title: Wingspan (video game)
# PageError for title: Bachelor Party (video game)
# PageError for title: Space Race (video game)
# PageError for title: Bionicle (video game)
# PageError for title: Haze (video game)
# PageError for title: Eternal Darkness
# PageError for title: Mortal Kombat (1992 video game)
# PageError for title: Blockade (video game)
# PageError for title: List of best-selling video game franchises
# PageError for title: Keywords Studios
# PageError for title: Freelancer (video game)
# PageError for title: Hatred (video game)
# PageError for title: Tencent
# PageError for title: Pac-Man
# PageError for title: Sacrifice (video game)
# PageError for title: Commando (video game)
# PageError for title: Game Workers Unite
# PageError for title: Analogue Pocket
# PageError for title: Street Fighter II
# PageError for title: Grand Theft Auto III
# PageError for title: Discworld (video game)
# PageError for title: GameStop
# PageError for title: Façade (video game)
# PageError for title: Banana (video game)
# PageError for title: Florence (video game)
# PageError for title: Graphics card
# PageError for title: Centipede (video game)
# PageError for title: History of Eastern role-playing video games
# PageError for title: Pac-Man (Atari 2600 video game)
# PageError for title: Natali Morris
# PageError for title: The Game Awards 2022
# PageError for title: Humankind (video game)
# PageError for title: Rift Tour
# PageError for title: Virtual reality
# PageError for title: Tudum
# PageError for title: Virtual XI
# PageError for title: Miku Expo
# PageError for title: SB19
# PageError for title: X Japan
# PageError for title: Jaron Lanier
# PageError for title: Dermot Kennedy
# PageError for title: VRChat
# PageError for title: Des Rocs
# PageError for title: MLD Entertainment
# PageError for title: Lorna Luft
# PageError for title: MyFreeCams
# PageError for title: Hololive Production
# PageError for title: Mat and Savanna Shaw
# PageError for title: Gawr Gura
# PageError for title: Mica Burton
# PageError for title: Fluxus
# PageError for title: Michael Nesmith
# PageError for title: Spider-Man 2 (2023 video game)
# PageError for title: Jonathan Groff
# PageError for title: 2018 in American television
# PageError for title: Moosetape
# PageError for title: Backstreet Boys
# PageError for title: Olivia Rodrigo
# PageError for title: Stickam
# PageError for title: Harry Chapin
# PageError for title: Jordan Rudess
# PageError for title: Peacock Theater
# PageError for title: Jeff Lynne
# PageError for title: Vinnie Vincent
# PageError for title: Kiss (band)
# PageError for title: Bay to Breakers
# PageError for title: Geddy Lee
# PageError for title: Unity Technologies
# PageError for title: Topgolf
# PageError for title: Dua Lipa
# PageError for title: AJ Styles
# PageError for title: Highline Entertainment
# PageError for title: The Kid Laroi
# PageError for title: AJR (band)
# PageError for title: Berghain
# PageError for title: Lea Salonga
# PageError for title: Tate McRae
# PageError for title: Mickie James
# PageError for title: Blackpink
# PageError for title: Adderall
# PageError for title: Fuser (video game)
# PageError for title: Dwayne Johnson
# PageError for title: Paul Stookey
# PageError for title: WWE NXT
# PageError for title: Jason Lo
# PageError for title: Bob Weir
# PageError for title: Keke Palmer
# PageError for title: CJ ENM
# PageError for title: Thomas Bergersen
# PageError for title: Distrito T-Mobile
# PageError for title: Nathan Barnatt
# PageError for title: Within Temptation
# PageError for title: Amy Lee
# PageError for title: Maspalomas
# PageError for title: Festival du Voyageur
# PageError for title: BTS
# PageError for title: Monsta X
# PageError for title: Tim McGraw
# PageError for title: Tones and I
# PageError for title: Love Live!
# PageError for title: Ryan Shore
# PageError for title: TM Network
# PageError for title: The Miz
# PageError for title: Dave Matthews Band
# PageError for title: Xbox Series X and Series S
# PageError for title: List of PlayStation 2 games (L–Z)
# PageError for title: Selena Gomez
# PageError for title: Michael Martin Murphey
# PageError for title: Just Dance 2020
# PageError for title: Gymshark
# PageError for title: Kristy Scott
# PageError for title: Alix Earle
# PageError for title: Saffron Barker
# PageError for title: The Hype House
# PageError for title: Lil Tay
# PageError for title: Georgina Rodríguez
# PageError for title: Save the Kids token
# PageError for title: Viral marketing
# Error for title: Skims, retrying (1/3)
# PageError for title: Elyse Myers
# PageError for title: Belle Delphine
# PageError for title: Jeremy Fragrance
# PageError for title: Jackson Hinkle
# PageError for title: Yoseph Haddad
# PageError for title: Addison Rae
# PageError for title: Grace Beverley
# PageError for title: Demi Rose
# PageError for title: IShowSpeed
# PageError for title: Caleb Finn
# PageError for title: Tilly Ramsay
# PageError for title: Kelli Erdmann
# PageError for title: Lucy Edwards
# PageError for title: Hannah Pearl Davis
# PageError for title: Charli D'Amelio
# PageError for title: Ella Halikas
# PageError for title: Mark Goldbridge
# PageError for title: Cash App
# PageError for title: Everette Taylor
# PageError for title: Rizza Islam
# PageError for title: Kevin Jonas
# PageError for title: Mrs Hinch
# PageError for title: Emira D'Spain
# PageError for title: Andrew Tate
# PageError for title: Depths of Wikipedia
# PageError for title: Clements twins
# PageError for title: Logan Paul
# PageError for title: Fashion
# PageError for title: Josh Pieters
# PageError for title: Matthew Tye
# PageError for title: Impact of the COVID-19 pandemic on social media
# PageError for title: Gabbie Hanna
# PageError for title: Vince Dao
# PageError for title: Zoe LaVerne
# PageError for title: Sam Chui
# PageError for title: Natasha Stagg
# PageError for title: Avani Gregg
# PageError for title: Katja Mia
# PageError for title: Just Riadh
# PageError for title: FanCentro
# PageError for title: Bretman Rock
# PageError for title: Tone Sekelius
# PageError for title: Maine Mendoza
# PageError for title: Faith Nketsi
# PageError for title: Diana Eneje
# PageError for title: Rob Broadfield
# Error for title: Dawn Thandeka King, retrying (1/3)
# PageError for title: Met Gala
# PageError for title: Adam J. Bass
# PageError for title: Makenna Kelly
# PageError for title: Jake Paul
# PageError for title: Zeus Network
# PageError for title: Whitney Bond
# PageError for title: Peer pressure
# PageError for title: Truth Social
# PageError for title: Miz Cracker
# PageError for title: Youngmi Mayer
# PageError for title: Jimmy Darts
# PageError for title: Shivam Patil
# PageError for title: Luke Hemmings
# PageError for title: Lock Upp (season 1)
# PageError for title: Omah Lay
# PageError for title: Spacestation Gaming
# PageError for title: Studio 54
# PageError for title: Andrew Rannells
# PageError for title: Billy Porter
# PageError for title: Gavin Creel
# PageError for title: Reg Rogers
# PageError for title: Molly Gordon
# PageError for title: Obie Award
# PageError for title: Kate Reinders
# PageError for title: Phillipa Soo
# PageError for title: MJ the Musical
# PageError for title: Thomas Kail
# PageError for title: Jonathan Groff
# PageError for title: Laura Benanti
# PageError for title: Lucie Arnaz
# PageError for title: Jesse L. Martin
# PageError for title: Pedro Pascal
# PageError for title: Michael Urie
# PageError for title: Reneé Rapp
# PageError for title: Robert Hegyes
# PageError for title: Sarah Stiles
# PageError for title: Jennifer Westfeldt
# PageError for title: T. R. Knight
# PageError for title: Phoebe Cates
# PageError for title: Krysta Rodriguez
# PageError for title: Dear Evan Hansen
# PageError for title: Jim Parsons
# PageError for title: Kevin Kline
# PageError for title: Justin Guarini
# PageError for title: Tyne Daly
# PageError for title: Jin Ha
# PageError for title: Nathan Lane
# PageError for title: Daniel Durant
# PageError for title: Amy Irving
# PageError for title: Jordan Gelber
# PageError for title: Danielle Brooks
# PageError for title: Steven Pasquale
# PageError for title: Larry Pine
# PageError for title: Julie White
# PageError for title: Norm Lewis
# PageError for title: Michael Chernus
# PageError for title: Colman Domingo
# PageError for title: Jon Bernthal
# PageError for title: L Morgan Lee
# PageError for title: Shucked
# PageError for title: Sean Allan Krill
# PageError for title: Michaela Jaé Rodriguez
# PageError for title: Pat Carroll
# PageError for title: Hamish Linklater
# PageError for title: Len Cariou
# PageError for title: Sam Waterston
# PageError for title: Playbill
# PageError for title: Sierra Boggess
# PageError for title: Carl Anderson (singer)
# PageError for title: Glenne Headly
# PageError for title: Matthew Morrison
# PageError for title: John Astin
# PageError for title: Solea Pfeiffer
# PageError for title: Anthony Rapp
# PageError for title: Robyn Hurder
# PageError for title: Skylar Astin
# PageError for title: Lee Pace
# PageError for title: Lily Rabe
# PageError for title: IO Theater
# PageError for title: Estelle Parsons
# PageError for title: Godspell
# PageError for title: James Earl Jones
# PageError for title: Barrett Foa
# PageError for title: Dom DeLuise
# PageError for title: Ben McKenzie
# PageError for title: 76th Tony Awards
# PageError for title: Tom Hulce
# PageError for title: Joseph Papp
# PageError for title: Hadestown
# PageError for title: 1501 Broadway
# PageError for title: Sam Levene
# PageError for title: Wicked (musical)
# PageError for title: Mike Faist
# PageError for title: Karen Olivo
# PageError for title: Eric Petersen
# PageError for title: Jessica Vosk
# PageError for title: Rex Everhart
# PageError for title: Jeff Daniels
# PageError for title: Roger Rees
# PageError for title: Apollo Theater
# PageError for title: Laura Osnes
# PageError for title: Peggy Cass
# PageError for title: Lauri Peters
# PageError for title: Taye Diggs
# PageError for title: Joan Van Ark
# PageError for title: Shark Tank
# PageError for title: Virtual reality
# PageError for title: Reality
# PageError for title: Jessie Godderz
# PageError for title: Jess Bush
# PageError for title: List of Impact Wrestling personnel
# PageError for title: Jason Hervey
# PageError for title: Lacey Von Erich
# PageError for title: Tom Brittney
# PageError for title: Su Yung
# PageError for title: Dany Garcia
# PageError for title: 2018 in American television
# PageError for title: Kylie Rae
# PageError for title: Hulk Hogan
# PageError for title: WeCrashed
# PageError for title: AXS TV
# PageError for title: Billions (TV series)
# PageError for title: Game of Thrones
# PageError for title: My Hero Academia
# PageError for title: Jonathan Gresham
# PageError for title: Issa Rae
# PageError for title: Android TV
# PageError for title: LA Knight
# PageError for title: Jordyn Woods
# PageError for title: Michele Ross
# PageError for title: Shivangi Joshi
# PageError for title: FX (TV channel)
# PageError for title: OnlyFans
# PageError for title: Brooke Hogan
# PageError for title: Chucky (TV series)
# PageError for title: Lucha Underground
# PageError for title: Rob Van Dam
# PageError for title: Hunters (2020 TV series)
# PageError for title: Amit Sadh
# PageError for title: Arrowverse
# PageError for title: Live PD
# PageError for title: Gundam
# PageError for title: Chris Coelen
# PageError for title: Jase Robertson
# PageError for title: HGTV
# PageError for title: The Wire
# PageError for title: Mad Men
# PageError for title: Dino Morea
# PageError for title: Kep1er
# PageError for title: Videodrome
# PageError for title: Stranger Things
# PageError for title: Simon Cowell
# PageError for title: CNN
# PageError for title: Chelsea Handler
# PageError for title: Kevin Nash
# PageError for title: RT (TV network)
# PageError for title: Top Chef
# PageError for title: The Simpsons
# PageError for title: Bering Sea Gold
# PageError for title: Adrianne Curry
# PageError for title: Sophie Gradon
# PageError for title: Coming Out Colton
# PageError for title: Gisele Shaw
# PageError for title: Sixto Rodriguez
# PageError for title: Whitney Houston
# PageError for title: Slavery in Africa
# PageError for title: Dark Side of the 2000s
# PageError for title: Paula Abdul
# PageError for title: Dana Plato
# PageError for title: Heart Evangelista
# PageError for title: Big Brother 15 (American season)
# PageError for title: LaVar Ball
# PageError for title: Wallace Chung
# PageError for title: Joan Rivers
# PageError for title: Kristin Davis
# PageError for title: Quinton Jackson
# PageError for title: Leah Remini
# PageError for title: Top Gear (2002 TV series)
# PageError for title: Lita (wrestler)
# PageError for title: 2023 in American television
# PageError for title: Karla Souza
# PageError for title: RuPaul's Drag Race
# PageError for title: Ryan Seacrest
# PageError for title: Amy Winehouse
# PageError for title: The WB
# PageError for title: MTV
# PageError for title: Devs (TV series)
# PageError for title: American Idol
# PageError for title: The CW
# PageError for title: Madison Rayne
# PageError for title: Giga Pet
# PageError for title: Karlie Redd
# PageError for title: Servant of the People (2015 TV series)
# PageError for title: Larry Lawton
# PageError for title: Brandy Norwood
# PageError for title: Pose (TV series)
# PageError for title: Alexandra Cooper
# PageError for title: Trainwreckstv
# PageError for title: Emelia Hartford
# PageError for title: Michael Hobbes
# PageError for title: Esther Perel
# PageError for title: Spider-Man 2 (2023 video game)
# PageError for title: Zuri Hall
# PageError for title: Dax Shepard
# PageError for title: Fashion
# PageError for title: Michael Covel
# PageError for title: Neal Mohan
# PageError for title: Aubrey Gordon
# PageError for title: Mia Khalifa
# PageError for title: Bronze Age Pervert
# PageError for title: Donut Media
# PageError for title: Justin Long
# PageError for title: Gemma Collins
# PageError for title: Google Forms
# PageError for title: Brittany Broski
# PageError for title: Google Classroom
# PageError for title: Rich Miner
# PageError for title: Gento (song)
# PageError for title: Twitter, Inc.
# PageError for title: Kate Mara
# PageError for title: Jay Ellis
# PageError for title: Josh Allen
# PageError for title: Auto-GPT
# PageError for title: ChatGPT
# PageError for title: Pixel Fold
# PageError for title: Noclip
# PageError for title: Widevine
# PageError for title: The Daily Wire
# PageError for title: The Game Awards 2021
# PageError for title: Giovanna Fletcher
# PageError for title: Dua Lipa
# PageError for title: Steven Hyden
# PageError for title: GPT-4
# PageError for title: CGP Grey
# PageError for title: Keemstar
# PageError for title: Lili Reinhart
# PageError for title: Google
# PageError for title: Ken Suson
# PageError for title: Casey Frey
# PageError for title: Bruce Lipton
# PageError for title: Google Keep
# PageError for title: Kemah Bob
# PageError for title: The Last of Us Part II
# PageError for title: Guz Khan
# PageError for title: Ken Jennings
# PageError for title: Justin de Dios
# PageError for title: Karl Jobst
# PageError for title: Shawn Christensen
# PageError for title: NPR
# PageError for title: Anti-vaccine activism
# PageError for title: The Game Awards 2022
# PageError for title: Jodie Harsh
# PageError for title: Eric Nam
# PageError for title: Demi Moore
# PageError for title: Logan Paul
# PageError for title: Jeff Wittek
# PageError for title: Mean Girls
# PageError for title: Trey Wingo
# PageError for title: Alastair Campbell
# PageError for title: Google Search
# PageError for title: Addison Rae
# PageError for title: Lemonada Media
# PageError for title: QAnon
# PageError for title: LeVar Burton
# PageError for title: Belle Delphine
# PageError for title: Hopepunk
# PageError for title: Elyse Willems
# PageError for title: Jean-Michel Basquiat
# PageError for title: Pat Sajak
# PageError for title: Google Chrome
# PageError for title: Greta Thunberg
# PageError for title: IOS 16
# PageError for title: God of War (2018 video game)
# PageError for title: Pet Sounds
# PageError for title: Godzilla (2014 film)
# PageError for title: United Airlines Flight 232
# PageError for title: Steve Jobs
# PageError for title: Bazball
# PageError for title: Dream (YouTuber)
# PageError for title: SoundCloud
# PageError for title: Truth Be Told (2019 TV series)
# PageError for title: Lilly Singh
# PageError for title: Kylie Jenner
# PageError for title: Veem
# PageError for title: Norm Macdonald
# PageError for title: AlphaGo
# PageError for title: Kendall Jenner
# PageError for title: Arthur (TV series)
# PageError for title: NewJeans
# PageError for title: Dominic Fike
# PageError for title: Social bookmarking
# PageError for title: Red Red Wine
# PageError for title: Sergey Brin
# PageError for title: Counting Crows
# PageError for title: List of YouTubers
# PageError for title: The Little Mermaid (2023 film)
# PageError for title: IOS 15
# PageError for title: Breaking Bad
# PageError for title: BookTok
# PageError for title: EPUB
# PageError for title: The Book Job
# PageError for title: CreateSpace
# PageError for title: Comic book
# PageError for title: Oni Press
# PageError for title: The Rosie Project
# PageError for title: Arbor House
# PageError for title: BookBub
# PageError for title: Benjamin Hoff
# PageError for title: First Comics
# PageError for title: Pearson Education
# PageError for title: WWE Books
# PageError for title: Gold Key Comics
# PageError for title: André Rieu
# PageError for title: Timas Publishing Group
# PageError for title: Walsworth Publishing Company
# PageError for title: American Dirt
# PageError for title: Bark at the Moon
# PageError for title: Wattpad
# PageError for title: Dan Poynter
# PageError for title: American automobile industry in the 1950s
# PageError for title: Industrial Revolution
# PageError for title: Record producer
# PageError for title: E-reader
# PageError for title: Fashion
# PageError for title: Baen Books
# PageError for title: Z-Library
# PageError for title: Ben Shapiro
# PageError for title: Casino
# PageError for title: Comic book
# PageError for title: List of comic books
# PageError for title: Steve Rolston
# PageError for title: Johnny Test
# PageError for title: Canadian comics
# PageError for title: Discworld
# PageError for title: Webcomic
# PageError for title: Drawn & Quarterly
# PageError for title: It's a Good Life, If You Don't Weaken
# PageError for title: Hernandez brothers
# PageError for title: Butcher Billy
# PageError for title: Oni Press
# PageError for title: Neil Gaiman
# PageError for title: My Friend Dahmer
# PageError for title: Dead by Daylight
# PageError for title: Nausicaä of the Valley of the Wind (manga)
# PageError for title: Todd McFarlane
# PageError for title: Killer Kane
# PageError for title: The Walking Dead (comic book)
# PageError for title: Nimona
# PageError for title: Kai Starr
# PageError for title: Dead Alewives
# PageError for title: Mad (magazine)
# PageError for title: Princess Knight
# PageError for title: Antony Johnston
# PageError for title: Moomins
# PageError for title: Toon Books
# PageError for title: Alice Oseman
# PageError for title: Dragon Hoops
# PageError for title: Reed College
# PageError for title: Max Brooks
# PageError for title: Gender Queer
# PageError for title: Novel
# PageError for title: Dan Abnett
# PageError for title: John Carter of Mars
# PageError for title: Thomas Yeates
# PageError for title: Walter Moers
# PageError for title: Baltimore (comics)
# PageError for title: Nvidia GTC
# PageError for title: ReBoot
# PageError for title: Alice in Borderland (TV series)
# PageError for title: Avatar (2009 film)
# PageError for title: Turing Award
# PageError for title: James Cameron
# PageError for title: Deepfake
# PageError for title: Peter Cushing
# PageError for title: Tron: Legacy
# PageError for title: History of Eastern role-playing video games
# PageError for title: Fashion
# PageError for title: Fashion week
# PageError for title: New York Fashion Week
# PageError for title: Dark academia
# PageError for title: Miniskirt
# PageError for title: Kate Moss
# PageError for title: RSVP
# PageError for title: RinRin Doll
# PageError for title: Gigi Hadid
# PageError for title: La Sape
# PageError for title: Anna Wintour
# PageError for title: Kendall Jenner
# PageError for title: CL (rapper)
# PageError for title: Hi-Fi Rush
# PageError for title: Roland Barthes
# PageError for title: Spider-Man 2 (2023 video game)
# PageError for title: François Sagat
# PageError for title: Monokini
# PageError for title: Zuri Hall
# PageError for title: Zoolander
# PageError for title: Tom Ford
# PageError for title: The Game Awards 2022
# PageError for title: Grace Kelly
# PageError for title: Jisoo
# PageError for title: Ines Di Santo
# PageError for title: Bermuda shorts
# PageError for title: Pattie Boyd
# PageError for title: Marc Jacobs
# PageError for title: Jeanne Beker
# PageError for title: Leo DaSilva
# PageError for title: Virgil Abloh
# PageError for title: Canada
# PageError for title: Sneaker collecting
# PageError for title: Flapper
# PageError for title: LVMH
# PageError for title: George Davies (retailer)
# PageError for title: Clueless
# PageError for title: Louis Vuitton
# PageError for title: Kilt
# PageError for title: Sienna Miller
# PageError for title: Esther Perel
# PageError for title: Ynet
# PageError for title: Inflation
# PageError for title: Hanbok
# PageError for title: Alexander McQueen
# PageError for title: Supermodel Me
# PageError for title: Mia Khalifa
# PageError for title: Crocs
# PageError for title: Lee Ju-myoung
# PageError for title: Kathy Ireland
# PageError for title: Charli D'Amelio
# PageError for title: Competitive intelligence
# PageError for title: Lauryn Hill
# PageError for title: International Men's Day
# PageError for title: Astrological progression
# PageError for title: Vick Hope
# PageError for title: Ken Suson
# PageError for title: Windsor Castle
# PageError for title: Coco Chanel
# PageError for title: Chloe Ting
# PageError for title: Art dealer
# PageError for title: Art Basel
# PageError for title: Art handler
# PageError for title: Alexandra Hedison
# PageError for title: Fry Art Gallery
# PageError for title: Keith Haring
# PageError for title: Peter Doig
# PageError for title: Pop art
# PageError for title: Wallach Art Gallery
# PageError for title: Hamburger Kunsthalle
# PageError for title: National Art Gallery, Sri Lanka
# PageError for title: David Hockney

# %%
# Create the CSV from the DataFrame
entr_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Entertainment.csv"
entr_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Entertainment = pd.read_csv("./Data/Entertainment.csv")
Entertainment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Sports

# %%
# Define the topics and subtopics
title = {
    'Sports': [
        'Cricket','CricketT20', 'Cricket World Cup'
        'Major sporting events', 'Sports analytics', 'Sports history',
        'Olympic Games developments', 'World Cup soccer', 'Tennis Grand Slams',
        'NBA and basketball trends', 'NFL and American football updates', 'MLB and baseball news',
        'NHL and hockey insights', 'Golf tournaments', 'Boxing and MMA events',
        'Track and field athletics', 'Swimming competitions', 'Gymnastics championships',
        'Extreme sports', 'E-sports and competitive gaming', 'Cricket updates',
        'Rugby league and union', 'Formula 1 and motorsports', 'Cycling events like Tour de France',
        'Winter sports and skiing', 'Marathons and endurance races', 'Horse racing',
        'Sports nutrition and fitness trends', 'Sports psychology', 'Youth and college sports',
        'Sports technology advancements', 'Sports medicine and injuries', 'Women in sports',
        'Sports governance and policies', 'International sports diplomacy', 'Sports and environmental sustainability',
        'Athlete endorsements and sponsorships', 'Sports broadcasting and media rights', 'Fan cultures and sports communities'
    ],
}


# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: 2023 Cricket World Cup
# PageError for title: 2007 Cricket World Cup
# PageError for title: 2015 Cricket World Cup
# PageError for title: 1992 Cricket World Cup
# PageError for title: 2011 Cricket World Cup
# PageError for title: 1975 Cricket World Cup
# PageError for title: 1983 Cricket World Cup
# PageError for title: 2023 Cricket World Cup Qualifier
# PageError for title: Twenty20
# PageError for title: Shubman Gill
# PageError for title: Shan Masood
# PageError for title: Kane Williamson
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: 1987 Cricket World Cup squads
# PageError for title: 2006 Under-19 Cricket World Cup
# PageError for title: Jiminy Cricket
# PageError for title: Pat Cummins
# PageError for title: 1979 Cricket World Cup squads
# PageError for title: Asia Cup
# PageError for title: Babar Azam
# PageError for title: Jay Shah
# PageError for title: 2004 Under-19 Cricket World Cup
# PageError for title: 2022 Under-19 Cricket World Cup
# PageError for title: Mohammed Shami
# PageError for title: Viv Richards
# PageError for title: Mole cricket
# PageError for title: Mohammad Kaif
# PageError for title: Tamim Iqbal
# PageError for title: MS Dhoni
# PageError for title: Brian Lara Cricket (1998 video game)
# PageError for title: 2020 Under-19 Cricket World Cup squads
# PageError for title: ICC Women's T20 World Cup
# PageError for title: 2002 Under-19 Cricket World Cup
# PageError for title: Gray-Nicolls
# PageError for title: Mitchell Starc
# PageError for title: Adam Zampa
# PageError for title: The Gabba
# PageError for title: 2015 Cricket World Cup squads
# PageError for title: 2011 Cricket World Cup squads
# PageError for title: Brendon McCullum
# PageError for title: Twenty20
# PageError for title: ICC Women's T20 World Cup
# PageError for title: Chris Gayle
# PageError for title: SA20
# PageError for title: Babar Azam
# PageError for title: Jos Buttler
# PageError for title: Ellyse Perry
# PageError for title: Mohammed Shami
# PageError for title: Shaheen Afridi
# PageError for title: Rahul Chahar
# PageError for title: Suresh Raina
# PageError for title: Brendon McCullum
# PageError for title: Suryakumar Yadav
# PageError for title: Aiden Markram
# PageError for title: Kamran Akmal
# PageError for title: Bas de Leede
# PageError for title: Kane Williamson
# PageError for title: 2023 Cricket World Cup
# PageError for title: Asia Cup
# PageError for title: James Neesham
# PageError for title: Fred Klaassen
# PageError for title: Tamim Iqbal
# PageError for title: 2025 ICC Champions Trophy
# PageError for title: Alex Hales
# PageError for title: Brad Hogg
# PageError for title: Lockie Ferguson
# PageError for title: MS Dhoni
# PageError for title: Sanju Samson
# PageError for title: Pat Cummins
# PageError for title: 2025 Under-19 Women's T20 World Cup
# PageError for title: Sam Curran
# PageError for title: 2022 Asia Cup
# PageError for title: Salman Butt
# PageError for title: Trent Boult
# PageError for title: Tim David
# PageError for title: Imad Wasim
# PageError for title: Chris Woakes
# PageError for title: Shikhar Dhawan
# PageError for title: Ashish Nehra
# PageError for title: Ahsan Raza
# PageError for title: Hunain Shah
# PageError for title: Marco Jansen
# PageError for title: Shan Masood
# PageError for title: Meg Lanning
# PageError for title: Steve Smith (cricketer)
# PageError for title: Tim Southee
# PageError for title: Joe Root
# PageError for title: Moeen Ali
# PageError for title: Mitchell Starc
# PageError for title: Sara Kennedy
# PageError for title: AB de Villiers
# PageError for title: Paarl Royals
# PageError for title: 1975 Cricket World Cup
# PageError for title: Asia Cup
# PageError for title: MS Dhoni
# PageError for title: Ellyse Perry
# PageError for title: Ricky Ponting
# PageError for title: Sport in South Africa
# PageError for title: Jacques Kallis
# PageError for title: 2023 FIFA Women's World Cup
# PageError for title: Arjuna Award
# PageError for title: Sport in England
# PageError for title: 83 (film)
# PageError for title: Shane Warne
# PageError for title: 2003 Rugby World Cup
# PageError for title: Don Bradman
# PageError for title: 2023 PDC World Darts Championship
# PageError for title: BeIN Sports
# PageError for title: Eurosport
# PageError for title: Sweet Caroline
# PageError for title: Big Bash League
# PageError for title: Sport in Victoria
# PageError for title: Adelaide Oval
# PageError for title: US Open (tennis)
# PageError for title: Match fixing
# PageError for title: Roy and HG
# PageError for title: Farokh Engineer
# PageError for title: FIBA Women's Basketball World Cup
# PageError for title: Australian Open
# PageError for title: Laura Davies
# PageError for title: Imran Khan
# PageError for title: MKM Stadium
# PageError for title: FIVB Volleyball Men's World Championship
# PageError for title: ITV Sport
# PageError for title: Golf in the United States
# PageError for title: Ernie Els
# PageError for title: 1896 Summer Olympics
# PageError for title: Talksport
# PageError for title: Tennis
# PageError for title: Limerick
# PageError for title: Turf Moor
# PageError for title: Oundle School
# PageError for title: Zach Lowe
# PageError for title: Predictive analytics
# PageError for title: Druski
# PageError for title: Tony Khan
# PageError for title: Alison Lukan
# PageError for title: Sam Hinkie
# PageError for title: Erika Nardini
# PageError for title: Pat McAfee
# PageError for title: Cynthia Frelund
# PageError for title: Godzilla (2014 film)
# PageError for title: Suzy Kolber
# PageError for title: Kyle Dubas
# PageError for title: 1998 NFC Championship Game
# PageError for title: Tim Chartier
# PageError for title: Axon Sports
# PageError for title: Baseball Prospectus
# PageError for title: Nike, Inc.
# PageError for title: His & Hers (TV program)
# PageError for title: Canada
# PageError for title: FloSports
# PageError for title: Zack Scott
# PageError for title: Dan Abrams
# PageError for title: Playtech
# PageError for title: CrazyGames
# PageError for title: 1988 Summer Olympics medal table
# PageError for title: Ryan Trahan
# PageError for title: Bill Gates
# PageError for title: Substack
# PageError for title: Ted Lasso
# PageError for title: Hattrick (video game)
# PageError for title: John Chayka
# PageError for title: Carvana
# PageError for title: Erling Haaland
# PageError for title: The New York Times
# PageError for title: Shane Battier
# PageError for title: 2023 Jacksonville Jaguars season
# PageError for title: Italy
# PageError for title: Slingbox
# PageError for title: Danica Patrick
# PageError for title: PayPal
# PageError for title: Inter Miami CF
# PageError for title: 2000 Summer Olympics medal table
# PageError for title: 1912 Summer Olympics medal table
# PageError for title: Squid Game
# PageError for title: Elon University
# PageError for title: Jeff Bezos
# PageError for title: YouGov
# PageError for title: David Stearns
# PageError for title: Adriana Lima
# PageError for title: Bryant University
# PageError for title: My Hero Academia
# PageError for title: Microsoft Office
# PageError for title: Xu Kai
# PageError for title: Donda West
# PageError for title: Charles Barkley
# PageError for title: Leeds
# PageError for title: Under Armour
# PageError for title: Kenya
# PageError for title: Reiwa era
# PageError for title: Amer Sports
# PageError for title: BeIN Sports
# PageError for title: Vin Scully
# PageError for title: Buffalo Bulls football
# PageError for title: Andrea Kremer
# PageError for title: Patrick Mahomes
# PageError for title: EA Sports
# PageError for title: Race and ethnicity in the NBA
# PageError for title: JD Sports
# PageError for title: Green Bay Packers
# PageError for title: Jim Nantz
# PageError for title: Super Bowl XLII
# PageError for title: SportsCenter
# PageError for title: Matt Millen
# PageError for title: Boardsport
# PageError for title: Wii Sports
# PageError for title: Jimbo Fisher
# PageError for title: Sony Sports Network
# PageError for title: History of games
# PageError for title: Nike, Inc.
# PageError for title: Cris Carter
# PageError for title: Joe Burrow
# PageError for title: 2019 Varsity Sports (South Africa)
# PageError for title: Rachel Luba
# PageError for title: IOS version history
# PageError for title: JJB Sports
# PageError for title: One Sports
# PageError for title: Yale Bulldogs
# PageError for title: SonyLIV
# PageError for title: Dick Enberg
# PageError for title: Black History Month
# PageError for title: Sega Sports R&D
# PageError for title: History of WWE
# PageError for title: 2010 Winter Olympics
# PageError for title: 1972 Summer Olympics
# PageError for title: 2022 Winter Olympics
# PageError for title: 1988 Winter Olympics
# PageError for title: 1988 Summer Olympics
# PageError for title: 1976 Summer Olympics
# PageError for title: 1980 Summer Olympics
# PageError for title: Bids for the 2036 Summer Olympics
# PageError for title: 2018 Winter Olympics
# PageError for title: Winter Olympics (video game)
# PageError for title: 1972 Winter Olympics
# PageError for title: 1960 Winter Olympics
# PageError for title: 1984 Summer Olympics
# PageError for title: 1984 Winter Olympics
# PageError for title: 2026 Winter Olympics
# PageError for title: 1900 Summer Olympics
# PageError for title: 2023 Pan American Games
# PageError for title: 2022 Asian Games
# PageError for title: Doodle Champion Island Games
# PageError for title: 2026 Asian Games
# PageError for title: 1964 Summer Olympics
# PageError for title: 2025 SEA Games
# PageError for title: 2027 Pan American Games
# PageError for title: 2022 Winter Olympics medal table
# PageError for title: 1951 Asian Games
# PageError for title: List of PlayStation 2 games (A–K)
# PageError for title: 2002 Commonwealth Games
# PageError for title: List of 2024 Summer Olympics broadcasters
# PageError for title: List of Sega video games
# PageError for title: 2000 Summer Olympics opening ceremony
# PageError for title: 2023 SEA Games
# PageError for title: 1990 Asian Games
# PageError for title: BRICS Games
# PageError for title: 2030 Mediterranean Games
# PageError for title: History of games
# PageError for title: 2002 Asian Games
# PageError for title: Highland games
# PageError for title: 2032 Summer Paralympics
# PageError for title: 1976 Summer Olympics medal table
# PageError for title: 2019 SEA Games
# PageError for title: Sharron Davies
# PageError for title: 2005 SEA Games
# PageError for title: Peggy Fleming
# PageError for title: Rafer Johnson
# PageError for title: Geoff Capes
# PageError for title: Football at the 1924 Summer Olympics
# PageError for title: 1984 Summer Olympics medal table
# PageError for title: Olympic Gold (video game)
# PageError for title: 2016 in video games
# PageError for title: Dave Brailsford
# PageError for title: Sega Sports R&D
# PageError for title: Judo
# PageError for title: Lane Hutson
# PageError for title: Mediatonic
# PageError for title: Koobits
# PageError for title: 2021 SEA Games
# PageError for title: John Grimek
# PageError for title: Pacific Drive (video game)
# PageError for title: NAOC
# PageError for title: Cutter Gauthier
# PageError for title: Katarina Johnson-Thompson
# PageError for title: Les Mills
# PageError for title: Swin Cash
# PageError for title: Center Parc Stadium
# PageError for title: Ryan Suter
# PageError for title: Video games in Belgium
# PageError for title: Alexi Pappas
# PageError for title: Emily Sonnett
# PageError for title: Tan Boon Heong
# PageError for title: Aron Baynes
# PageError for title: USA Baseball
# PageError for title: Steve Ovett
# PageError for title: Ryan Donato
# PageError for title: Jordan Clarkson
# PageError for title: Eileen Gu
# PageError for title: 2025 FIFA Beach Soccer World Cup
# PageError for title: 2018 FIFA World Cup
# PageError for title: 1970 FIFA World Cup
# PageError for title: 1994 FIFA World Cup
# PageError for title: Julie Ertz
# PageError for title: 2025 FIFA Club World Cup
# PageError for title: Landon Donovan
# PageError for title: Rose Lavelle
# PageError for title: Mia Hamm
# PageError for title: Carli Lloyd
# PageError for title: WMF World Cup
# PageError for title: World Cup 98 (video game)
# PageError for title: BMO Field
# PageError for title: 2023 Cricket World Cup
# PageError for title: Kelley O'Hara
# PageError for title: 1930 FIFA World Cup
# PageError for title: 2023 FIFA Women's World Cup
# PageError for title: FIFA U-20 World Cup
# PageError for title: 2007 FIFA Women's World Cup
# PageError for title: 2019 FIFA U-17 World Cup
# PageError for title: 1986 FIFA World Cup
# PageError for title: Tobin Heath
# PageError for title: 2015 Cricket World Cup
# PageError for title: 1934 FIFA World Cup
# PageError for title: 1994 FIFA World Cup squads
# PageError for title: Timothy Weah
# PageError for title: 1930 FIFA World Cup squads
# PageError for title: Alphonso Davies
# PageError for title: 2022 FIFA World Cup broadcasting rights
# PageError for title: 1974 FIFA World Cup
# PageError for title: 2006 FIFA World Cup (video game)
# PageError for title: Brad Guzan
# PageError for title: Trinity Rodman
# PageError for title: Marla Messing
# PageError for title: 2023 Leagues Cup
# PageError for title: Christian Pulisic
# PageError for title: 2002 FIFA World Cup final
# PageError for title: Shaolin Soccer
# PageError for title: FIFA World Cup on NBC
# PageError for title: Marta (footballer)
# PageError for title: Michelle Akers
# PageError for title: 1990 FIFA World Cup
# PageError for title: South Africa women's national soccer team
# PageError for title: 2022 FIFA World Cup squads
# PageError for title: 2022 FIFA World Cup qualification (CAF)
# PageError for title: 2002 FIFA World Cup (video game)
# PageError for title: 2022 FIFA World Cup Group B
# PageError for title: Men's FIH Hockey World Cup
# PageError for title: Harry Kewell
# PageError for title: Emily Sonnett
# PageError for title: Tim Howard
# PageError for title: 1994 FIFA World Cup final
# PageError for title: FC Dallas
# PageError for title: Jill Ellis
# PageError for title: Lindsey Horan
# PageError for title: 2007 World Cup
# PageError for title: John Herdman
# PageError for title: 1978 FIFA World Cup
# PageError for title: 1950 FIFA World Cup
# PageError for title: Christen Press
# PageError for title: 2002 FIFA World Cup Group F
# PageError for title: Sport in South Africa
# PageError for title: Maynor Figueroa
# PageError for title: Striker (video game)
# PageError for title: 1958 FIFA World Cup squads
# PageError for title: Sam Mewis
# PageError for title: 2003 Rugby World Cup
# PageError for title: ICC Women's T20 World Cup
# PageError for title: Kristine Lilly
# PageError for title: 2002 FIFA World Cup knockout stage
# PageError for title: Kasey Keller
# PageError for title: 2006 FIFA World Cup qualification (UEFA)
# PageError for title: Cyle Larin
# PageError for title: FIFA 06
# PageError for title: 2006 FIFA World Cup final
# PageError for title: Brenden Aaronson
# PageError for title: 2023 FIBA Basketball World Cup
# PageError for title: 2021 FIFA U-20 World Cup
# PageError for title: CONCACAF Gold Cup
# PageError for title: 1934 FIFA World Cup squads
# PageError for title: Crystal Dunn
# PageError for title: 1954 FIFA World Cup
# PageError for title: 2022 MLS Cup Playoffs
# PageError for title: 2000 World Cup
# PageError for title: Hugo Sánchez
# PageError for title: Freddy Adu
# PageError for title: 2024 AFC Futsal Asian Cup
# PageError for title: 2031 Rugby World Cup
# PageError for title: Lori Lindsey
# PageError for title: Allie Long
# PageError for title: Paolo Maldini
# PageError for title: Tyler Adams
# PageError for title: Shaun Wright-Phillips
# PageError for title: All-time tennis records – Women's singles
# PageError for title: Serena Williams
# PageError for title: Rafael Nadal
# PageError for title: US Open (tennis)
# PageError for title: Venus Williams
# PageError for title: Tennis
# PageError for title: Roger Federer
# PageError for title: Australian Open
# PageError for title: Rod Laver
# PageError for title: Mark Edmondson
# PageError for title: 2023 ATP Tour
# PageError for title: AO Tennis 2
# PageError for title: Alex Eala
# PageError for title: Holger Rune
# PageError for title: Annabel Croft
# PageError for title: Chris Evert
# PageError for title: Tony Roche
# PageError for title: Simona Halep
# PageError for title: 2022 French Open
# PageError for title: Fred Perry
# PageError for title: Li Na
# PageError for title: Bob Bryan
# PageError for title: 1988 Grand Prix (tennis)
# PageError for title: Daniil Medvedev
# PageError for title: Mark Woodforde
# PageError for title: Leylah Fernandez
# PageError for title: Pat Rafter
# PageError for title: 2023 French Open
# PageError for title: Sumit Nagal
# PageError for title: 2023 US Open (tennis)
# PageError for title: Justine Henin
# PageError for title: Casper Ruud
# PageError for title: Andy Murray
# PageError for title: Fred Stolle
# PageError for title: Ken Rosewall
# PageError for title: Alexander Blockx
# PageError for title: Bobby Riggs
# PageError for title: 1987 Grand Prix (tennis)
# PageError for title: 2023 WTA Tour
# PageError for title: 1984 Grand Prix (tennis)
# PageError for title: Ben Shelton
# PageError for title: Daniel Nestor
# PageError for title: Monica Seles
# PageError for title: Ma Long
# PageError for title: Virginia Wade
# PageError for title: Sue Barker
# PageError for title: 2007 ATP Tour
# PageError for title: Boris Becker
# PageError for title: Sloane Stephens
# PageError for title: John Peers
# PageError for title: Mike Bryan
# PageError for title: 1985 Grand Prix (tennis)
# PageError for title: Petr Korda
# PageError for title: 1983 Grand Prix (tennis)
# PageError for title: Tennis at the 2020 Summer Olympics – Men's singles
# PageError for title: 2022 WTA Tour
# PageError for title: 2023 ATP Finals
# PageError for title: Leo Borg
# PageError for title: Sara Errani
# PageError for title: Zina Garrison
# PageError for title: 2008 ATP Tour
# PageError for title: List of Wimbledon ladies' singles champions
# PageError for title: Dominic Thiem
# PageError for title: Zhang Jike
# PageError for title: Michael Stich
# PageError for title: Vincent Richards
# PageError for title: 2022 US Open – Men's singles
# PageError for title: Ryan Harrison
# PageError for title: Pat Cash
# PageError for title: Rafael Nadal career statistics
# PageError for title: Helen Wills
# PageError for title: 1971 Grand Prix (tennis)
# PageError for title: Michael Chang
# PageError for title: 2021 French Open
# PageError for title: Ken Flach
# PageError for title: Budge Patty
# PageError for title: Tennis ball
# PageError for title: Arthur Fils
# PageError for title: Tennis on NBC
# PageError for title: NBA TV
# PageError for title: Kobe Bryant
# PageError for title: 2020 NBA Finals
# PageError for title: NBA G League
# PageError for title: Draymond Green
# PageError for title: Kevin Durant
# PageError for title: NBA 2K16
# PageError for title: 2019 NBA Finals
# PageError for title: Patty Mills
# PageError for title: Chris Paul
# PageError for title: David Stern
# PageError for title: Chicago Bulls
# PageError for title: Jeff Van Gundy
# PageError for title: Kyrie Irving
# PageError for title: NBA 2K6
# PageError for title: Jerry Stackhouse
# PageError for title: Chris Bosh
# PageError for title: 2020 United States men's Olympic basketball team
# PageError for title: Vlade Divac
# PageError for title: Caris LeVert
# PageError for title: Kenny Wooten
# PageError for title: Tyler Ulis
# PageError for title: Brad Stevens
# PageError for title: Lute Olson
# PageError for title: Walt Williams
# PageError for title: Dick Vitale
# PageError for title: Nike, Inc.
# PageError for title: Sheck Wes
# PageError for title: Moda Center
# PageError for title: Las Vegas Aces
# PageError for title: 2011 NCAA Division I men's basketball tournament
# PageError for title: Duck Dynasty
# PageError for title: Newsreaders
# PageError for title: Sneaker collecting
# PageError for title: Double Dribble (video game)
# PageError for title: List of 2K games
# PageError for title: Gym shorts
# PageError for title: 2021 WNBA Finals
# PageError for title: Dime Magazine
# PageError for title: Will McDonald
# PageError for title: ESPN on ABC
# PageError for title: Hamline University
# PageError for title: YouTube TV
# PageError for title: Steve Ballmer
# PageError for title: Southland Conference
# PageError for title: University of Utah
# PageError for title: 2023 in American television
# PageError for title: Adderall
# PageError for title: Whats Poppin
# PageError for title: 1976 in the United States
# PageError for title: Monster Cable
# PageError for title: Kim Jong Un
# PageError for title: 2023 in Philippine television
# PageError for title: Fujii Kaze
# PageError for title: Bilibili
# PageError for title: New York City
# PageError for title: Chris Gethard
# PageError for title: Honestly, Nevermind
# PageError for title: USA Today
# PageError for title: Statistics of the COVID-19 pandemic in Brazil
# PageError for title: Washington, D.C.
# PageError for title: Cai Xukun
# PageError for title: Normani
# PageError for title: China
# PageError for title: Inland Empire
# PageError for title: 2023 NFL season
# PageError for title: Madden NFL 22
# PageError for title: Super Bowl
# PageError for title: James Harrison (American football)
# PageError for title: 2021 NFL season
# PageError for title: American Underdog
# PageError for title: Adrian Peterson
# PageError for title: Chuck Hughes
# PageError for title: Jordan Mailata
# PageError for title: 2022 NFL season
# PageError for title: 2007 NFL season
# PageError for title: NFL 2K
# PageError for title: Kenny Pickett
# PageError for title: Monday Night Football
# PageError for title: Madden NFL 21
# PageError for title: Steve Smith Sr.
# PageError for title: Myles Garrett
# PageError for title: Jake Plummer
# PageError for title: Matt Prater
# PageError for title: Tom Brady
# PageError for title: Bruce Irvin
# PageError for title: Michael Vick
# PageError for title: 2018 NFL season
# PageError for title: Darren Waller
# PageError for title: 2023 NFL Draft
# PageError for title: Jill Arrington
# PageError for title: Josh Allen
# PageError for title: 2020 NFL season
# PageError for title: Joe Haden
# PageError for title: Jason Verrett
# PageError for title: Akili Smith
# PageError for title: Jason Myers
# PageError for title: Zack Martin
# PageError for title: Shaun Gayle
# PageError for title: Brandin Cooks
# PageError for title: Marcus Peters
# PageError for title: Eric Reid
# PageError for title: Kyler Murray
# PageError for title: Mike Rozier
# PageError for title: Peyton Manning
# PageError for title: Michael Strahan
# PageError for title: Jeremy Maclin
# PageError for title: Ryan Shazier
# PageError for title: Kenny Golladay
# PageError for title: Rashaan Evans
# PageError for title: Allegiant Stadium
# PageError for title: Walter Payton
# PageError for title: Tee Higgins
# PageError for title: Madden NFL 08
# PageError for title: Will Grier
# PageError for title: Cam Newton
# PageError for title: Ahmad Rashad
# PageError for title: Robert Alford (American football)
# PageError for title: NFL on ABC
# PageError for title: Joe Burrow
# PageError for title: Boomer Esiason
# PageError for title: Warrick Dunn
# PageError for title: Chicago Bears
# PageError for title: Davis Webb
# PageError for title: Jaire Alexander
# PageError for title: Jimmie Ward
# PageError for title: Damar Hamlin
# PageError for title: Madden NFL 2002
# PageError for title: C. J. Beathard
# PageError for title: Ron Dayne
# PageError for title: 2022 NFL Draft
# PageError for title: Ha Ha Clinton-Dix
# PageError for title: Adam Thielen
# PageError for title: Tennessee Titans
# PageError for title: Las Vegas Raiders
# PageError for title: Bo Davis
# PageError for title: 2000 NFL season
# PageError for title: Super Bowl LI
# PageError for title: Drew Brees
# PageError for title: Devin White
# PageError for title: Tyron Smith
# PageError for title: Jerry Glanville
# PageError for title: Alvin Kamara
# PageError for title: Marc Bulger
# PageError for title: Jordan Poyer
# PageError for title: Calvin Ridley
# PageError for title: George Blanda
# PageError for title: Super Bowl LVII
# PageError for title: Brett Favre
# PageError for title: Charissa Thompson
# PageError for title: Carson Wentz
# PageError for title: Aaron Rodgers
# PageError for title: Terry Beckner
# PageError for title: Super Bowl LVIII
# PageError for title: Madden NFL 2003
# PageError for title: Brian Brohm
# PageError for title: Cade McNown
# PageError for title: Darren Sproles
# PageError for title: Dee Ford
# PageError for title: K. J. Wright
# PageError for title: Green Bay Packers
# PageError for title: Nick Foles
# PageError for title: Bradley Roby
# PageError for title: New York Jets
# PageError for title: Emmanuel Sanders
# PageError for title: Mace (wrestler)
# PageError for title: Marqise Lee
# PageError for title: Los Angeles Chargers
# PageError for title: Andrus Peat
# PageError for title: National Football League 2000s All-Decade Team
# PageError for title: Brittany Mahomes
# PageError for title: Jon Gruden
# PageError for title: Jamie Gillan
# PageError for title: Kelvin Benjamin
# PageError for title: Josh Pederson
# PageError for title: Craig Breslow
# Error for title: Joe Espada, retrying (1/3)
# PageError for title: MLB International
# PageError for title: Billy Beane
# PageError for title: 2023 World Baseball Classic
# PageError for title: Corey Seager
# PageError for title: 2026 World Baseball Classic
# PageError for title: 2023 Major League Baseball season
# PageError for title: 2022 Major League Baseball All-Star Game
# PageError for title: 2022 Major League Baseball season
# PageError for title: Pete Alonso
# PageError for title: Mookie Betts
# PageError for title: Zac Gallen
# PageError for title: Joey Gallo
# PageError for title: Kerry Wood
# PageError for title: MLB on TBS
# PageError for title: Adolis García
# PageError for title: Francisco Lindor
# PageError for title: Wander Franco
# PageError for title: 2021 Major League Baseball postseason
# PageError for title: Anthony Volpe
# PageError for title: Kyle Seager
# PageError for title: 2024 Baseball Hall of Fame balloting
# PageError for title: Blake Snell
# PageError for title: Jake Bauers
# PageError for title: Aroldis Chapman
# PageError for title: Kyle Tucker
# PageError for title: Billy Bean
# PageError for title: Chris Sale
# PageError for title: Trea Turner
# PageError for title: Casey Schmitt
# PageError for title: Ken Griffey Jr.
# PageError for title: Julio Urías
# PageError for title: Craig Counsell
# PageError for title: Chipper Jones
# PageError for title: Pete Crow-Armstrong
# PageError for title: David Robertson (baseball)
# PageError for title: Miami Marlins
# PageError for title: Rob Manfred
# PageError for title: Rhys Hoskins
# PageError for title: Zack Gelof
# PageError for title: 2022 Baseball Hall of Fame balloting
# PageError for title: Hank Aaron
# PageError for title: Jon Gray
# PageError for title: Christopher Morel
# PageError for title: Derek Jeter
# PageError for title: Yu Darvish
# PageError for title: Trayce Thompson
# PageError for title: Mike Trout
# PageError for title: Scott Hatteberg
# PageError for title: George Brett
# PageError for title: Hunter Pence
# PageError for title: Josh Donaldson
# PageError for title: 2020 Major League Baseball season
# PageError for title: Phil Nevin
# PageError for title: Joe Torre
# PageError for title: Robinson Canó
# PageError for title: Sean Gilmartin
# PageError for title: Alek Thomas
# PageError for title: R. A. Dickey
# PageError for title: Luke Jackson (baseball)
# PageError for title: Sarah Langs
# PageError for title: Tom Seaver
# Error for title: Andrés Galarraga, retrying (1/3)
# PageError for title: Jason Giambi
# PageError for title: Brooks Raley
# PageError for title: Jasson Domínguez
# PageError for title: Byron Buxton
# PageError for title: 2019 Major League Baseball season
# PageError for title: Jackie Robinson
# PageError for title: 1965 Major League Baseball draft
# PageError for title: Bud Selig
# PageError for title: Albert Pujols
# PageError for title: Jacob deGrom
# PageError for title: Tyler Glasnow
# PageError for title: David Stearns
# PageError for title: Jack Leiter
# PageError for title: Cecil Fielder
# PageError for title: Jonah Heim
# PageError for title: Bruce Bochy
# PageError for title: Nolan Ryan
# PageError for title: Gavin Lux
# PageError for title: Designated hitter
# PageError for title: Barry Bonds
# PageError for title: James McCann (baseball)
# PageError for title: Willson Contreras
# PageError for title: Ian Kinsler
# PageError for title: Masyn Winn
# PageError for title: Globe Life Field
# PageError for title: Nathaniel Lowe
# PageError for title: Matt Harvey
# PageError for title: Vida Blue
# PageError for title: Jackson Holliday
# PageError for title: Alek Manoah
# PageError for title: Ryan Braun
# PageError for title: Chris Chelios
# PageError for title: Craig Button
# PageError for title: Ron MacLean
# PageError for title: Mike Johnston (ice hockey)
# PageError for title: Coors Light
# PageError for title: DraftKings
# PageError for title: Ted Leonsis
# PageError for title: Marv Albert
# PageError for title: Jägermeister
# PageError for title: Charles M. Schulz
# PageError for title: 2018 in American television
# PageError for title: WHPT
# PageError for title: 2023 in American television
# PageError for title: Abbott Elementary
# PageError for title: Brown bear
# PageError for title: 1985 in American television
# PageError for title: Southwestern United States
# PageError for title: Derek Jeter
# PageError for title: Comcast
# PageError for title: Tennessee
# PageError for title: Cablevision
# PageError for title: USS Monitor
# PageError for title: Mariano Rivera
# PageError for title: 2021 in American television
# PageError for title: AXS TV
# PageError for title: 2022 in American television
# PageError for title: Bob Wolff
# PageError for title: Disc golf
# PageError for title: Golf Channel
# PageError for title: LIV Golf
# PageError for title: 2023 LPGA Tour
# PageError for title: Golf in the United States
# PageError for title: Jack Nicklaus
# PageError for title: Golf in India
# PageError for title: Glossary of golf
# PageError for title: LPGA
# PageError for title: Golf in the Philippines
# PageError for title: Code golf
# PageError for title: Gary Player
# PageError for title: Sequoyah Country Club
# PageError for title: 2023 Japan Golf Tour
# PageError for title: Everybody's Golf
# PageError for title: 2021 LPGA Tour
# PageError for title: 2022 LPGA Tour
# PageError for title: Miniature golf
# PageError for title: 2022 Open Championship
# PageError for title: Jon Rahm
# PageError for title: 2023 Masters Tournament
# PageError for title: South Australian Open (golf)
# PageError for title: Samuel Ryder
# PageError for title: Lexi Thompson
# PageError for title: Paul McBeth
# PageError for title: Nelly Korda
# PageError for title: Par (score)
# PageError for title: WGC Championship
# PageError for title: Byron Nelson
# PageError for title: 2023 U.S. Open (golf)
# PageError for title: Patrick Reed
# PageError for title: Golf ball
# PageError for title: Golf in Russia
# PageError for title: Kelly Tilghman
# PageError for title: PGA Tour Champions
# PageError for title: 2024 European Tour
# PageError for title: Nick Faldo
# PageError for title: Lilia Vu
# PageError for title: 2021 Open Championship
# PageError for title: Yin Ruoning
# PageError for title: Gary Woodland
# PageError for title: Brendan Steele
# PageError for title: Conor McGregor
# PageError for title: Holly Holm
# PageError for title: Kimbo Slice
# PageError for title: Victoria Elise
# PageError for title: Tommy Morrison
# PageError for title: Dillon Danis
# PageError for title: Tom Aspinall
# PageError for title: Anderson Silva
# PageError for title: Evolve MMA
# PageError for title: Streetbeefs
# PageError for title: Nate Diaz
# PageError for title: Florian Marku
# PageError for title: Dana White
# PageError for title: Anthony Pettis
# PageError for title: Boxing
# PageError for title: Chase Hooper
# PageError for title: Jimmy Lennon Jr.
# PageError for title: Chael Sonnen
# PageError for title: Nick Diaz
# PageError for title: Marvin Vettori
# PageError for title: Bruce Buffer
# PageError for title: Cris Cyborg
# PageError for title: Jack Della Maddalena
# PageError for title: André Fialho
# PageError for title: Jaron Ennis
# PageError for title: Todd Duffee
# PageError for title: Vale Tudo
# PageError for title: Alan Baudot
# PageError for title: Danyelle Wolf
# PageError for title: Jessica Penne
# PageError for title: Julianna Peña
# PageError for title: Luke Rockhold
# PageError for title: Fernand Lopez
# PageError for title: Don Frye
# PageError for title: Gabi Garcia
# PageError for title: Demsey McKean
# PageError for title: Ray Mercer
# PageError for title: Sergio Pettis
# PageError for title: Shane Carwin
# PageError for title: Jens Pulver
# PageError for title: Tank Abbott
# PageError for title: Amanda Nunes
# PageError for title: Stamp Fairtex
# PageError for title: Mickey Gall
# PageError for title: Ian Machado Garry
# PageError for title: Ray Mancini
# PageError for title: Maryna Moroz
# PageError for title: Nicco Montaño
# PageError for title: Makhmud Muradov
# PageError for title: Michael Bisping
# PageError for title: Floyd Mayweather Jr.
# PageError for title: Johny Hendricks
# PageError for title: Paige VanZant
# PageError for title: Travis Browne
# PageError for title: Bob Sapp
# PageError for title: Dan Hardy
# PageError for title: Lucas Browne
# PageError for title: Tyson Fury
# PageError for title: Muay Thai
# PageError for title: Lerone Murphy
# PageError for title: Petr Yan
# PageError for title: Joselyne Edwards
# PageError for title: Rick Roufus
# PageError for title: Cub Swanson
# PageError for title: Dan Hooker
# PageError for title: Patricio Manuel
# PageError for title: Erik Paulson
# PageError for title: José Aldo
# PageError for title: Jake Paul
# PageError for title: Alexa Grasso
# PageError for title: Trevor Wittman
# PageError for title: Jennifer Maia
# PageError for title: Aaron Pico
# PageError for title: John Wayne Parr
# PageError for title: Mark Godbeer
# PageError for title: Rafael Cordeiro
# PageError for title: Frankie Edgar
# PageError for title: Matheus Nicolau
# PageError for title: Fallon Fox
# PageError for title: Reinier de Ridder
# PageError for title: Ricky Glenn
# PageError for title: Ricardo Mayorga
# PageError for title: Frank Mir
# PageError for title: Robbie Lawler
# PageError for title: Tyron Woodley
# PageError for title: Yoel Romero
# PageError for title: Ben Askren
# PageError for title: Dustin Poirier
# PageError for title: Markus Perez
# PageError for title: Stephan Bonnar
# PageError for title: Dustin Jacoby
# PageError for title: Manel Kape
# PageError for title: Brendan Schaub
# PageError for title: Jimmy Crute
# PageError for title: Hannah Goldy
# PageError for title: Dennis Hallman
# PageError for title: Quinton Jackson
# PageError for title: UFC 8
# PageError for title: Dillian Whyte
# PageError for title: Sport in England
# PageError for title: Justin Tafa
# PageError for title: Athletics at the 2024 Summer Olympics
# PageError for title: Para-athletics
# PageError for title: Track & Field (video game)
# PageError for title: 2022 World Athletics Championships
# PageError for title: KC Lightfoot
# PageError for title: 55 metres
# PageError for title: 2020 United States Olympic trials (track and field)
# PageError for title: 2023 Diamond League
# PageError for title: 1984 United States Olympic trials (track and field)
# PageError for title: 2023 World Athletics Championships
# PageError for title: 1992 United States Olympic trials (track and field)
# PageError for title: 1998 African Championships in Athletics
# PageError for title: TrackTown USA
# PageError for title: Chase Ealey
# PageError for title: 2004 United States Olympic trials (track and field)
# PageError for title: Oklahoma Sooners
# PageError for title: Matthew Boling
# PageError for title: Bob Larsen
# PageError for title: Carl Lewis
# PageError for title: Ryan Crouser
# PageError for title: Tom Tellez
# PageError for title: 1988 United States Olympic trials (track and field)
# PageError for title: Hunter Woodhall
# PageError for title: Percy Perry
# PageError for title: Gail Devers
# PageError for title: 50 metres
# PageError for title: 2012 United States Olympic trials (track and field)
# PageError for title: Sanya Richards-Ross
# PageError for title: Brandon Starc
# PageError for title: Swimming (sport)
# PageError for title: Swimming at the 2024 Summer Olympics
# PageError for title: Swimming at the 2000 Summer Olympics
# PageError for title: Swimming at the 2004 Summer Olympics
# PageError for title: Competitive swimwear
# PageError for title: NCAA swimming championships (Philippines)
# PageError for title: Lia Thomas
# PageError for title: Heather Cox
# PageError for title: Ross Edgley
# PageError for title: Aquatics at the 1990 Commonwealth Games
# PageError for title: Swimming at the 2024 Summer Olympics – Qualification
# PageError for title: 1995 FINA World Swimming Championships (25 m)
# PageError for title: Mary Killman
# PageError for title: 2023 U.S. National Gymnastics Championships
# PageError for title: Gymnastics at the 2024 Summer Olympics
# PageError for title: 2023 Rhythmic Gymnastics World Championships
# PageError for title: 2021 World Artistic Gymnastics Championships
# PageError for title: McKayla Maroney
# PageError for title: Simone Biles
# PageError for title: Gymnastics at the 2016 Summer Olympics
# PageError for title: Aly Raisman
# PageError for title: World cup
# PageError for title: Rebeca Andrade
# PageError for title: Sunisa Lee
# PageError for title: Dominique Dawes
# PageError for title: Morgan Hurd
# PageError for title: Carlos Yulo
# PageError for title: Steve Penny
# PageError for title: Leanne Wong
# PageError for title: 1989 World Artistic Gymnastics Championships
# PageError for title: Alice Kinsella
# PageError for title: Yang Hak-seon
# PageError for title: Cathy Rigby
# PageError for title: Kara Eaker
# PageError for title: Bart Conner
# PageError for title: 2019 European Artistic Gymnastics Championships
# PageError for title: 2019 U.S. National Gymnastics Championships
# PageError for title: Gymnastics at the 1976 Summer Olympics
# PageError for title: McKenna Kelley
# PageError for title: Allana Slater
# PageError for title: Oklahoma Sooners
# PageError for title: Amy Chow
# PageError for title: Brenna Dowell
# PageError for title: XXX (2002 film)
# PageError for title: Human Playground
# PageError for title: BMX XXX
# PageError for title: Jay Alvarrez
# PageError for title: Mount Everest
# PageError for title: The Dudesons
# PageError for title: Red Bull

# %%
# Create the CSV from the DataFrame
sprs_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Sports.csv"
sprs_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Sports = pd.read_csv("./Data/Sports.csv")
Sports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Politics

# %%
# Define the topics and subtopics
title = {
    'Politics': [
        'World Political Elections', 'Public policy analysis', 'International relations',
        'Political campaign strategies', 'Voting behavior and trends', 'Political party dynamics',
        'Governmental systems and structures', 'Legislative processes', 'Diplomacy and foreign policy',
        'Political ideologies and theories', 'Geopolitical conflicts', 'Human rights and international law',
        'Election laws and reforms', 'Political corruption and ethics', 'Global governance and institutions',
        'Environmental policy and politics', 'Economic policy debates', 'Healthcare policy',
        'Education policy', 'Immigration policy and debates', 'Defense and military policy',
        'Technology impact on politics', 'Social movements and activism', 'Media role in politics',
        'Political history and developments', 'Regional political analysis', 'Urban and rural politics',
        'Political psychology', 'Political sociology', 'Political economy',
        'Cybersecurity and politics', 'National security issues', 'Trade policies and agreements',
        'Political leadership and figures', 'Public opinion and polls', 'Civic engagement and participation'
    ],
}


# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: Independent politician
# PageError for title: 1940 United States presidential election
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: Gabon
# PageError for title: Shas
# PageError for title: Women's suffrage
# PageError for title: Accountability
# PageError for title: Political views of Generation Z
# PageError for title: 1944 United States presidential election
# PageError for title: Green party
# PageError for title: Aftermath of World War I
# PageError for title: Political repression
# PageError for title: Centrism
# PageError for title: 1956 United States presidential election
# PageError for title: Amit Shah
# PageError for title: 2022 United States House of Representatives elections
# PageError for title: 2004 Indian general election
# PageError for title: 2024 Salvadoran general election
# PageError for title: 1952 United States presidential election
# PageError for title: 1976 United States presidential election
# PageError for title: 1994 South African general election
# PageError for title: 2024 United States House of Representatives elections in Florida
# PageError for title: 2023 United States elections
# PageError for title: 2022 United States Senate elections
# PageError for title: 2004 United States presidential election
# PageError for title: Revolutions of 1989
# PageError for title: Lists of political office-holders in East Germany
# PageError for title: Elections in Chile
# PageError for title: 1964 United States presidential election
# PageError for title: Shiv Sena
# PageError for title: 1864 United States presidential election
# PageError for title: Laos–United States relations
# PageError for title: Richard R. Nelson
# PageError for title: Robert Entman
# PageError for title: RAND Corporation
# PageError for title: Public participation
# Error for title: Tableau Software, retrying (1/3)
# PageError for title: Lewis Goodall
# PageError for title: Donald Rice
# PageError for title: National Environmental Policy Act
# PageError for title: Public housing
# PageError for title: Governance
# PageError for title: Victoria Atkins
# PageError for title: Centre for Economics and Business Research
# PageError for title: Xi Jinping
# PageError for title: Andrea Levin
# PageError for title: Michael Ettlinger
# PageError for title: Cato Institute
# PageError for title: International economics
# Error for title: Foreign relations of Iran, retrying (1/3)
# PageError for title: Stephen Walt
# PageError for title: Henry Kissinger
# PageError for title: Pariah state
# PageError for title: John Ikenberry
# PageError for title: Cold War
# PageError for title: Neorealism
# PageError for title: Impact of the COVID-19 pandemic on international relations
# PageError for title: SIL International
# PageError for title: Annan Plan
# PageError for title: Iceland–European Union relations
# PageError for title: Joseph Nye
# PageError for title: James Carville
# PageError for title: Donald Trump 2024 presidential campaign
# PageError for title: Respectability politics
# PageError for title: Jeff Roe
# PageError for title: Political views of Generation Z
# PageError for title: Nicolle Wallace
# PageError for title: Amway
# PageError for title: Gary Hart
# PageError for title: Catherine M. Russell
# PageError for title: Charlie Kirk
# PageError for title: 1840 United States presidential election
# PageError for title: 2004 United States presidential election
# PageError for title: Karine Jean-Pierre
# PageError for title: Independent politician
# PageError for title: Ben Affleck
# PageError for title: Amit Shah
# PageError for title: Sara Fagen
# PageError for title: Brad Parscale
# PageError for title: Peter Thiel
# PageError for title: Bob Shrum
# PageError for title: Vladimir Putin 2004 presidential campaign
# PageError for title: Dan Bartlett
# PageError for title: Brock Pierce
# PageError for title: Cambridge Analytica
# PageError for title: Drew Westen
# PageError for title: George Soros
# PageError for title: Tim Kaine
# PageError for title: Marie Harf
# PageError for title: Wes Moore
# PageError for title: Rishi Sunak
# PageError for title: Jimmy Carter
# PageError for title: Donald Trump 2020 presidential campaign
# PageError for title: Karrin Taylor Robson
# PageError for title: 1952 United States presidential election
# PageError for title: Alastair Campbell
# PageError for title: Pete Snyder
# PageError for title: 2021 Canadian federal election
# PageError for title: 1968 United States presidential election
# PageError for title: Howie Hawkins
# PageError for title: No Labels
# PageError for title: Nadine Dorries
# PageError for title: Lori Lightfoot
# PageError for title: 2000 Canadian federal election
# PageError for title: 2024 Democratic Party presidential primaries
# PageError for title: Centrism
# PageError for title: Scott Gessler
# PageError for title: Dominic Cummings
# PageError for title: Suez Crisis
# PageError for title: Emmy Ruiz
# PageError for title: Robert F. Kennedy
# PageError for title: Kamala Harris
# PageError for title: Fake news
# PageError for title: Stuart Stevens
# PageError for title: Viral video
# PageError for title: Lyndon B. Johnson
# PageError for title: 2023 Louisiana gubernatorial election
# PageError for title: Jim Webb
# PageError for title: Liz Truss
# PageError for title: John McCain
# PageError for title: Amara Enyia
# PageError for title: Darren Bailey
# PageError for title: Jill Biden
# PageError for title: Morgan Ortagus
# PageError for title: The Game Awards 2021
# PageError for title: Adolescence
# PageError for title: Peer pressure
# PageError for title: Duverger's law
# PageError for title: Spider-Man 2 (2023 video game)
# PageError for title: Canada
# PageError for title: Gender inequality
# PageError for title: Sidney Powell
# PageError for title: Generation Z in the United States
# PageError for title: Locus of control
# PageError for title: Flapper
# PageError for title: Creativity
# PageError for title: Accountability
# PageError for title: Asexuality
# PageError for title: Generation X
# PageError for title: Google Search
# PageError for title: Deepfake
# PageError for title: MeToo movement
# PageError for title: Anti-vaccine activism
# PageError for title: Gilded Age
# PageError for title: Wells Fargo
# PageError for title: Michael Weist
# PageError for title: Google
# PageError for title: The Little Mermaid (2023 film)
# PageError for title: Ray Dalio
# PageError for title: Song Joong-ki
# PageError for title: Joe Lombardo
# PageError for title: Baby boomers
# PageError for title: George Soros
# PageError for title: Marsha Blackburn
# PageError for title: Greta Thunberg
# PageError for title: QAnon
# PageError for title: Melania Trump
# PageError for title: IQ classification
# PageError for title: Rage farming
# PageError for title: Deshaun Watson
# PageError for title: Genshin Impact
# PageError for title: Candyman (2021 film)
# PageError for title: The Last of Us Part II
# PageError for title: Cary Grant
# PageError for title: United Nations
# PageError for title: Civic technology
# PageError for title: Five Nights at Freddy's
# PageError for title: Korean War
# Error for title: Connected car, retrying (1/3)
# PageError for title: Elon Musk
# PageError for title: Demi Moore
# PageError for title: Persona 5
# PageError for title: Machine learning
# PageError for title: Jimmy Fallon
# PageError for title: Progressive Era
# PageError for title: New Deal
# PageError for title: Billy Graham
# PageError for title: Marital rape
# PageError for title: 35th AVN Awards
# PageError for title: Lauryn Hill
# PageError for title: Microtargeting
# PageError for title: School resource officer
# PageError for title: Vaas Montenegro
# PageError for title: Claude Steele
# PageError for title: John F. Kennedy
# PageError for title: Imran Khan
# PageError for title: Party system
# PageError for title: Nazi Party
# PageError for title: Black Panther Party
# PageError for title: Political repression
# PageError for title: Hu Jintao
# PageError for title: Party of Regions
# PageError for title: Jordan Peterson
# PageError for title: 1952 United States presidential election
# PageError for title: Samson Option
# PageError for title: 1964 United States presidential election
# PageError for title: Rick Harrison
# PageError for title: Apartheid
# PageError for title: Xi Jinping
# PageError for title: SCL Group
# PageError for title: Classical economics
# PageError for title: Mos Def
# PageError for title: 1988 United States presidential election
# PageError for title: Game theory
# PageError for title: Jimmy Dore
# PageError for title: Die Hard
# PageError for title: Presidential system
# PageError for title: Latvia
# PageError for title: XHamster
# PageError for title: Accountability
# PageError for title: 1936 United States presidential election
# PageError for title: Jim Mattis
# PageError for title: Eastern Bloc
# PageError for title: Deep South
# PageError for title: Class (2023 TV series)
# PageError for title: Dale L. Smith
# PageError for title: Joke
# PageError for title: Dveri
# PageError for title: East Timor
# PageError for title: Bolshevism
# PageError for title: Hamas
# PageError for title: 1968 United States presidential election
# PageError for title: Babrak Karmal
# Error for title: University of Bristol, retrying (1/3)
# PageError for title: Steve Turley
# PageError for title: Panchayati raj in India
# PageError for title: Italy
# PageError for title: Chris Coons
# PageError for title: 6 February 1934 crisis
# PageError for title: John F. Kennedy
# PageError for title: Deliberation
# PageError for title: Robert Dahl
# PageError for title: Amrit Patel
# PageError for title: Philippines
# PageError for title: Biopower
# PageError for title: Maldives
# PageError for title: Root (board game)
# PageError for title: 2023 deaths in the United States
# PageError for title: Presidential system
# PageError for title: Westminster system
# PageError for title: Human body
# PageError for title: Intelligent transportation system
# PageError for title: Party system
# PageError for title: Circulatory system
# PageError for title: Government of South Africa
# PageError for title: OSI model
# PageError for title: E-governance
# PageError for title: Computer
# PageError for title: Motorola
# PageError for title: Information retrieval
# PageError for title: SSL (company)
# Error for title: Government of the Soviet Union, retrying (1/3)
# PageError for title: FAPSI
# PageError for title: Infosys
# PageError for title: Regions of England
# PageError for title: Caste system in India
# PageError for title: Automated fare collection
# PageError for title: CODASYL
# PageError for title: Governance
# PageError for title: Black box
# PageError for title: U.S. state
# PageError for title: EG&G
# PageError for title: FasTrak
# PageError for title: Ada (programming language)
# PageError for title: German Bundesrat
# PageError for title: Independent politician
# PageError for title: U.S. state
# PageError for title: 2021 United States federal budget
# PageError for title: Substantive due process
# PageError for title: Housing Act of 1949
# PageError for title: Constitution of India
# PageError for title: 2024 Salvadoran general election
# PageError for title: United States Senate
# PageError for title: Joe Geller
# PageError for title: Amit Shah
# PageError for title: House of Lords
# PageError for title: Government of South Africa
# PageError for title: List of bills in the 115th United States Congress
# PageError for title: British Raj
# PageError for title: Khan Yunis
# PageError for title: Track II diplomacy
# PageError for title: Henry Kissinger
# PageError for title: Joseph Nye
# PageError for title: Liz Truss
# PageError for title: Xi Jinping
# PageError for title: Diplomatic history of World War II
# PageError for title: Antony Blinken
# PageError for title: National Security Decision Directive 77
# PageError for title: Brent Christensen
# PageError for title: Monroe Doctrine
# PageError for title: James Rubin
# PageError for title: Madman theory
# PageError for title: Indira Gandhi
# PageError for title: Park Jin
# PageError for title: Kylie Moore-Gilbert
# PageError for title: Critical theory
# PageError for title: Moral foundations theory
# PageError for title: Communication theory
# PageError for title: Game theory
# PageError for title: George Soros
# PageError for title: Centrism
# PageError for title: Definitions of fascism
# PageError for title: Antonio Gramsci
# PageError for title: Great Reset
# PageError for title: Ultraconservatism
# PageError for title: Fredric Jameson
# PageError for title: Racism
# PageError for title: Justice
# PageError for title: Structural Marxism
# PageError for title: Anti-capitalism
# PageError for title: QAnon
# PageError for title: Jackson Hinkle
# PageError for title: Marxist feminism
# PageError for title: Karl Popper
# PageError for title: Market fundamentalism
# PageError for title: Orthodox Marxism
# PageError for title: Hindutva
# PageError for title: Songun
# PageError for title: Queer theory
# PageError for title: Corporatism
# PageError for title: Party system
# PageError for title: Womanism
# PageError for title: Fourierism
# PageError for title: Respectability politics
# PageError for title: Marjorie Taylor Greene
# PageError for title: Elitism
# PageError for title: Rebellion
# PageError for title: Hutu Power
# PageError for title: 2022 FIFA World Cup Group B
# PageError for title: Indo-Pakistani wars and conflicts
# PageError for title: Resource war
# PageError for title: Ian Bremmer
# PageError for title: Political risk
# PageError for title: City
# PageError for title: Russo-Ukrainian War
# PageError for title: Nord Stream 2
# PageError for title: Timeline of the Israeli–Palestinian conflict in 2007
# PageError for title: 2034: A Novel of the Next World War
# PageError for title: Environmental issues
# PageError for title: Vietnam War
# PageError for title: Supercar (TV series)
# PageError for title: War in Donbas
# PageError for title: Cold War
# PageError for title: Indo-Pakistani War of 1965
# PageError for title: Henry Kissinger
# PageError for title: Suez Crisis
# PageError for title: Pepe Escobar
# PageError for title: Robert D. Kaplan
# PageError for title: Hamas
# PageError for title: Indira Gandhi
# PageError for title: Gulf War
# PageError for title: Intermarium
# PageError for title: Korean War
# PageError for title: 49th G7 summit
# PageError for title: SouthFront
# PageError for title: Yves Rocher
# PageError for title: Greenland
# PageError for title: Vlad the Impaler
# PageError for title: Vladimir Putin
# PageError for title: Romulus Augustulus
# PageError for title: Elon Musk
# PageError for title: Iraq War
# PageError for title: Southeast Asia
# PageError for title: Environmental justice
# PageError for title: Nina Jankowicz
# PageError for title: India and the Non-Aligned Movement
# PageError for title: Janet Yellen
# PageError for title: Wagner Group
# PageError for title: Matt Damon
# PageError for title: World War Z (film)
# PageError for title: Norway
# PageError for title: Han Chinese
# PageError for title: Silk Road
# PageError for title: White Paper of 1939
# PageError for title: FN FAL
# PageError for title: Land (economics)
# PageError for title: Menachem Begin
# PageError for title: Bono
# PageError for title: MEDays
# PageError for title: Mohammed bin Salman
# PageError for title: Nebuchadnezzar II
# PageError for title: North Sea
# PageError for title: Edward de Bono
# PageError for title: Francesca Albanese
# PageError for title: Children's rights
# PageError for title: Bill of rights
# PageError for title: Human rights in Colombia
# PageError for title: Dignity
# PageError for title: Human rights in Iceland
# PageError for title: Annan Plan
# PageError for title: Fundamental rights in India
# PageError for title: Kerry Kennedy
# PageError for title: Philip Alston
# PageError for title: Bodily integrity
# PageError for title: Chin people
# PageError for title: Environmental law
# PageError for title: Unenumerated rights
# PageError for title: Legal person
# PageError for title: Bill of Rights 1689
# PageError for title: Reform Act 1832
# PageError for title: Bonar Law
# PageError for title: 2000 Canadian federal election
# PageError for title: Kim Foxx
# PageError for title: 1872 United States presidential election
# PageError for title: 2000 United States presidential election
# PageError for title: Jaya Prakash Narayana
# PageError for title: Progressive Era
# PageError for title: House of Lords
# PageError for title: SAFE-T Act
# Error for title: United Kingdom of Great Britain and Ireland, retrying (1/3)
# PageError for title: Midterm election
# PageError for title: Keir Starmer
# PageError for title: Women's suffrage
# PageError for title: Duverger's law
# PageError for title: Mimi Rocah
# PageError for title: Elections in Chile
# PageError for title: 2021 Iraqi parliamentary election
# PageError for title: Apartheid
# PageError for title: 1892 United States presidential election
# PageError for title: Cleisthenes
# PageError for title: 2022 United States elections
# PageError for title: Nancy Mace
# PageError for title: 1876 United States presidential election
# PageError for title: Lina Hidalgo
# PageError for title: 1880 United States presidential election
# PageError for title: 2021 Canadian federal election
# PageError for title: Abdullah II of Jordan
# PageError for title: Clare's Law
# PageError for title: 2000 Russian presidential election
# PageError for title: 2004 United States presidential election
# PageError for title: 2024 Russian presidential election
# PageError for title: 2022 Southend West by-election
# PageError for title: Trey Gowdy
# PageError for title: 1991 Indian general election
# PageError for title: Environmental law
# PageError for title: 2004 Indian general election
# PageError for title: Accountability
# PageError for title: Dependency theory
# PageError for title: Bob Menendez
# PageError for title: Abscam
# PageError for title: Andrew Gillum
# PageError for title: BAE Systems
# PageError for title: Erin Kenny
# PageError for title: Devender Goud
# PageError for title: Koreagate
# PageError for title: Jonathan Haidt
# PageError for title: Adalberto Costa Júnior
# PageError for title: Lauren Boebert
# PageError for title: Michael Sandel
# PageError for title: Spoils system
# PageError for title: Norm Eisen
# PageError for title: Athol Williams
# PageError for title: Bangladesh Police
# PageError for title: Kenya
# PageError for title: Progressive Era
# PageError for title: Jacob Zuma
# PageError for title: Jason Kander
# PageError for title: Jawan (film)
# PageError for title: Social justice
# PageError for title: Scott Turow
# PageError for title: Chris Coons
# PageError for title: Sarah Palin
# PageError for title: Druze
# PageError for title: Conscience
# PageError for title: Les Merritt
# PageError for title: Resource war
# PageError for title: Andrew Cuomo
# PageError for title: Vaza Jato
# PageError for title: Tucker Carlson
# PageError for title: Jamie Fox
# PageError for title: SCP Foundation
# PageError for title: Provinces of Kenya
# PageError for title: Governance
# PageError for title: E-governance
# PageError for title: Sustainable Development Goal 16
# PageError for title: World Economic Forum
# PageError for title: City
# PageError for title: Great Reset
# PageError for title: Global Greens
# PageError for title: Meg Munn
# PageError for title: Samo Burja
# PageError for title: Higher education
# PageError for title: United Nations University
# PageError for title: Accountability
# Error for title: Fund governance, retrying (1/3)
# PageError for title: Karen Bakker
# PageError for title: Public participation
# PageError for title: Ray Dalio
# PageError for title: African Union
# PageError for title: Diversity, equity, and inclusion
# PageError for title: Xi Jinping

# %%
# Create the CSV from the DataFrame
plts_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Politics.csv"
plts_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Politics = pd.read_csv("./Data/Politics.csv")
Politics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Education

# %%
# Define the topics and subtopics
title = {
    'Education': [
        'Literacy rates', 'Education trends', 'Online education',
        'Early childhood education', 'K-12 education systems', 'Higher education developments',
        'Special education and inclusivity', 'STEM education', 'Arts and humanities education',
        'Educational technology advancements', 'Distance learning methodologies', 'Blended learning models',
        'Student assessment and testing', 'Teacher training and professional development', 'Education policy and reform',
        'International education systems', 'Educational psychology', 'Career and technical education',
        'Lifelong learning and adult education', 'Vocational training', 'Scholarships and financial aid',
        'Educational leadership and administration', 'Learning disabilities and support', 'Bilingual and language education',
        'Gender equality in education', 'Education in developing countries', 'Impact of COVID-19 on education',
        'Academic research and publications', 'School safety and bullying', 'Extracurricular activities and student engagement',
        'Parental involvement in education', 'School funding and resources', 'Education and social justice',
        'Environmental education', 'Mental health in education', 'Innovative teaching methods'
    ],
}


# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: Gender inequality in India
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: Digital literacy
# PageError for title: Manor, India
# PageError for title: Education in Mali
# PageError for title: Munger district
# PageError for title: Magadi
# PageError for title: Financial literacy
# PageError for title: Kachhi District
# PageError for title: River Gee County
# PageError for title: World Literacy Foundation
# PageError for title: Malvi language
# PageError for title: Banga, India
# PageError for title: Bomdila
# PageError for title: Higher education
# PageError for title: Female education
# PageError for title: XHamster
# PageError for title: Bloom's taxonomy
# PageError for title: Dark academia
# PageError for title: Title IX
# PageError for title: Scott Plous
# PageError for title: Google Classroom
# PageError for title: Embassy of Austria, Washington, D.C.
# PageError for title: Jeremy Rifkin
# PageError for title: Generation X
# PageError for title: Average human height by country
# PageError for title: Inflation
# PageError for title: Educational psychology
# PageError for title: Google Search
# PageError for title: Eric Stefani
# PageError for title: Periodic table
# PageError for title: Bill McKibben
# PageError for title: Ionization energy
# PageError for title: Generation Z in the United States
# PageError for title: Laurence Tribe
# PageError for title: Gender inequality in India
# PageError for title: Baby boomers
# PageError for title: Grade retention
# PageError for title: AMA University
# PageError for title: Andrew Ng
# PageError for title: Pedagogy
# PageError for title: Udemy
# PageError for title: Google Classroom
# PageError for title: Online learning
# PageError for title: KL University
# PageError for title: Capella University
# PageError for title: Almeda University
# PageError for title: Edmodo
# PageError for title: Online dating
# PageError for title: Stride, Inc.
# PageError for title: Scott McNealy
# PageError for title: LinkedIn Learning
# PageError for title: Byju's
# PageError for title: BigBlueButton
# PageError for title: Daphne Koller
# PageError for title: Sing Up
# PageError for title: Maryville University
# PageError for title: Skillshare
# PageError for title: Online marketplace
# PageError for title: GeekBrains
# PageError for title: Online banking
# PageError for title: Michelle Dee
# PageError for title: Digital literacy
# PageError for title: ULesson
# PageError for title: Higher education
# PageError for title: Female education
# PageError for title: Naver Corporation
# PageError for title: Bruce Kingma
# PageError for title: Pearson Education
# PageError for title: Bantu Education Act, 1953
# PageError for title: Outschool
# PageError for title: John Katzman
# PageError for title: Financial literacy
# PageError for title: Extramarks
# PageError for title: Bloom's taxonomy
# PageError for title: Title IX
# PageError for title: DreamBox Learning
# PageError for title: Documentation
# PageError for title: Jennifer Garner
# PageError for title: Ms. Rachel
# PageError for title: Anne Dias-Griffin
# PageError for title: Lilian Katz
# PageError for title: Anne Aly
# PageError for title: Fred Rogers
# PageError for title: Babysitting
# PageError for title: James Heckman
# PageError for title: Sara Wilford
# PageError for title: Wellbeing Literacy
# PageError for title: Governess
# PageError for title: Pip and Posy
# PageError for title: Leah Ayres
# PageError for title: HighScope
# PageError for title: Cycle of poverty
# PageError for title: Heising-Simons Foundation
# PageError for title: Toddler
# PageError for title: Nudity
# PageError for title: FS
# PageError for title: Tony Ryall
# PageError for title: Chris Hipkins
# PageError for title: Children's Book of the Year Award: Early Childhood
# PageError for title: Jim Hunt
# PageError for title: Learning
# PageError for title: Margaret Croke
# PageError for title: Civic engagement
# Error for title: Secondary education in Japan, retrying (1/3)
# PageError for title: K. Sivan
# PageError for title: CDW
# PageError for title: Lily K. Donaldson
# PageError for title: Michael K. Williams
# PageError for title: Higher education
# PageError for title: EPAM Systems
# PageError for title: Joe Lombardo
# PageError for title: Agrifood systems
# PageError for title: Infosys
# PageError for title: Philip K. Dick
# PageError for title: B+ tree
# PageError for title: British thermal unit
# PageError for title: Tor missile system
# PageError for title: The F**k-It List
# PageError for title: Randi Weingarten
# PageError for title: Financial literacy
# PageError for title: Circulatory system
# PageError for title: K (disambiguation)
# PageError for title: Indentation style
# PageError for title: Doug Burgum
# PageError for title: Comoros
# PageError for title: Ajit Doval
# PageError for title: Teacher education
# PageError for title: Educational entertainment
# PageError for title: Google Classroom
# PageError for title: Information literacy
# PageError for title: Russell Pearce
# PageError for title: Edmodo
# PageError for title: Solar System
# PageError for title: Janet Woodcock
# PageError for title: Anti-lock braking system
# PageError for title: Hypergamy
# PageError for title: Female education
# PageError for title: Pedagogy
# PageError for title: Mayo Clinic
# PageError for title: Force
# PageError for title: Ministry of Education (Saudi Arabia)
# PageError for title: Benin
# PageError for title: Machine learning
# PageError for title: Academic term
# PageError for title: Higher education
# PageError for title: Project 985
# PageError for title: Ministry of Higher Education (Afghanistan)
# PageError for title: Female education
# PageError for title: Bloom's taxonomy
# PageError for title: Rajiv Dixit
# PageError for title: Special needs
# PageError for title: Female education
# PageError for title: Higher education
# PageError for title: Pedagogy
# PageError for title: Michelle Dee
# PageError for title: Ranj Singh
# PageError for title: Canada
# PageError for title: 76th Tony Awards
# PageError for title: Teacher education
# PageError for title: Education in Wales
# PageError for title: Leeds
# PageError for title: Lizzo
# PageError for title: LinkedIn Learning
# PageError for title: Chris Boyle
# PageError for title: Baby boomers
# PageError for title: Javed Ahmad Tak
# PageError for title: Beatrice Gomez
# PageError for title: Glossary of education terms (G–L)
# PageError for title: Aipan art
# PageError for title: Katrina Kaif
# PageError for title: MEDays
# PageError for title: Ed Balls
# PageError for title: Jordan Peterson
# PageError for title: Disability
# PageError for title: First-generation college students in the United States
# PageError for title: Gender inequality in India
# PageError for title: Abby Stein
# PageError for title: Philippines
# PageError for title: Sunny Hostin
# PageError for title: China
# PageError for title: Randi Weingarten
# PageError for title: PFLAG
# PageError for title: Affirmative action in the United States
# PageError for title: Robert F. Kennedy
# PageError for title: Female education
# PageError for title: SAE International
# PageError for title: Sarah Brightman
# PageError for title: Christina Ochoa
# PageError for title: SETI Institute
# PageError for title: Sandbox game
# PageError for title: Santa Ono
# PageError for title: Kay Ivey
# PageError for title: Lily K. Donaldson
# PageError for title: Math 55
# PageError for title: Silicon shire
# PageError for title: TGR Foundation
# PageError for title: Ginger
# PageError for title: Linda Katehi
# PageError for title: Julia Mundy
# PageError for title: Maria Cardona
# PageError for title: Tim Gill
# PageError for title: Norah Patten
# Error for title: Geek Rhythms, retrying (1/3)
# PageError for title: Larry Bock
# PageError for title: Camille McKayle
# PageError for title: Title IX
# PageError for title: DSRP
# PageError for title: Ken Oshman
# Error for title: Deena Pierott, retrying (1/3)
# PageError for title: Eastern Illinois University
# PageError for title: Clemson University
# PageError for title: Arts and letters
# Error for title: Ashoka University, retrying (1/3)
# PageError for title: Master of Letters
# PageError for title: Female education
# PageError for title: KL University
# PageError for title: Creativity
# PageError for title: Charles Sturt University
# PageError for title: Humanistic education
# PageError for title: Lynne Cheney
# Error for title: William G. Bowen, retrying (1/3)
# PageError for title: Environmental studies
# PageError for title: BRAC University
# PageError for title: Mobility
# PageError for title: Stanley Fish
# PageError for title: Educational psychology
# PageError for title: ETH Zurich
# PageError for title: Camera
# PageError for title: Digital literacy
# PageError for title: Cebu Institute of Technology – University
# PageError for title: Adama University
# PageError for title: Victorian fashion
# PageError for title: Ansys
# PageError for title: IIT Hyderabad
# PageError for title: Timeline of historic inventions
# PageError for title: Syed Ahmad Khan
# PageError for title: Alan Kay
# PageError for title: Fire Technology
# PageError for title: Computer
# PageError for title: Michael Dell
# PageError for title: Amy Karle
# PageError for title: Civic engagement
# PageError for title: 3D printing
# PageError for title: Quaid-e-Awam University of Engineering, Science & Technology
# PageError for title: Wikimedia Foundation
# PageError for title: Progressivism
# PageError for title: Han Chinese
# PageError for title: Hanson Robotics
# PageError for title: China
# PageError for title: Generation X
# PageError for title: Philippines
# PageError for title: Song dynasty
# PageError for title: Italy
# PageError for title: Longan
# PageError for title: Thomas Edison
# PageError for title: Sci-Hub
# PageError for title: Pedagogy
# PageError for title: Educational psychology
# PageError for title: Digital literacy
# PageError for title: Information literacy
# PageError for title: CTI Education Group
# PageError for title: Lean manufacturing
# PageError for title: Marva Collins
# PageError for title: Cultural competence
# PageError for title: Virtual reality
# PageError for title: Statistical inference
# PageError for title: Likert scale
# PageError for title: Emily Oster
# PageError for title: Ray Dalio
# PageError for title: Francis Bacon
# PageError for title: The Big Bang Theory (season 11)
# PageError for title: Elon Musk
# PageError for title: Computer
# PageError for title: Least squares
# PageError for title: John F. Kennedy
# PageError for title: North America
# PageError for title: Italy
# PageError for title: Xi Jinping
# PageError for title: Christianity
# PageError for title: Positivism
# PageError for title: Metalinguistics
# PageError for title: Moby-Dick
# PageError for title: Meta-analysis
# PageError for title: QAnon
# PageError for title: History of science
# PageError for title: Indo-European languages
# PageError for title: Food miles
# PageError for title: Marco Polo
# PageError for title: Metric system
# PageError for title: Mariah Carey
# PageError for title: Corpus linguistics
# PageError for title: Stanford University
# PageError for title: Search engine
# PageError for title: Carver Mead
# PageError for title: Accounting
# PageError for title: Ising model
# PageError for title: Addition
# PageError for title: Stride, Inc.
# PageError for title: Emotion classification
# PageError for title: Cooperative learning
# PageError for title: Pedagogy
# PageError for title: DALL-E
# PageError for title: Creativity
# PageError for title: Immersive learning
# PageError for title: Ford Model T
# PageError for title: Byju's
# PageError for title: Andrew Ng
# PageError for title: Abella Danger
# PageError for title: Olivier Richters
# PageError for title: Midjourney
# PageError for title: IRONCAD
# PageError for title: Microtraining
# PageError for title: Bella Thorne
# PageError for title: Teacher education
# PageError for title: Ford Motor Company
# PageError for title: Word recognition
# PageError for title: Mara Jade
# PageError for title: AirPods Pro
# PageError for title: Jennifer Connelly
# PageError for title: Coleen Garcia
# PageError for title: One Piece (season 20)
# PageError for title: Annotation
# PageError for title: Virtual reality
# PageError for title: The F**k-It List
# PageError for title: Orgasm
# PageError for title: Nordic model
# PageError for title: Spirituality
# PageError for title: What Women Want
# PageError for title: Metaliteracy
# PageError for title: Information literacy
# PageError for title: Gabrielle Union
# PageError for title: QR code
# PageError for title: Kia Soul
# PageError for title: Characteristic impedance
# PageError for title: Inpainting
# PageError for title: Listenbourg
# PageError for title: Boeing 2707
# PageError for title: David McCallum
# PageError for title: Limerence
# PageError for title: Harry Potter
# PageError for title: Leonard Bernstein
# PageError for title: Hong Kong
# PageError for title: ASAP Rocky
# PageError for title: Kong: Skull Island
# PageError for title: Inception
# PageError for title: Jena Malone
# PageError for title: Marilyn Monroe
# PageError for title: Characters of the Marvel Cinematic Universe: M–Z
# PageError for title: Babson College
# PageError for title: Christopher Nolan
# PageError for title: Indo-European languages
# PageError for title: Adrian Belew
# PageError for title: Kraven the Hunter
# PageError for title: Saif Ali Khan
# PageError for title: Rachel Weisz
# PageError for title: Jeon Somi
# PageError for title: Pete Waterman
# PageError for title: List of Wild Kratts episodes
# PageError for title: DiSTI
# PageError for title: Taylor Swift
# PageError for title: Microsoft Bing
# PageError for title: Gilded Age
# PageError for title: Cary Grant
# PageError for title: Asia
# PageError for title: KFC
# PageError for title: Islam
# PageError for title: Ryan Shuck
# PageError for title: Alias Grace
# PageError for title: Avatar: The Way of Water
# PageError for title: Ray Dalio
# PageError for title: Star Wars
# PageError for title: Educational measurement
# PageError for title: FairTest
# PageError for title: IQ classification
# PageError for title: TOEIC
# PageError for title: Testing effect
# PageError for title: ALEKS
# PageError for title: Reading comprehension
# Error for title: Texas Educational Assessment of Minimum Skills, retrying (1/3)
# Error for title: Texas Educational Assessment of Minimum Skills, retrying (2/3)
# PageError for title: Nations and IQ
# PageError for title: Flynn effect
# PageError for title: Situational judgement test
# PageError for title: Kahoot!
# PageError for title: LeetCode
# PageError for title: Critical thinking
# PageError for title: David W. Allvin
# PageError for title: Study skills
# PageError for title: PAA (test)
# PageError for title: Educational psychology
# PageError for title: Compassion fatigue
# PageError for title: Standards-based education reform in the United States
# PageError for title: Higher-order thinking
# PageError for title: IIT Bombay
# PageError for title: Teacher education
# PageError for title: Microteaching
# PageError for title: Sing Up
# PageError for title: Juris Doctor
# PageError for title: CDMT
# PageError for title: Kai Greene
# PageError for title: Educational psychology
# PageError for title: Reading comprehension
# PageError for title: Teach For All
# PageError for title: Bloodsport (film)
# PageError for title: Overtime Elite
# PageError for title: Helmut Kentler
# PageError for title: Education in Malawi
# PageError for title: Home economics
# PageError for title: Skilled worker
# PageError for title: Higher education
# PageError for title: Jon Bernthal
# PageError for title: Lee Strasberg
# PageError for title: Brian Plummer
# PageError for title: Standards-based education reform in the United States
# PageError for title: Education Act 1944
# PageError for title: Jaya Prakash Narayana
# PageError for title: Progressive Era
# PageError for title: Xi Jinping
# PageError for title: Math wars
# PageError for title: Apartheid
# PageError for title: Robert Reich
# PageError for title: Rosa DeLauro
# PageError for title: Female education
# PageError for title: Title IX
# PageError for title: China
# PageError for title: Financial literacy
# PageError for title: Democratic Alliance (South Africa)
# PageError for title: Randi Weingarten
# PageError for title: Open Society Foundations
# PageError for title: Ministry of Education (Ghana)
# PageError for title: Suzerain (video game)
# PageError for title: Clare O'Neil
# PageError for title: Anne Dias-Griffin
# PageError for title: Home economics
# PageError for title: Jo Boaler
# PageError for title: Wang Anshi
# PageError for title: Presidency of Barack Obama
# PageError for title: Hong Kong
# PageError for title: House of Lords
# PageError for title: Ramesh Chander
# PageError for title: Pedagogy
# PageError for title: Higher education
# PageError for title: Pearson Education
# PageError for title: Presidential system
# PageError for title: SRI International
# PageError for title: AMA University
# PageError for title: EPAM Systems
# PageError for title: Female education
# PageError for title: SAE International
# PageError for title: OSI model
# PageError for title: Accounting
# PageError for title: Wellbeing Literacy
# PageError for title: Brown v. Board of Education
# PageError for title: Teacher education
# PageError for title: Agrifood systems
# PageError for title: Bantu Education Act, 1953
# PageError for title: Circulatory system
# PageError for title: ISO 21001
# PageError for title: Educational psychology
# PageError for title: Bloom's taxonomy
# PageError for title: Positive psychology
# PageError for title: Testing effect
# PageError for title: Self-esteem
# PageError for title: Self-regulation
# PageError for title: Learning
# PageError for title: Note-taking
# PageError for title: Pedagogy
# PageError for title: Locus of control
# PageError for title: Kristin Neff
# PageError for title: Crowd psychology
# PageError for title: Motivation
# PageError for title: Adolescence
# PageError for title: Twice exceptional
# PageError for title: School bullying
# PageError for title: Dale Schunk
# PageError for title: Abnormal psychology
# PageError for title: Sociocultural perspective
# PageError for title: Dr Fox
# PageError for title: Johnmarshall Reeve
# PageError for title: Study skills
# PageError for title: Robert Sternberg
# PageError for title: Linda Nielsen
# PageError for title: Environmental psychology
# PageError for title: Kevin Cokley
# PageError for title: Need for cognition
# PageError for title: Teacher education
# PageError for title: Alfred E. Smith Career and Technical Education High School
# PageError for title: Home economics
# PageError for title: Tim Kaine
# PageError for title: Maxwell
# PageError for title: Jill Wine-Banks
# PageError for title: Olympic High School (Silverdale, Washington)

# %%
# Create the CSV from the DataFrame
edcs_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Education.csv"
edcs_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Education = pd.read_csv("./Data/Education.csv")
Education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Travel

# %%
# Define the topics and subtopics
title = {
    'Travel': [
        'Top tourist destinations', 'Airline industry data', 'Travel trends',
        'Eco-tourism and sustainable travel', 'Cruise industry insights', 'Adventure travel destinations',
        'Cultural and heritage tourism', 'Luxury travel experiences', 'Budget and backpacking travel',
        'Hotel and hospitality industry', 'Travel technology advancements', 'Travel insurance and safety',
        'Solo travel trends', 'Family travel and vacations', 'Business travel dynamics',
        'Road trips and car travel', 'Rail travel and train tours', 'Food and culinary tourism',
        'Health and wellness retreats', 'Travel photography and blogging', 'Digital nomad lifestyle',
        'Travel during COVID-19', 'Visa and immigration policies', 'Accessible travel for disabled travelers',
        'Destination weddings and honeymoons', 'Travel gear and accessories', 'Frequent flyer programs and loyalty schemes',
        'Travel booking platforms and apps', 'Cultural etiquette and customs', 'Language and communication in travel',
        'Wildlife and nature tourism', 'Historical travel and tours', 'Seasonal travel trends',
        'Volunteer and educational travel', 'Space tourism', 'Emerging travel destinations'
    ],
}


# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: Heho Airport
# PageError for title: Big Sur
# PageError for title: Hiroshima
# PageError for title: Zaan
# PageError for title: Sipalay
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: Île-de-France
# PageError for title: Kanyam
# PageError for title: Belize
# PageError for title: Disneyland Paris
# PageError for title: Sex tourism
# PageError for title: Boracay
# PageError for title: Tourist attractions in Vienna
# PageError for title: Axum
# PageError for title: Overtourism
# PageError for title: Top Withens
# PageError for title: Tourism in Egypt
# PageError for title: Dalaman Airport
# PageError for title: Camm Morton
# PageError for title: Ubud
# PageError for title: Elephanta Island
# PageError for title: Gay village
# PageError for title: Cliffs of Moher
# PageError for title: CityPASS
# PageError for title: Warsaw
# PageError for title: Pai, Thailand
# PageError for title: Funchal
# PageError for title: Riviera Maya
# PageError for title: Space tourism
# PageError for title: Ko Samui
# PageError for title: Spiderhead
# PageError for title: Metro Manila
# PageError for title: Santa Claus, Indiana
# PageError for title: Victoria Falls
# PageError for title: Colca Canyon
# PageError for title: Teluk Bahang
# PageError for title: Mallorca
# PageError for title: Porto Flavia
# PageError for title: Visa requirements for Indian citizens
# PageError for title: Da Lat
# PageError for title: Malaysia Airlines Flight 370
# PageError for title: Frontier Airlines
# PageError for title: United Airlines
# PageError for title: Flightradar24
# PageError for title: EasyJet
# PageError for title: China Airlines
# PageError for title: Spirit Airlines
# PageError for title: Northwest Airlines
# PageError for title: Northwest Airlines Flight 255
# PageError for title: Flight attendant
# PageError for title: US Airways
# PageError for title: El Al
# PageError for title: British Airways
# PageError for title: ATA 100
# PageError for title: Air Astana
# PageError for title: American Airlines Flight 965
# PageError for title: Antonov An-12
# PageError for title: Skybus Airlines
# PageError for title: Airfare
# PageError for title: MakeMyTrip
# PageError for title: South African Airways
# PageError for title: Airbus A318
# PageError for title: Airlink
# PageError for title: United Airlines Flight 328
# PageError for title: Pitot tube
# PageError for title: CommuteAir
# PageError for title: Dornier 228
# PageError for title: Boeing Commercial Airplanes
# PageError for title: ZS Associates
# PageError for title: Airbus A300
# PageError for title: Axess (CRS)
# PageError for title: Virgin Atlantic
# PageError for title: Safair
# PageError for title: Mango (airline)
# PageError for title: Saab 340
# PageError for title: Boeing 737
# PageError for title: Convair 880
# PageError for title: ETOPS
# PageError for title: Tunisair
# PageError for title: ChatGPT
# PageError for title: Boeing 247
# PageError for title: Airbus A330neo
# PageError for title: Fokker 100
# PageError for title: List of companies in the Dallas–Fort Worth metroplex
# PageError for title: Tupolev Tu-204
# PageError for title: United Airlines Flight 232
# PageError for title: Economy of Colombia
# PageError for title: Ko Samui
# PageError for title: British Aerospace 146
# PageError for title: Pratt & Whitney JT8D
# PageError for title: List of GIS data sources
# PageError for title: Elko, Nevada
# PageError for title: Plantronics
# PageError for title: Illinois Tool Works
# PageError for title: CA Technologies
# PageError for title: USA Today
# PageError for title: Mode of transport
# PageError for title: Intermiles
# PageError for title: Mary Kom
# PageError for title: Traveling Wilburys
# PageError for title: Passport
# PageError for title: XHamster
# PageError for title: Recreational vehicle
# PageError for title: Safari
# PageError for title: CNN
# PageError for title: William Goldring (businessman)
# PageError for title: RSVP
# PageError for title: Andrea Botez
# PageError for title: Fashion
# PageError for title: Withlocals
# PageError for title: Africa Travel Association
# PageError for title: Cleartrip
# PageError for title: Baldur's Gate 3
# PageError for title: Bhoot Police
# PageError for title: Mancation
# PageError for title: Google Search
# PageError for title: Visa requirements for Indian citizens
# PageError for title: Forspoken
# PageError for title: Norse Atlantic Airways
# PageError for title: Croatia Airlines
# PageError for title: Flydubai
# PageError for title: Assassin's Creed Mirage
# PageError for title: Greta Thunberg
# PageError for title: New York City
# PageError for title: Ionization energy
# PageError for title: Jet stream
# PageError for title: Marvel's Midnight Suns
# PageError for title: Call of Duty
# PageError for title: State of Palestine
# PageError for title: EasyJet
# PageError for title: Gilded Age
# PageError for title: The Game Awards 2022
# PageError for title: Shuttle bus
# PageError for title: Speed of sound
# PageError for title: Melania Trump
# PageError for title: Grace Kelly
# PageError for title: Belle Delphine
# PageError for title: Birkin bag
# PageError for title: SpaceX Starship
# PageError for title: Polar bear
# PageError for title: Linda Evangelista
# PageError for title: Markwayne Mullin
# PageError for title: Eco hotel
# PageError for title: Kuwait Vision 2035
# PageError for title: Africa Travel Association
# PageError for title: Riviera Maya
# PageError for title: Wildlife
# PageError for title: Food miles
# PageError for title: Economy of Colombia
# PageError for title: Isabela (province)
# PageError for title: Greenpeace
# PageError for title: Castle of Mey
# PageError for title: Greenland
# PageError for title: Alpes-Maritimes
# PageError for title: City
# PageError for title: Haiti
# PageError for title: Caracas
# PageError for title: French Bee
# PageError for title: Rail transport in India
# PageError for title: Grab (company)
# PageError for title: EasyJet
# PageError for title: Island of Bryan
# PageError for title: Italy
# PageError for title: New York City
# PageError for title: Bandung
# PageError for title: Philippines
# PageError for title: Food security
# PageError for title: 47th G7 summit
# PageError for title: Pantanal
# PageError for title: Cambridge
# PageError for title: Economy of China
# PageError for title: Disneyland Paris
# PageError for title: Industrial Revolution
# Error for title: Criticisms of globalization, retrying (1/3)
# PageError for title: Dead Sea
# PageError for title: Salton Sea
# PageError for title: Bintulu
# PageError for title: Southern right whale
# PageError for title: Easter Island
# PageError for title: Lake Sevan
# PageError for title: Wonder of the Seas
# PageError for title: Gulfstream G550
# PageError for title: AVN Awards
# PageError for title: Sea-Doo
# PageError for title: Type 095 submarine
# PageError for title: Wesley Eure
# PageError for title: 20th Century Studios
# PageError for title: Iron Dome
# PageError for title: Lana Del Rey
# PageError for title: Jisoo
# PageError for title: NAL Saras
# PageError for title: Gavin Newsom
# PageError for title: Kate Winslet
# PageError for title: Sikorsky S-70
# PageError for title: New York City
# PageError for title: Robert Maxwell
# PageError for title: List of one-hit wonders in the United States
# PageError for title: MBB Bo 105
# PageError for title: Ted Bundy
# PageError for title: Mil Mi-28
# PageError for title: Blackpink
# PageError for title: Avatar: The Way of Water
# PageError for title: The Northman
# PageError for title: Chengdu J-20
# PageError for title: Nope (film)
# PageError for title: 2023 in American television
# PageError for title: Brooklyn
# PageError for title: Business jet
# PageError for title: Hyundai Sonata
# PageError for title: Sukhoi Su-30
# PageError for title: EasyJet
# PageError for title: Honda CR-V
# PageError for title: DP World
# PageError for title: Acura MDX
# PageError for title: Moby-Dick
# PageError for title: Mad Men
# PageError for title: FASTag
# PageError for title: Italy
# PageError for title: Toyota Prius
# PageError for title: Tor missile system
# PageError for title: Aaron Sorkin
# PageError for title: John Schnatter
# PageError for title: SARS-CoV-2
# PageError for title: Sicily
# PageError for title: Robert Louis Stevenson
# PageError for title: Type 63 multiple rocket launcher
# PageError for title: Orca
# PageError for title: Ram pickup
# PageError for title: Seville
# PageError for title: Intelligent transportation system
# PageError for title: Great white shark
# PageError for title: Sukhoi Su-17
# PageError for title: Roger Ebert
# PageError for title: Vladimir Putin
# PageError for title: BtoB (band)
# PageError for title: Frontier Airlines
# PageError for title: 2023 in the United Kingdom
# PageError for title: Fake news
# PageError for title: List of S&P 400 companies
# PageError for title: Fokker 100
# PageError for title: Airbus A330neo
# PageError for title: Ainu people
# PageError for title: Focke-Wulf Fw 191
# PageError for title: Sikorsky S-92
# PageError for title: Jet pack
# PageError for title: List of American films of 2021
# PageError for title: Bain Capital
# PageError for title: Jeb Bush
# PageError for title: Russian Air Force
# PageError for title: The Bund
# PageError for title: Eurocopter EC145
# PageError for title: COVID-19 vaccine
# PageError for title: STA Travel
# PageError for title: Swain Destinations
# PageError for title: Don Wildman
# PageError for title: Allan Karl
# PageError for title: CityPASS
# PageError for title: Gateway (video game)
# PageError for title: Andrew Zimmern
# PageError for title: Bill & Ted's Excellent Adventure (1991 video game)
# PageError for title: The Amazing Race 35
# PageError for title: Cinque Terre
# PageError for title: Shangri-La
# PageError for title: NST (company)
# PageError for title: Dave Hood
# PageError for title: Gogobot
# PageError for title: The Amazing Race Canada 9
# PageError for title: Cultural tourism
# PageError for title: Jim Shockey
# PageError for title: Vacation
# PageError for title: Richard Dennison
# PageError for title: Deliverance
# PageError for title: Robert Swan
# PageError for title: Sex tourism
# PageError for title: Drew Binsky
# PageError for title: If You Had Wings
# PageError for title: Canada 3000
# PageError for title: Dora the Explorer
# PageError for title: One Piece (season 20)
# PageError for title: Ryan Pyle
# PageError for title: Mag Mell
# PageError for title: Romana (Doctor Who)
# PageError for title: Catbus
# PageError for title: Recreational vehicle
# PageError for title: Slum tourism
# PageError for title: Aviasales
# PageError for title: Dark ride
# PageError for title: Toe Laew
# PageError for title: Lost in Space
# PageError for title: Saint-Malo
# PageError for title: 1883 (TV series)
# PageError for title: Phil Keoghan
# PageError for title: Starsector
# PageError for title: Dom Joly
# PageError for title: Icy Strait Point
# PageError for title: Red seal ships
# PageError for title: Victoria Falls
# PageError for title: Sorted Food
# PageError for title: The Real Adventures of Jonny Quest
# PageError for title: Teluk Bahang
# PageError for title: Shannen Doherty
# PageError for title: Carl Mullan
# PageError for title: Tom Gleisner
# PageError for title: People mover
# PageError for title: Secret of Mana
# PageError for title: Jared Leto
# PageError for title: List of Greek and Latin roots in English/P–Z
# PageError for title: Raiders of the Lost Ark
# PageError for title: Mayflower
# PageError for title: Disneyland Paris
# PageError for title: Charley Pollard
# PageError for title: The Amazing Race 19
# PageError for title: Baldur's Gate
# PageError for title: Ratz (TV series)
# PageError for title: Intersect (2020 film)
# PageError for title: Pan Am Flight 103
# PageError for title: The Durrells
# PageError for title: Playmobil
# PageError for title: Cultural tourism
# PageError for title: World Heritage Site
# PageError for title: Dark tourism
# PageError for title: Ministry of Tourism (Saudi Arabia)
# PageError for title: Religious tourism
# PageError for title: Slum tourism
# PageError for title: Smart tourism
# PageError for title: Cultural center
# PageError for title: Cultural relativism
# PageError for title: Cross-cultural
# PageError for title: Cultural icon
# PageError for title: Cultural competence
# PageError for title: Cultural literacy
# PageError for title: Vacation
# PageError for title: MSC Cruises
# PageError for title: Airbnb
# PageError for title: Starwood
# PageError for title: Saga plc
# PageError for title: Safari
# PageError for title: Premier Inn
# PageError for title: Palace on Wheels
# PageError for title: Riviera Maya
# PageError for title: Rocky Mountaineer
# PageError for title: Star Wars: Galactic Starcruiser
# PageError for title: Voyage.tv
# PageError for title: MSC Seaside
# PageError for title: Anna Sorokin
# PageError for title: Jeff Koons
# PageError for title: Anthony Bourdain
# PageError for title: JW Marriott Hotels
# PageError for title: Louis Vuitton
# PageError for title: Ocean liner
# PageError for title: W Motors
# PageError for title: Roja Dove
# PageError for title: V&A Waterfront
# PageError for title: Ian Schrager
# PageError for title: Lincoln MKZ
# PageError for title: Lisa Ray
# PageError for title: Overtourism
# PageError for title: Sarah Isgur
# PageError for title: AMC Pacer
# PageError for title: Mario Salcedo
# PageError for title: Boracay
# PageError for title: Pai, Thailand
# PageError for title: Vanessa Bayer
# PageError for title: The Sims 4
# PageError for title: Gordon Ramsay
# PageError for title: Paternoster, South Africa
# PageError for title: Emilia Clarke
# PageError for title: Pan Am
# PageError for title: Citroën SM
# PageError for title: Jeff Bezos
# PageError for title: Barbie (film)
# PageError for title: Island of Bryan
# PageError for title: One Piece (season 17)
# PageError for title: Queen Mary 2
# PageError for title: A Town Like Alice
# PageError for title: Patek Philippe
# PageError for title: Kish Island
# PageError for title: AMC Concord
# PageError for title: Chung Ju-yung
# PageError for title: John DeLorean
# PageError for title: Dusit International
# PageError for title: Stray Kids
# PageError for title: Gigi Hadid
# PageError for title: Roald Dahl
# PageError for title: Bonnie Wright
# PageError for title: John Keats
# PageError for title: Bella Hadid
# PageError for title: Edward VII
# PageError for title: Reply 1988
# PageError for title: Antibes
# PageError for title: A Perfect Getaway
# PageError for title: 2018 in American television
# PageError for title: Lee Je-hoon
# PageError for title: Maachis
# PageError for title: Citizen Ruth
# PageError for title: Mount Everest
# PageError for title: Lauren Boebert
# PageError for title: HM Transport
# PageError for title: Double bass
# PageError for title: Willys MB
# PageError for title: Eric Adams
# PageError for title: Soulja Boy
# PageError for title: Eddie Bauer
# PageError for title: Miracle at St. Anna
# PageError for title: Lee Soon-jae
# PageError for title: Billings, Montana
# PageError for title: Invader Zim
# PageError for title: Smartphone
# PageError for title: Dodge WC series
# PageError for title: University of Wyoming
# PageError for title: The Real Adventures of Jonny Quest
# PageError for title: Hospitality
# PageError for title: Avari Hotels
# PageError for title: RedDoorz
# PageError for title: GLH Hotels
# PageError for title: Anthony Melchiorri
# Error for title: Chief Ministership of N. Chandrababu Naidu, retrying (1/3)
# PageError for title: Motel 6
# PageError for title: Dusit International
# PageError for title: Alticor
# PageError for title: Starwood
# PageError for title: Novotel
# PageError for title: Robin Hutson
# PageError for title: Ian Schrager
# PageError for title: Hotel du Vin
# PageError for title: Airbnb
# PageError for title: Sandals Resorts
# PageError for title: ANA Hotels
# PageError for title: Endeavour Group
# PageError for title: JW Marriott Hotels
# PageError for title: Bashar Wali
# PageError for title: David Kong
# PageError for title: Avid Hotels
# PageError for title: Infor
# PageError for title: Swire Hotels
# PageError for title: Front office
# PageError for title: Landry's
# PageError for title: SevenRooms
# PageError for title: Golyan Group
# PageError for title: HMI Hotel Group
# PageError for title: Gordon Ramsay
# PageError for title: Operation Paperclip
# PageError for title: Civic technology
# PageError for title: Fermi paradox
# PageError for title: Primer (film)
# PageError for title: Camera
# PageError for title: Deepfake
# PageError for title: Telepresence
# PageError for title: Volkswagen Golf Mk8
# PageError for title: Unreal Engine
# PageError for title: Remembrance of Earth's Past
# PageError for title: Wernher von Braun
# PageError for title: Jet airliner
# PageError for title: Wikimedia Foundation
# PageError for title: Computer
# Error for title: Four-engined jet aircraft, retrying (1/3)
# PageError for title: China
# PageError for title: Eve Online
# PageError for title: Space exploration
# PageError for title: Philippines
# PageError for title: 2300 AD
# PageError for title: Italy
# PageError for title: Smartphone
# PageError for title: Flying car
# PageError for title: Han Chinese
# PageError for title: Frozen II
# PageError for title: Industrial Revolution
# PageError for title: Mae Jemison
# PageError for title: The Crossing (video game)
# PageError for title: James Cameron
# PageError for title: Song dynasty
# PageError for title: Aston University
# PageError for title: Brave New World
# PageError for title: Tupolev Tu-144
# PageError for title: Mars 2020
# PageError for title: Superhuman
# PageError for title: Record producer
# PageError for title: Bill Gates
# PageError for title: Flight engineer
# PageError for title: 2023 deaths in the United States
# PageError for title: Golf ball
# PageError for title: Xi Jinping
# PageError for title: Black Nova Scotians
# PageError for title: H. G. Wells
# PageError for title: Kamala Harris
# PageError for title: 49th G7 summit
# PageError for title: DC Universe
# PageError for title: Water
# PageError for title: Richard Branson
# PageError for title: Bronze Age
# PageError for title: Jack Parsons
# PageError for title: Julius Caesar
# PageError for title: List of megaprojects
# PageError for title: Milky Way
# PageError for title: NRMA
# PageError for title: Costco
# PageError for title: Wesfarmers
# PageError for title: Kia K5
# PageError for title: Jeep Patriot
# PageError for title: Lincoln LS
# PageError for title: Pit bull
# PageError for title: Joe Biden
# PageError for title: Volkswagen Amarok
# PageError for title: MOT test
# PageError for title: Mercedes-Benz S-Class (W221)
# PageError for title: Ford Escape
# PageError for title: Airplane
# PageError for title: Craig Tracey
# PageError for title: Why Women Kill
# PageError for title: Elaine Chao
# PageError for title: ADAC
# PageError for title: Big Dig
# PageError for title: Spirit Airlines
# PageError for title: Saab 9-3
# PageError for title: Speedometer
# PageError for title: Malaysia Airlines Flight 370
# PageError for title: Title 15 of the United States Code
# PageError for title: Cargo
# PageError for title: Qantas
# PageError for title: Volvo S60
# PageError for title: Kia Soul
# PageError for title: Ford Mustang Mach-E
# PageError for title: .ar
# PageError for title: Moped
# PageError for title: Grab (company)
# PageError for title: Turkish Airlines Flight 981
# PageError for title: BSI Group
# PageError for title: Leeds
# PageError for title: MV Golden Ray
# PageError for title: Gavin Newsom
# PageError for title: Chung Ju-yung
# PageError for title: People's Party (Iceland)
# PageError for title: Storm Daniel
# PageError for title: Textron
# PageError for title: Mar-a-Lago
# PageError for title: Angus King
# PageError for title: Willy Brandt
# PageError for title: Gattaca
# Error for title: Stapleton International Airport, retrying (1/3)
# PageError for title: Micromobility
# PageError for title: Airlink
# PageError for title: United Airlines Flight 175
# PageError for title: Buick Rainier
# PageError for title: Boiler
# PageError for title: Russell 1000 Index
# PageError for title: AMC Pacer
# PageError for title: Gilded Age
# PageError for title: Traveling Wilburys
# PageError for title: Spice Girls
# PageError for title: Neil Young
# PageError for title: Double bass
# PageError for title: Taemin
# PageError for title: Visa requirements for Indian citizens
# PageError for title: Sandara Park
# PageError for title: Barbie (film)
# PageError for title: J. J. Cale
# PageError for title: Jet stream
# PageError for title: Star Wars
# PageError for title: Steve Howe
# PageError for title: Eiza González
# PageError for title: Jeon Somi
# PageError for title: Diablo IV
# PageError for title: Henry Cavill
# PageError for title: Park Bom
# PageError for title: Kang Daniel
# PageError for title: Deepfake
# PageError for title: Gladys Knight
# PageError for title: Art dealer
# PageError for title: Melania Trump
# PageError for title: Donnie Iris
# PageError for title: Kendall Jenner
# PageError for title: Kiss (band)
# PageError for title: Chaka Khan
# PageError for title: Park Eun-bin
# PageError for title: Money Heist
# PageError for title: Catherine, Princess of Wales
# PageError for title: Brave New World (TV series)
# PageError for title: Sam Kass
# PageError for title: Kamala Khan
# PageError for title: Carol Danvers
# PageError for title: Connie Francis
# PageError for title: Harrison Ford
# PageError for title: Applause
# PageError for title: Pattie Boyd
# PageError for title: Logan Paul
# PageError for title: The Little Mermaid (2023 film)
# PageError for title: Joywave
# PageError for title: Dua Lipa
# PageError for title: Rob Halford
# PageError for title: Gigi Hadid
# PageError for title: Qatar Airways
# PageError for title: Stray Kids
# PageError for title: 83 (film)
# PageError for title: Nay Win
# PageError for title: Emily Carr
# PageError for title: Black Widow (2021 film)
# PageError for title: Damar Hamlin
# PageError for title: Jean-Michel Basquiat
# PageError for title: Tupolev Tu-144
# PageError for title: California condor
# PageError for title: Cai Xukun
# PageError for title: Justin Bieber
# PageError for title: Suho
# PageError for title: Sea shanty
# PageError for title: Lee Seung-gi
# PageError for title: Zack Snyder's Justice League
# PageError for title: Gary Moore
# PageError for title: Måneskin
# PageError for title: Norway
# PageError for title: Citroën SM
# PageError for title: Ludwig van Beethoven
# PageError for title: List of Christmas films
# PageError for title: Honda S2000
# PageError for title: Wonderwall Music
# PageError for title: Artie Shaw
# PageError for title: Rod Stewart
# PageError for title: Julie Andrews
# PageError for title: A Visit from the Goon Squad
# PageError for title: Francis Galton
# PageError for title: Apex Legends
# PageError for title: Adam Saleh
# PageError for title: Nissan 350Z
# PageError for title: Fall Guys
# PageError for title: T.A.T.u.
# PageError for title: Faye Wong
# PageError for title: Fallout 76
# PageError for title: John Cena
# PageError for title: Terminator Genisys
# PageError for title: Richard Branson
# PageError for title: Doctor Who (series 13)
# PageError for title: Italy
# PageError for title: Sea of Thieves
# PageError for title: Lady Gaga
# PageError for title: IU discography
# PageError for title: David Bowie
# PageError for title: Kelly Clarkson
# PageError for title: Cosplay
# PageError for title: Kim So-hyun
# PageError for title: Bryan Adams
# PageError for title: Pole dance
# PageError for title: Queendom (TV series)
# PageError for title: Joseph Haydn
# PageError for title: Clare Fischer
# PageError for title: Kerry Ellis
# PageError for title: Shinee
# PageError for title: Ramones
# PageError for title: Guitar Hero
# PageError for title: The X-Files
# PageError for title: Vacation
# PageError for title: Family Guy
# PageError for title: Costco
# PageError for title: Vrbo
# PageError for title: Bewitched
# PageError for title: Home Alone
# PageError for title: R'Bonney Gabriel
# PageError for title: Charles Manson
# PageError for title: Recreational vehicle
# PageError for title: Rosie O'Donnell
# PageError for title: Religious tourism
# PageError for title: United Airlines
# PageError for title: Anthony Bourdain
# PageError for title: 2018 in American television
# PageError for title: Westboro Baptist Church
# PageError for title: Zac Efron
# PageError for title: Pyramidal tracts
# PageError for title: Sarah Isgur
# PageError for title: Jayne Mansfield's Car
# PageError for title: Centurion Card
# PageError for title: Eugene Levy
# PageError for title: After We Fell
# PageError for title: Wanda Sykes
# PageError for title: ATA Airlines
# PageError for title: Characters of the Marvel Cinematic Universe: M–Z
# PageError for title: Charles Francis Sweeny
# PageError for title: Yvonne Orji
# PageError for title: Tom Petty
# PageError for title: The Transformers (Marvel Comics)
# PageError for title: Randy Quaid
# PageError for title: The A-Team (season 5)
# PageError for title: Vice President of Colombia
# PageError for title: Airbnb
# PageError for title: Chevrolet Volt
# PageError for title: List of American films of 2023
# PageError for title: Vanessa Hudgens
# PageError for title: Here Comes the Boom
# PageError for title: Benjamin Harrison
# PageError for title: Steve Harvey
# PageError for title: Taken (film)
# PageError for title: Marco Polo
# PageError for title: Marcus Lamb
# PageError for title: Jon Hamm
# PageError for title: Cary Grant
# PageError for title: Tim Allen
# PageError for title: Michael J. Fox
# PageError for title: Gerhard Lauter
# PageError for title: Super Wings
# PageError for title: One Piece
# PageError for title: Spirited Away
# PageError for title: 2023 deaths in the United States
# PageError for title: Jimmy Carter
# PageError for title: Montauk, New York
# PageError for title: Raiders of the Lost Ark
# PageError for title: Russo-Ukrainian War
# PageError for title: Vladimir Putin
# PageError for title: Britt Ekland
# PageError for title: John Candy
# PageError for title: Jhimma
# PageError for title: Charli D'Amelio
# PageError for title: Joe Jonas
# PageError for title: Olivia Newton-John
# PageError for title: Cape Cod
# PageError for title: Boston Dynamics
# PageError for title: BMW i8
# PageError for title: Karim Lala
# PageError for title: Mos Def
# PageError for title: GBU-28
# PageError for title: Ashburn, Virginia
# PageError for title: Jeff Bezos
# PageError for title: Legacy of Kain
# PageError for title: Gex (video game)
# PageError for title: XHamster
# PageError for title: XIII: The Conspiracy
# PageError for title: Shuttle bus
# PageError for title: China
# PageError for title: Anomaly
# PageError for title: Textron
# PageError for title: 2023 deaths in the United States
# PageError for title: Flexjet
# PageError for title: Unity Technologies
# PageError for title: Convair 880
# PageError for title: John F. Kennedy
# PageError for title: Rick Goings
# PageError for title: Atmosphere of Earth
# PageError for title: Continuum mechanics
# PageError for title: Driven (2001 film)
# PageError for title: AlphaGo
# PageError for title: Surface Laptop 3
# PageError for title: Microsoft Bing
# PageError for title: Russell 1000 Index
# PageError for title: Brian Jones
# PageError for title: Italy
# PageError for title: Speed of sound
# PageError for title: Lamu
# PageError for title: GitHub
# PageError for title: Sonic boom
# PageError for title: Kim Jong Un
# PageError for title: Surface Laptop Go 2
# PageError for title: Maldives
# PageError for title: M1 Abrams
# PageError for title: Principle of locality
# PageError for title: Wendy Carlos
# PageError for title: William Anders
# PageError for title: Apartheid
# PageError for title: Music
# PageError for title: Hong Kong
# PageError for title: Jimmy Page
# PageError for title: Bill Gates
# PageError for title: Arthur Miller
# PageError for title: QAnon
# PageError for title: Market segmentation
# PageError for title: Philippines
# PageError for title: Christianity
# PageError for title: Ghostbusters II
# PageError for title: Ludwig van Beethoven
# PageError for title: Celts
# PageError for title: Washington, D.C.
# PageError for title: Latvia
# PageError for title: Remittance
# PageError for title: George Takei
# PageError for title: Water
# PageError for title: Jon Shirley
# PageError for title: Outer space
# PageError for title: Electricity
# PageError for title: Dragonball Evolution
# PageError for title: Flying car
# PageError for title: India–United Kingdom bus routes
# PageError for title: Yuba County Five
# PageError for title: Joy Ride (2001 film)
# PageError for title: Bertha Benz
# PageError for title: Parking
# PageError for title: Pet carrier
# PageError for title: American Pickers
# PageError for title: Per diem
# PageError for title: U.S. Route 66
# PageError for title: Top Gear (series 22)
# PageError for title: The Fearway
# PageError for title: Alibag
# PageError for title: Top Gear (series 14)
# PageError for title: Recreational vehicle
# PageError for title: Road 96
# PageError for title: Top Gear (2002 TV series)
# PageError for title: Ring of Kerry
# PageError for title: Intelligent transportation system
# PageError for title: Amtrak
# PageError for title: Braess's paradox
# PageError for title: Outerbridge Crossing
# PageError for title: Bike lane
# PageError for title: U.S. Route 550
# PageError for title: Joanne Lees
# PageError for title: Tracie Andrews
# PageError for title: Roxham Road
# PageError for title: Leyland brothers
# PageError for title: Road to Perdition
# PageError for title: Mercedes-Benz W126
# PageError for title: Virginia State Route 267
# PageError for title: Joyride (2022 film)
# PageError for title: Zipcar
# PageError for title: Dan Blocker
# PageError for title: Donnie Darko
# PageError for title: Stagecoach
# PageError for title: European route E6
# PageError for title: Speedometer
# PageError for title: The F**k-It List
# PageError for title: Top Gear (series 21)
# PageError for title: Gridlock
# PageError for title: Sundown town
# PageError for title: Guy Fieri
# PageError for title: Railroad car
# PageError for title: HitchBOT
# PageError for title: Rust Creek
# PageError for title: AMC Pacer
# PageError for title: Jeremy Clarkson
# PageError for title: Trapped (2002 film)
# PageError for title: The Grownup
# PageError for title: Parking brake
# PageError for title: Erwin Baker
# PageError for title: T. L. Osborn
# PageError for title: Rail transport in India
# PageError for title: Empire Builder
# PageError for title: TGV
# PageError for title: MakeMyTrip
# PageError for title: Rocky Mountaineer
# PageError for title: Uniworld
# PageError for title: British Rail Class 55
# PageError for title: British Rail Class 395
# PageError for title: List of IATA-indexed railway stations
# PageError for title: Amtrak
# PageError for title: SNCF
# PageError for title: British Rail Class 309
# PageError for title: Dubai Metro
# PageError for title: British Rail Class 86
# PageError for title: Palace on Wheels
# PageError for title: British Rail Class 33
# PageError for title: Dark ride
# PageError for title: R211 (New York City Subway car)
# PageError for title: Georgia 300
# PageError for title: Regio 2N

# %%
# Create the CSV from the DataFrame
Trvl_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Travel.csv"
Trvl_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Travel = pd.read_csv("./Data/Travel.csv")
Travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB

# %% [markdown]
# ## Food

# %%
# Define the topics and subtopics
title = {
    'Food': [
        'Crop yield statistics', 'Global hunger and food security', 'Top world dishes',
        'Sustainable agriculture', 'Organic farming trends', 'Genetically modified organisms (GMOs)',
        'Food industry innovations', 'Nutrition and dietary trends', 'Veganism and plant-based diets',
        'Food safety and regulations', 'Food supply chain management', 'Impact of climate change on agriculture',
        'Aquaculture and fisheries', 'Food waste reduction strategies', 'Local food movements',
        'Culinary tourism', 'Street food culture', 'Fusion cuisine trends',
        'Food technology and startups', 'Superfoods and health trends', 'Food policy and legislation',
        'Agricultural technology (AgTech)', 'Food marketing and branding', 'Celebrity chefs and influencers',
        'Food in popular culture', 'Cooking techniques and trends', 'Gastronomy and fine dining',
        'Ethical eating and food justice', 'Childrens nutrition and school meals', 'Food allergies and intolerances',
        'Wine and beverage industry', 'Food festivals and events', 'Traditional cooking methods and preservation',
        'Food anthropology and history', 'Farming and rural development', 'Food and economic development'
    ],
}


# Initialize an empty list to store the scraped data
data_list = []

# Each and Every Heading and Side Headings related to the title gets looped.
# Webpages with unique titles and Summary over 250 characters are chosen.
# More than 5100 documents are set as a limit to extract information.
# Webpages are appended onto a list that later can be used to get a DataFrame.
# Wikipedia Disambiguation, HTTP timeout and Page errors are handled to enhance the process.
for heading, side_heading in title.items():
    short_summary_count = 0
    unique_titles = set()

    for iterate in side_heading:
        wikipedia.set_lang("en")
        search_results = wikipedia.search(iterate, results=5600)
        for webpage_heading in search_results:
            retry_count = 0
            while retry_count < 3:  # Retry up to 3 times
                try:
                    if webpage_heading in unique_titles:
                        break
                    page = wikipedia.page(webpage_heading)
                    summary = page.summary
                    if len(summary) >= 250:
                        data_list.append({
                            'Topic': heading,
                            'Title': page.title,
                            'Summary': summary,
                            'URL': page.url,
                            'Revision ID': page.revision_id  
                        })
                        unique_titles.add(webpage_heading)
                    break  # Exit retry loop if successful
                except wikipedia.exceptions.DisambiguationError:
                    break  # No retry for disambiguation errors
                except wikipedia.exceptions.PageError:
                    print(f"PageError for title: {webpage_heading}")
                    break  # No retry for page errors
                except (wikipedia.exceptions.HTTPTimeoutError, requests.exceptions.ConnectionError):
                    print(f"Error for title: {webpage_heading}, retrying ({retry_count + 1}/3)")
                    time.sleep(5)  # Wait 5 seconds before retrying
                    retry_count += 1
                except Exception as e:
                    print(f"Unhandled exception for title: {webpage_heading}: {e}")
                    break  # Exit retry loop for any other exception

            if len(unique_titles) >= 5600:
                break

        if len(unique_titles) >= 5600:
            break
# Out:
# PageError for title: Cereal
# PageError for title: Agriculture in India
# c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file c:\Users\aniru\AppData\Local\Programs\Python\Python311\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# PageError for title: Organic farming
# PageError for title: Alfalfa
# PageError for title: Vertical farming
# PageError for title: Corn production in the United States
# PageError for title: Sesame
# PageError for title: Pearl millet
# PageError for title: Pigeon pea
# PageError for title: Injera
# PageError for title: Almond
# PageError for title: Agriculture in South Africa
# PageError for title: Pollination
# PageError for title: Pumpkin
# PageError for title: Ginger
# PageError for title: Proso millet
# PageError for title: Food security
# PageError for title: Yuan Longping
# PageError for title: Shiso
# PageError for title: Machine learning
# PageError for title: Haber process
# PageError for title: Hop production in the United States
# PageError for title: Farmall
# PageError for title: Ricky Ponting
# PageError for title: Economy of Canada
# PageError for title: Gilded Age
# PageError for title: Q (disambiguation)
# PageError for title: Jordan Peterson
# PageError for title: Isabela (province)
# PageError for title: Belize
# PageError for title: Romania
# PageError for title: Nutmeg
# PageError for title: 2018 British Isles heatwave
# PageError for title: Industrial Revolution
# PageError for title: Economy of China
# PageError for title: German wine
# PageError for title: Wa State
# PageError for title: Inflation
# PageError for title: Clemson University
# PageError for title: El Niño
# PageError for title: Chaos theory
# PageError for title: Food security
# PageError for title: Cheryl Mills
# PageError for title: Agrifood systems
# PageError for title: Jennifer Clapp
# PageError for title: Soup kitchen
# PageError for title: Food desert
# PageError for title: United Nations
# PageError for title: Yuan Longping
# PageError for title: Midday Meal Scheme
# PageError for title: Southern Africa
# PageError for title: Bobby Sands
# PageError for title: Ami Bera
# PageError for title: John Glen (politician)
# PageError for title: Drought
# PageError for title: The Farmlink Project
# PageError for title: Lester R. Brown
# PageError for title: Water scarcity
# PageError for title: Deliveroo
# PageError for title: Organic farming
# PageError for title: Sandy Berger
# PageError for title: Agriculture in India
# PageError for title: 38th G8 summit
# PageError for title: Walmart
# PageError for title: Economic impact of the COVID-19 pandemic
# PageError for title: Joe Biden
# PageError for title: Iraq War
# PageError for title: City
# PageError for title: Hillhouse Capital
# PageError for title: Oxfam
# PageError for title: Philippines
# PageError for title: Barbie (film)
# PageError for title: China
# PageError for title: Landesa
# PageError for title: Obesity
# PageError for title: National dish
# PageError for title: Dim sum
# PageError for title: List of crab dishes
# PageError for title: Top Chef
# PageError for title: List of pasta dishes
# PageError for title: Tajine
# PageError for title: Fried rice
# PageError for title: Flat iron steak
# PageError for title: Top Chef: All-Stars L.A.
# PageError for title: List of toast dishes
# PageError for title: Thai cuisine
# PageError for title: Slow cooker
# PageError for title: Scallion
# PageError for title: Nutmeg
# PageError for title: Bay leaf
# PageError for title: Alambre
# PageError for title: Gordon Ramsay
# PageError for title: Injera
# PageError for title: Turmeric
# PageError for title: Kibbeh
# PageError for title: 2023 World Snooker Championship
# PageError for title: Manti (food)
# PageError for title: Fried egg
# PageError for title: Stamppot
# PageError for title: Vikas Khanna
# PageError for title: Shabu-shabu
# PageError for title: MasterChef (American season 13)
# PageError for title: Chili con carne
# PageError for title: Congee
# PageError for title: Anthony Bourdain
# PageError for title: Fall (2022 film)
# PageError for title: Bitter lemon
# PageError for title: Guy Fieri
# PageError for title: Toast Hawaii
# PageError for title: Pilaf
# PageError for title: Beetroot
# PageError for title: Peking duck
# PageError for title: Chipped beef
# PageError for title: Ginger
# PageError for title: Christine Hà
# PageError for title: Nattō
# PageError for title: Katy Perry
# PageError for title: Tri-tip
# PageError for title: Emily Osment
# PageError for title: Jollof rice
# PageError for title: Haunted Mansion (2023 film)
# PageError for title: MasterChef Australia (series 11)
# PageError for title: Philippines
# PageError for title: Frog legs
# PageError for title: Julia Haart
# PageError for title: Yum cha
# PageError for title: Honda NSX
# PageError for title: Organic farming
# PageError for title: Cocoa bean
# PageError for title: Agriculture in India
# PageError for title: Vertical farming
# PageError for title: Farmer
# PageError for title: List of agricultural machinery
# PageError for title: Joel Salatin
# PageError for title: Food security
# PageError for title: Deforestation
# PageError for title: Agenda 21
# PageError for title: Winged bean
# PageError for title: Blue economy
# PageError for title: Livestock
# PageError for title: Eutrophication
# PageError for title: Food miles
# PageError for title: Alfalfa
# PageError for title: Biosecurity
# PageError for title: Crowd Cow
# PageError for title: Bioproduct
# PageError for title: Mechanised agriculture
# Error for title: Metropolitan agriculture, retrying (1/3)
# PageError for title: Earth Summit 2002
# PageError for title: Environmental psychology
# PageError for title: Lavazza
# PageError for title: Non-renewable resource
# PageError for title: Environmental law
# PageError for title: Environmental technology
# PageError for title: Tomato
# PageError for title: Beekeeper
# PageError for title: Agrifood systems
# PageError for title: Sustainable planting
# PageError for title: Environmental engineering
# PageError for title: George Washington Carver
# PageError for title: Simple living
# PageError for title: Organic farming
# PageError for title: Agriculture in India
# PageError for title: Vertical farming
# PageError for title: Organic Rankine cycle
# PageError for title: Sam Kass
# PageError for title: Eutrophication
# PageError for title: Alfalfa
# PageError for title: Cocoa bean
# PageError for title: Microplastics
# PageError for title: Bioplastic
# PageError for title: Veganism
# PageError for title: Soil pH
# PageError for title: Farmall
# PageError for title: Plastic
# PageError for title: Pollination
# PageError for title: Nike, Inc.
# PageError for title: Sex effects of water pollution
# PageError for title: RethinkX
# PageError for title: Bhutan
# PageError for title: Latvia
# PageError for title: Food miles
# PageError for title: John Adams
# PageError for title: Incineration
# PageError for title: Definitions of fascism
# PageError for title: La Serenísima
# PageError for title: FarmVille
# PageError for title: Deforestation
# PageError for title: Black Sea
# PageError for title: Food security
# PageError for title: 2022 Uttar Pradesh Legislative Assembly election
# PageError for title: German wine
# PageError for title: Economy of China
# PageError for title: Deforestation in Brazil
# PageError for title: Greenpeace
# PageError for title: Contamination
# PageError for title: Tifton 85
# PageError for title: Evo Morales
# PageError for title: Designer baby
# PageError for title: Organic farming
# PageError for title: Michael Pollan
# PageError for title: Alfalfa
# PageError for title: Greens of Serbia
# PageError for title: Glowing Plant project
# PageError for title: History of Raëlism
# PageError for title: Bill Nye
# PageError for title: Andrew Demeter
# PageError for title: Cry1Ac
# PageError for title: Fast food
# PageError for title: MTY Food Group
# PageError for title: Food truck
# PageError for title: Functional food
# PageError for title: Industrial Revolution
# PageError for title: MeaTech
# PageError for title: Talabat
# PageError for title: Food security
# PageError for title: Wegmans
# PageError for title: Agriculture in India
# PageError for title: Gutter oil
# PageError for title: Economy of Canada
# PageError for title: Generic drug
# PageError for title: Mechanised agriculture
# PageError for title: Dawn Foods
# PageError for title: Food miles
# PageError for title: Fashion
# PageError for title: Givaudan
# PageError for title: James Sinegal
# PageError for title: Ray Kroc
# PageError for title: Mining
# PageError for title: Max Fashion
# PageError for title: Economy of Tamil Nadu
# PageError for title: Kashmiri cuisine
# PageError for title: Merck Group
# PageError for title: Deliveroo
# PageError for title: French fries
# PageError for title: Citric acid
# PageError for title: Cosmetics
# PageError for title: Lactic acid bacteria
# PageError for title: Beyond Meat
# PageError for title: Marico
# PageError for title: Albert Bourla
# PageError for title: Fish and chips
# PageError for title: JTC Corporation
# PageError for title: Organic farming
# PageError for title: Gordon Ramsay
# PageError for title: Oatly
# PageError for title: Royal Canin
# PageError for title: Cereal
# PageError for title: Dim sum
# PageError for title: Burger King
# PageError for title: PedidosYa
# PageError for title: Southern Africa
# PageError for title: Uber Eats
# PageError for title: OQ (company)
# PageError for title: Value proposition
# PageError for title: Technological Revolutions and Financial Capital
# PageError for title: Prebiotic (nutrition)
# PageError for title: Veganism
# PageError for title: Cat food
# PageError for title: Carnivore diet
# PageError for title: Trans fat
# PageError for title: Pea protein
# PageError for title: Oat milk
# PageError for title: Nutrition transition
# PageError for title: Superfood
# PageError for title: Chromium
# PageError for title: Whey protein
# PageError for title: Food security
# PageError for title: Brazil nut
# PageError for title: Vitamin B12 deficiency
# PageError for title: Iodised salt
# PageError for title: Obesity
# PageError for title: Average human height by country
# PageError for title: Sucrose
# PageError for title: Lectin
# PageError for title: Dog coat
# PageError for title: Butyric acid
# PageError for title: Fishcake
# PageError for title: Starch
# PageError for title: Falafel
# PageError for title: Puberty
# PageError for title: Guar gum
# PageError for title: Autoimmunity
# PageError for title: Alfalfa
# PageError for title: Southern Africa
# PageError for title: Fast food
# PageError for title: Snow pea
# PageError for title: Medicinal plants
# PageError for title: Brown bear
# PageError for title: Water
# PageError for title: Appendicitis
# PageError for title: ALS
# PageError for title: Baking mix
# PageError for title: WW International
# PageError for title: Red panda
# PageError for title: Longevity
# PageError for title: Veganism
# PageError for title: Healthy diet
# PageError for title: Brenda Davis
# PageError for title: Vegetarian diet
# PageError for title: Michael Greger
# PageError for title: DASH diet
# PageError for title: Cat food
# PageError for title: Oat milk
# PageError for title: Mary McCartney
# PageError for title: Dean Ornish
# PageError for title: Alpro
# PageError for title: Alicia Silverstone
# PageError for title: Simple living
# PageError for title: Joel Kahn
# PageError for title: Lightlife
# PageError for title: SlimFast
# PageError for title: Animal product
# PageError for title: B vitamins
# PageError for title: Oatly
# PageError for title: Pea milk
# PageError for title: Kat Von D
# PageError for title: Vitamin B12
# PageError for title: Scott Jurek
# PageError for title: Eric Adams
# PageError for title: Soul food
# PageError for title: Drew Barrymore
# PageError for title: Braising
# PageError for title: Rynn Berry
# PageError for title: Ed Templeton
# PageError for title: The Humane League
# PageError for title: Cat meat
# PageError for title: Chia seed
# PageError for title: Tobias Leenaert
# PageError for title: Abura-age
# PageError for title: John Mackey (businessman)
# PageError for title: Roasting
# PageError for title: Stew
# PageError for title: Nattō
# PageError for title: Goat meat
# PageError for title: Meat chop
# PageError for title: Falafel
# PageError for title: Vitasoy
# PageError for title: NLE Choppa
# PageError for title: Purple Carrot
# PageError for title: Sabra (company)
# PageError for title: Vertical farming
# PageError for title: James Cameron
# PageError for title: Steven Best
# PageError for title: JBS S.A.
# PageError for title: Mahi-mahi
# PageError for title: Miso
# PageError for title: Biosafety
# PageError for title: Gutter oil
# PageError for title: FPO mark
# PageError for title: American cheese
# PageError for title: Bay leaf
# PageError for title: Janet Woodcock
# PageError for title: SAFE FOODS
# PageError for title: Caramel color
# PageError for title: Food truck
# PageError for title: Pressure cooking
# PageError for title: Anne Astin
# PageError for title: Pasteurization
# PageError for title: Cosmetics
# PageError for title: Animal product
# PageError for title: Diacetyl
# PageError for title: Deliveroo
# PageError for title: Food security
# PageError for title: Resource Conservation and Recovery Act
# PageError for title: Trans fat
# PageError for title: Almond
# PageError for title: Dog meat
# PageError for title: Traceability
# PageError for title: Tealight
# PageError for title: Apple cider
# PageError for title: Escolar
# PageError for title: Whey protein
# PageError for title: KFC
# PageError for title: Grocers Supply
# PageError for title: Agrifood systems
# PageError for title: Jabil
# PageError for title: Food security
# PageError for title: MTY Food Group
# PageError for title: Burger King
# PageError for title: Fast food
# PageError for title: Water resources
# PageError for title: ISO 14000
# PageError for title: Cat food
# PageError for title: Food miles
# PageError for title: List of companies of the United Kingdom K-Z
# PageError for title: Safeway
# PageError for title: Fiesta Mart
# PageError for title: Famous Brands
# PageError for title: Costco
# PageError for title: Safeway (UK)
# PageError for title: Teal organisation
# PageError for title: Managerial economics
# PageError for title: Bureau Veritas
# PageError for title: BWG Foods
# PageError for title: Infor
# PageError for title: PPB Group
# PageError for title: Sablefish
# PageError for title: DHIS2
# PageError for title: BSI Group
# PageError for title: Swisslog
# PageError for title: Water scarcity
# PageError for title: Organic farming
# PageError for title: Pep Boys
# PageError for title: American Stores
# PageError for title: REWE Group
# PageError for title: CKE Restaurants
# PageError for title: Walmart
# PageError for title: Costa Coffee
# PageError for title: SA8000
# PageError for title: Kathryn Garcia
# PageError for title: Galen Weston
# PageError for title: Environmental degradation
# PageError for title: Climate change in Iraq
# PageError for title: Livestock
# PageError for title: Drought
# PageError for title: Food security
# PageError for title: Water resources
# PageError for title: Temperate climate
# PageError for title: Environmental issues
# PageError for title: Water scarcity
# PageError for title: Organic farming
# PageError for title: Greta Thunberg
# PageError for title: Benjamin Z. Houlton
# PageError for title: Agriculture in India
# PageError for title: Deforestation
# PageError for title: Deforestation in Brazil
# PageError for title: David Lobell
# PageError for title: Climate of South Africa
# PageError for title: Bioenergy
# PageError for title: Asia
# PageError for title: Frank Ewert
# PageError for title: Mariculture
# PageError for title: Alligator gar
# PageError for title: Blue economy
# PageError for title: Bay of Bengal
# PageError for title: Carmen C. Velasquez
# PageError for title: Sablefish
# PageError for title: Ministry of Fisheries (New Zealand)
# PageError for title: Mussel
# PageError for title: List of domesticated animals
# PageError for title: Giant clam
# PageError for title: Mors (island)
# PageError for title: Holothuria scabra
# PageError for title: Black sea bass
# PageError for title: Grass carp
# PageError for title: Ministry of Fisheries (Sri Lanka)
# PageError for title: Paddlefish
# PageError for title: West Nusa Tenggara
# PageError for title: Food security
# PageError for title: Wong Kam-sing
# PageError for title: Environmental degradation
# PageError for title: Food miles
# PageError for title: Septic tank
# PageError for title: Agrifood systems
# PageError for title: Pollution
# PageError for title: Microplastics
# PageError for title: Acid rain
# PageError for title: Mining
# PageError for title: Biochar
# PageError for title: Climate change in Iraq
# PageError for title: Water resources
# PageError for title: Almond
# PageError for title: Eutrophication
# PageError for title: Organic farming
# PageError for title: Environmental law
# PageError for title: Rural area
# PageError for title: Hanford Site
# PageError for title: Jamie Oliver
# PageError for title: Joe Biden
# PageError for title: ISO 14000
# PageError for title: Vertical farming
# PageError for title: Environmental issues
# PageError for title: Pullapart
# PageError for title: Agriculture in India
# PageError for title: Termite
# PageError for title: Kenny vs. Spenny
# PageError for title: Starbucks
# PageError for title: Walmart
# PageError for title: Managerial economics
# PageError for title: Biofilter
# PageError for title: Open defecation
# PageError for title: Simple living
# PageError for title: Food security
# PageError for title: Food desert
# PageError for title: List of fascist movements
# PageError for title: Conviviality
# PageError for title: Baba Siddique
# PageError for title: The OA
# PageError for title: Sex worker movements
# PageError for title: Raccoon
# PageError for title: Organic farming
# PageError for title: Arctic wolf
# PageError for title: Pogona
# PageError for title: Veganism
# PageError for title: Earl Grey tea
# PageError for title: New York City
# PageError for title: Philippines
# PageError for title: Groundhog
# PageError for title: Washington, D.C.
# PageError for title: China
# PageError for title: Hyung Jin Moon
# PageError for title: Polar bear
# PageError for title: Yasser Arafat
# PageError for title: Colonisation of Africa
# PageError for title: Italy
# PageError for title: Manta ray
# PageError for title: 2001 United Kingdom foot-and-mouth outbreak
# PageError for title: Dugong
# PageError for title: Apartheid
# PageError for title: Reedfish
# PageError for title: Northern pike
# PageError for title: Environmental science
# PageError for title: Khun Sa
# PageError for title: Bull shark
# PageError for title: Wild boar
# PageError for title: Charles Manson
# PageError for title: Religion in China
# PageError for title: Islam
# PageError for title: Lion
# PageError for title: Morrissey
# PageError for title: Tongva
# PageError for title: Jim Jones
# PageError for title: Paul Reubens
# PageError for title: Christianity
# PageError for title: Rook (bird)
# PageError for title: Gilded Age
# PageError for title: Industrial Revolution
# PageError for title: Bed bug
# PageError for title: Indira Gandhi
# PageError for title: Environmental justice
# PageError for title: Greenland
# PageError for title: Pig
# PageError for title: Michael Portillo
# PageError for title: World War II casualties
# PageError for title: Romania
# PageError for title: Ecobricks
# PageError for title: The Beatles
# PageError for title: Carlos Lehder
# PageError for title: Bearded reedling
# PageError for title: Honeyeater
# PageError for title: Faroe Islands
# PageError for title: Resistance during World War II
# PageError for title: Giant sunfish
# PageError for title: Irgun
# PageError for title: Foodie
# PageError for title: Cultural tourism
# PageError for title: Sam Kass
# PageError for title: Withlocals
# PageError for title: Porta del Sol
# PageError for title: Swain Destinations
# PageError for title: Sicily
# PageError for title: Cape Town
# PageError for title: Sorted Food
# PageError for title: Ubud
# PageError for title: National dish
# PageError for title: Taken (film)
# PageError for title: John Besh
# PageError for title: Lake Bled
# PageError for title: Lyceum of the Philippines – Davao
# PageError for title: Bori (food)
# PageError for title: Thai cuisine
# PageError for title: V&A Waterfront
# PageError for title: John Torode
# PageError for title: Oceania Cruises
# PageError for title: China
# PageError for title: Philippines
# PageError for title: Morton Salt
# PageError for title: Norway
# PageError for title: Colonel Sanders
# PageError for title: Dusit International
# PageError for title: La Gomera
# PageError for title: Costa Brava
# PageError for title: Andong
# PageError for title: Saimin
# PageError for title: Josh Emett
# PageError for title: Icy Strait Point
# PageError for title: Rajasthani cuisine
# PageError for title: Food truck
# PageError for title: Thai cuisine
# PageError for title: Akara
# PageError for title: Fast food
# PageError for title: Food cart
# PageError for title: Samsa (food)
# PageError for title: Kashmiri cuisine
# PageError for title: Chop suey
# PageError for title: Goya Foods
# PageError for title: Mong Kok
# PageError for title: Culture of India
# PageError for title: Food Network
# PageError for title: Gupi
# PageError for title: National dish
# PageError for title: Manti (food)
# PageError for title: Tex-Mex
# PageError for title: Halal cart
# PageError for title: Jianbing
# PageError for title: Mott Street
# PageError for title: Grace Dent
# PageError for title: James Beard
# PageError for title: Halva
# PageError for title: Food security
# PageError for title: Dole plc
# PageError for title: Street Dancer 3D
# PageError for title: MTY Food Group
# PageError for title: Wari culture
# PageError for title: Bento
# PageError for title: List of Chinese dishes
# PageError for title: Maker culture
# PageError for title: Dog meat
# PageError for title: California roll
# PageError for title: Sesame Street
# PageError for title: Mr Chow
# PageError for title: Nicolas Appert
# PageError for title: French fries
# PageError for title: Simit
# PageError for title: Hot dog
# PageError for title: Al pastor
# PageError for title: Dim sum
# PageError for title: Hygge

# %%
# Create the CSV from the DataFrame
food_df = pd.DataFrame(data_list)
csv_file_name = "./Data/Food.csv"
food_df.to_csv(csv_file_name, index=False)

# Check with the csv file.
Food = pd.read_csv("./Data/Food.csv")
Food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Topic        5600 non-null   object
#  1   Title        5600 non-null   object
#  2   Summary      5600 non-null   object
#  3   URL          5600 non-null   object
#  4   Revision ID  5600 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 218.9+ KB
